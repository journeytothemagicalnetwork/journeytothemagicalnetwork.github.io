# %%
import pandas as pd
import networkx as nx
import numpy as np
import math
import re 
import urllib.request
import json
import matplotlib.pyplot as plt
import nltk
from nltk import * 
from nltk.corpus import * 
from nltk.tokenize import WordPunctTokenizer
import wordcloud
from IPython.display import YouTubeVideo, HTML, display
import pickle
from wordcloud import WordCloud, ImageColorGenerator
from PIL import Image

# %% [markdown]
# # Harry Potter: A journey to the magical Network
# Welcome to our final project, a trip where the unknown is unveiled through the understanding of networks and natural language processing.

# %% [markdown]
# # Data prep

# %% [markdown]
# ## DO NOT RUN: SCRAPPING PREP

# %% [markdown]
# ### Dataframe preparation (with name and house)

# %%
# list_of_cath =['Category:Unknown_House',
# 'Category:Ravenclaws',
# 'Category:Gryffindors',
# 'Category:Slytherins' ,
# 'Category:Hufflepuffs']

# dict_house={}
# for cat in list_of_cath:
#     list_of_members=[]
#     baseurl = "https://harrypotter.fandom.com/api.php?"
#     action = "action=query"
#     cmtitle = "cmtitle="+cat
#     content = "list=categorymembers&cmlimit=max"
#     dataformat ="format=json"

#     query = "{}{}&{}&{}&{}".format(baseurl, action, content, cmtitle, dataformat)

#     print(query)
#     wikiresponse = urllib.request.urlopen(query)
#     wikidata = wikiresponse.read()
#     wikitext = wikidata.decode('utf-8')
#     description = json.loads(wikitext)  
#     for dict_ in description['query']['categorymembers']:
#         if ('Template:' in dict_['title']) or ('Category:' in dict_['title']) \
#         or ('Unidentified' in dict_['title']):
#             pass
#         else:
#             list_of_members.append(dict_['title'])
#     dict_house[cat]=list_of_members
    
# all_house =[]
# for col in sorted(list_of_cath): 
#     df = pd.DataFrame(dict_house[col])
#     df['House']=col[9:]
#     df.columns=['Name','House']
#     all_house.append(df)
# df = pd.concat(all_house).reset_index(drop=True)
# df

# %% [markdown]
# ### Creation of the Description folder -> to be used for extracting info about the characters

# %%
# for name in list(df.Name):
#     baseurl = "https://harrypotter.fandom.com/api.php?"
#     action = "action=query"
#     title = "titles="+urllib.parse.quote_plus(name)
#     content = "prop=revisions&rvprop=content&rvslots=*"
#     dataformat ="format=json"

#     query = "{}{}&{}&{}&{}".format(baseurl, action, content, title, dataformat)

#     wikiresponse = urllib.request.urlopen(query)
#     wikidata = wikiresponse.read()
#     wikitext = wikidata.decode('utf-8')
#     description = json.loads(wikitext)  
#     page_number=list(description['query']['pages'].keys())[0]
#     text_to_paste= description['query']['pages'][page_number]['revisions'][0]['slots']['main']['*']
#     #SECOND STEP: SAVE RESULT IN A FOLDER

#     with open("Description\{}.txt".format(name), "w") as text_file:
#         json.dump(text_to_paste,text_file)
# #     print(name)

# %% [markdown]
# ### Creation of the Description extract folder -> to be used for text analysis

# %%
# for name in list(df.Name):
#     baseurl = "https://harrypotter.fandom.com/api.php?"
#     action = "action=query"
#     title = f"titles="+urllib.parse.quote_plus(name)
#     content = "prop=extracts&exlimit=1&explaintext"
#     dataformat ="format=json"
    
#     query = "{}{}&{}&{}&{}".format(baseurl, action, content, title, dataformat)
    
#     wikiresponse = urllib.request.urlopen(query)
#     wikidata = wikiresponse.read()
#     wikitext = wikidata.decode('utf-8')
#     description = json.loads(wikitext)
#     page_number = list(description['query']['pages'].keys())[0]
#     text_to_paste=description['query']['pages'][page_number]['extract']
#     list_to_remove=["== Notes and references ==","== External links ==",'\n','\t']
    
#     #FIRST STEP FIND TITLE WITH REG EXPRESS
#     pattern_1 ='(=+[\w\s\–\(\)\'^\w\/\"\,\.\w\-\w]+=+)'
#     pattern_2 ='(=+(?:[\w\s]+=+\s)+[\w\s]+=+)'
#     list_to_remove = re.findall(pattern_1,text_to_paste)+re.findall(pattern_2,text_to_paste)
#     list_to_remove.append('\t')
#     list_to_remove.append('\n')
#     for element in list_to_remove:
#         text_to_paste=text_to_paste.replace(element,"")
    
    
#     pattern_replace = '(\s\s+)'
#     list_to_replace = re.findall(pattern_replace,text_to_paste)
#     for element in list_to_replace:
#         text_to_paste=text_to_paste.replace(element," ")
        
#     # Here we are just removing the unicode characters from the text
#     text_to_paste = text_to_paste.encode('unicode_escape').decode('ascii')
#     text_to_paste = re.sub(r'\\u(.){4}', '', text_to_paste)
    
#     #SECOND STEP: SAVE RESULT IN A FOLDER
#     with open("Description_extract\{}.txt".format(name), "w") as text_file:
#          json.dump(text_to_paste,text_file)
#     print(name)

# %% [markdown]
# Cleaning Organisational character like TRIO and only keep characters

# %%
# page_path = "Description/"

# # list_to_remove=[]
# list_to_keep=[]
# for name in df.Name:

#     with open(page_path+name+'.txt','r') as f:
#         node_description= f.read()
#     node_description
# #     pattern_to_erase=r'(Organisation infobox)'
#     pattern_to_keep=r'(Individual infobox)'
#     if len(re.findall(pattern_to_find,node_description))>0:
#         list_to_remove.append(name)
#     if len(re.findall(pattern_to_keep,node_description))>0:
#         list_to_keep.append(name)

# df = df[df['Name'].isin(list_to_keep)]

# %%
# def find_cat(wikitext,reg):
#     value = re.findall(reg, wikitext)
#     if len(value) > 0:
#         return value[0]
#     else:
#         return "Unknown"
    
# def get_all_attributs(name,page_path = "Description/"):
#     with open(page_path+name+'.txt','r') as f:
#         node_description= f.read()

#     #gender
#     reg_gender = r"gender = ([\w \-]+)"
#     item= re.findall(reg_gender,node_description)
#     if len(item)>0:
#         gender=item[0]
#     else:
#         gender='Unknown'
    
#     #blood
#     reg_blood = r"blood = \[\[([\w\- ]+)\]\]"
#     item= re.findall(reg_blood,node_description)
#     if len(item)>0:
#         blood=item[0]
#     else:
#         blood='Unknown'
    
#     #species
#     reg_species= r"species = \[\[([\w \-]+)\]\]"
#     item = re.findall(reg_species,node_description)
#     if len(item)>0:
#         species=item[0]
#     else:
#         species='Unknown'
    
#     #nationality
#     reg_nationality_1=r"nationality = \[\[([\w\| \-]+)\]\]"
#     reg_nationality_1_bis=r'nationality = \[\[(.*?)(?:\|.*?)?\]\]'
#     reg_nationality_2=r"nationality = \{\{([\w\| \-]+)\}\}"

#     item= re.findall(reg_nationality_1_bis,node_description)+ re.findall(reg_nationality_2,node_description)  
#     if len(item)>0:
#         nationality=item[0]
#     else:
#         nationality='Unknown'
    
#     #heigh
#     reg_height= r"height = ([\w\s\-\']+)"
#     item = re.findall(reg_height,node_description)
#     if len(item)>0:
#         heigh=item[0]
#     else:
#         heigh='Unknown'    
    
#     #weight
#     reg_weight=r"weight = ([\w\s\-]+)"
#     item = re.findall(reg_weight,node_description)
#     if len(item)>0:
#         weight=item[0]
#     else:
#         weight='Unknown'
        
#     #hair
#     reg_hair=r"hair = ([\w \-]+)"
#     item =re.findall(reg_hair,node_description)
#     if len(item)>0:
#         hair=item[0]
#     else:
#         hair='Unknown'
        
#     #eyes
#     reg_eyes=r"eyes = ([\w \-]+)"
#     item =re.findall(reg_eyes,node_description)
#     if len(item)>0:
#         eyes=item[0]
#     else:
#         eyes='Unknown'
        
#     #skin    
#     reg_skin=r"skin = ([\w \-]+)"
#     item =re.findall(reg_skin,node_description)
#     if len(item)>0:
#         skin=item[0]
#     else:
#         skin='Unknown'
        
#     #caracters_in_page
#     new_reg_link = r'\[\[(.*?)(?:\|.*?)?\]\]'
#     caracters_in_page=[]
#     linked_names_quick= re.findall(new_reg_link,node_description)
#     for element in set(linked_names_quick):
#         if element in list(df.Name):
#             caracters_in_page.append(element)
#     return [gender,blood,species,nationality,heigh,weight,hair,eyes,skin,caracters_in_page]

# %%
# # get_all_attributs('Ronald Weasley')

# gender_link=[]
# blood_link=[]
# species_link=[]
# nationality_link=[]
# heigh_link=[]
# weight_link=[]
# hair_link=[]
# eyes_link=[]
# skin_link=[]
# caracters_in_page_link=[]

# for name in list(df['Name']):
#     attribut = get_all_attributs(name)
#     gender_link.append(attribut[0])
#     blood_link.append(attribut[1])
#     species_link.append(attribut[2])
#     nationality_link.append(attribut[3])
#     heigh_link.append(attribut[4])
#     weight_link.append(attribut[5])
#     hair_link.append(attribut[6])
#     eyes_link.append(attribut[7])
#     skin_link.append(attribut[8])
#     caracters_in_page_link.append(attribut[9])
    
    
# df['Gender']=gender_link
# df['Blood']=blood_link
# df['Species']=species_link
# df['Nationality']=nationality_link
# df['Heigh']=heigh_link
# df['Weight']=weight_link
# df['Hair']=hair_link
# df['Eyes']=eyes_link
# df['Skin']=skin_link
# df['Caracters_in_page']=caracters_in_page_link

# # df['List_link']=list_link
# # df['Race']=race_
# # df['Gender']=gender_
# # df['Description']=description_
# df.head()
# df['House'].replace('Unknown_House', 'Unknown')

# %% [markdown]
# ## YOU CAN RUN BOYSSSSSSSSSS

# %%
import pickle

# # # For storing

# # with open(r"pickle_network_prep.txt", "wb") as fp:   #Pickling
# #     pickle.dump(df, fp)

# For loading

with open(r"pickle_network_prep.txt", "rb") as fp:   # Unpickling
    df_all = pickle.load(fp)

df_all.describe()
# Out:
#                      Name        House Gender    Blood Species Nationality  \
# count                 865          865    865      865     865         865
# unique                865            5      3        4       3           7
# top     Salazar Slytherin  Gryffindors   Male  Unknown   Human      GBorIE
# freq                    1          230    469      664     833         773
#
#           Heigh   Weight     Hair     Eyes     Skin Caracters_in_page
# count       865      865      865      865      865               865
# unique       15       13       36       26       18               484
# top     Unknown  Unknown  Unknown  Unknown  Unknown                []
# freq        847      852      620      703      628               323

# %%
df_all.head()
# Out:
#                Name        House  Gender    Blood Species Nationality  \
# 0  Euan Abercrombie  Gryffindors    Male  Unknown   Human      GBorIE
# 1      Sakura Akagi  Gryffindors  Female  Unknown   Human      GBorIE
# 2       Zakir Akram  Gryffindors    Male  Unknown   Human      GBorIE
# 3         Nick Alas  Gryffindors    Male  Unknown   Human      GBorIE
# 4   Filemina Alchin  Gryffindors  Female  Unknown   Human      GBorIE
#
#      Heigh   Weight     Hair     Eyes     Skin  \
# 0  Unknown  Unknown  Unknown  Unknown  Unknown
# 1  Unknown  Unknown  Unknown  Unknown  Unknown
# 2  Unknown  Unknown  Unknown  Unknown  Unknown
# 3  Unknown  Unknown  Unknown  Unknown  Unknown
# 4  Unknown  Unknown  Unknown  Unknown  Unknown
#
#                    Caracters_in_page
# 0                     [Harry Potter]
# 1                                 []
# 2                                 []
# 3                                 []
# 4  [Angelina Appleby, Astrix Alixan]

# %%
G = nx.DiGraph()
for index, row in df_all.iterrows():
#     G.add_nodes_from([(this_dict[key], {'race': value[1],'gender': value[2]})])
    G.add_node(row['Name'], House=row['House'], Gender=row['Gender'],Blood=row['Blood'],Species=row['Species'] \
                          , Nationality=row['Nationality'], Heigh=row['Heigh'],Weight=row['Weight'],Eyes=row['Eyes'] \
                          ,Skin=row['Skin'])
for index, row in df_all.iterrows():
    for element in row['Caracters_in_page']:
        #REMOVE SELF LOOP
        if element !=row['Name']:
            G.add_edge(row['Name'],element)
            
#Remove node with zero degree
remove = [node for node,degree in dict(G.degree()).items() if degree==0]

print('nb nodes to remove',len(remove))

#Remove those nodes from the graph

G.remove_nodes_from(remove)

#Remove thoses nodes from the Dataframe
df_all.drop(df_all[df_all.Name.isin(remove)].index,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-b44c32ef2d95> in <module>
#       1 G = nx.DiGraph()
# ----> 2 for index, row in df_all.iterrows():
#       3 #     G.add_nodes_from([(this_dict[key], {'race': value[1],'gender': value[2]})])
#       4     G.add_node(row['Name'], House=row['House'], Gender=row['Gender'],Blood=row['Blood'],Species=row['Species'] \
#       5                           , Nationality=row['Nationality'], Heigh=row['Heigh'],Weight=row['Weight'],Eyes=row['Eyes'] \
#
# NameError: name 'df_all' is not defined

# %% [markdown]
# In the part, as we did during the exercice, we decided to consider only the GCC of the graph G. We also reduce the DataBase created in the part 0 with only the names of the characters in the GCC.

# %%
largest_cc = max(nx.weakly_connected_components(G), key=len)
GCC = G.subgraph(largest_cc)

## Creation of the dataframe that will contain only the GCC.
mask = df_all.Name.apply(lambda x: any(item for item in list(GCC.nodes()) if item in x))
df = df_all[mask]
##

# %%
import pickle

# # # For storing

# with open(r"pickle_network_final.txt", "wb") as fp:   #Pickling
#     pickle.dump(df, fp)

# For loading

with open(r"pickle_network_final.txt", "rb") as fp:   # Unpickling
    df = pickle.load(fp)

df.describe()
# Out:
#                    Name       House Gender    Blood Species Nationality  \
# count               511         511    511      511     511         511
# unique              511           5      3        4       3           7
# top     Thomas McGruder  Slytherins   Male  Unknown   Human      GBorIE
# freq                  1         126    276      315     487         428
#
#           Heigh   Weight     Hair     Eyes     Skin Caracters_in_page
# count       511      511      511      511      511               511
# unique       15       13       35       24       18               450
# top     Unknown  Unknown  Unknown  Unknown  Unknown    [Harry Potter]
# freq        493      498      293      368      296                38

# %% [markdown]
# # Part 1: Network visualization and basic stats
#
# Visualize the network (from lecture 5) and calculate stats (from lecture 4 and 5). For this exercise, we assume that you've already generated the BotW network and extracted the giant connected component. Use the GCC to report the results.
#
# _Exercise 1a_: Stats (see lecture 4 and 5 for more hints)
#
# > * What is the number of nodes in the network?
# > * What is the number of links?
# > * Who is the top connected character in BotW? (Report results for the in-degrees and out-degrees). Comment on your findings. Is this what you would have expected?
# > * Who are the top 5 most connected allies (again in terms of in/out-degree)?
# > * Who are the top 5 most connected enemies -- bosses included -- (again in terms of in/out-degree)?
# > * Plot the in- and out-degree distributions.
# >   * What do you observe?
# >   * Can you explain why the in-degree distribution is different from the out-degree distribution?
# > * Find the exponent of the degree distribution (by using the `powerlaw` package) for the in- and out-degree distribution. What does it say about our network?
# > * Compare the degree distribution of the undirected graph to a *random network* with the same number of nodes and probability of connection *p*. Comment your results.
#
# _Exercise 1b_: Visualization (see lecture 5 for more hints)
#
# > * Create a nice visualization of the total (undirected) network:
# >   * Color nodes according to the role;
# >   * Scale node-size according to degree;
# >   * Get node positions based on the Force Atlas 2 algorithm;
# >   * Whatever else you feel like that would make the visualization nicer.
# > * Describe the structure you observe. Can you identify nodes with a privileged position in the network? Do you observe chains of connected nodes? Do you see any interesting group of nodes (can you guess who's involved)?

# %%
print(f"Number of nodes in the network: {len(list(GCC.nodes))}" )
print(f"Number of links in the network: {len(list(GCC.edges))}" )
# Out:
# Number of nodes in the network: 511
# Number of links in the network: 5446

# %%
degrees_in = np.array([GCC.in_degree(n) for n in GCC.nodes()])
degrees_out = np.array([GCC.out_degree(n) for n in GCC.nodes()])
all_degree = np.array([GCC.degree(n) for n in GCC.nodes()])

df_degree= df.copy()
df_degree['in_degree']=degrees_in
df_degree['out_degree']=degrees_out
df_degree['all_degree']=all_degree

print('top connected character in BotW by All degrees')
print(df_degree.sort_values(by='all_degree',ascending=False)[['Name','all_degree']][:5])
print('______________________________________')
print('top connected character in BotW by in degrees')
print(df_degree.sort_values(by='in_degree',ascending=False)[['Name','in_degree']][:5])
print('______________________________________')
print('top connected character in BotW by out degrees')
print(df_degree.sort_values(by='out_degree',ascending=False)[['Name','out_degree']][:5])
# Out:
# top connected character in BotW by All degrees
#                  Name  all_degree
# 165      Harry Potter         371
# 52   Albus Dumbledore         222
# 667        Tom Riddle         218
# 220    Ronald Weasley         211
# 71   Hermione Granger         201
# ______________________________________
# top connected character in BotW by in degrees
#                  Name  in_degree
# 165      Harry Potter        277
# 667        Tom Riddle        154
# 52   Albus Dumbledore        129
# 220    Ronald Weasley        128
# 71   Hermione Granger        123
# ______________________________________
# top connected character in BotW by out degrees
#                  Name  out_degree
# 165      Harry Potter          94
# 52   Albus Dumbledore          93
# 220    Ronald Weasley          83
# 792   Jacob's sibling          81
# 71   Hermione Granger          78

# %% [markdown]
# Who are the top 5 most connected by house (again in terms of in/out-degree)? -> Gryffindors

# %%
df_gryffindors_degree=df_degree.loc[df_degree['House']=='Gryffindors']

print('top connected ally character in BotW by All degrees')
print(df_gryffindors_degree.sort_values(by='all_degree',ascending=False)[['Name','all_degree']].head())
print('______________________________________')

print('top connected ally character in BotW by in degrees')

print(df_gryffindors_degree.sort_values(by='in_degree',ascending=False)[['Name','in_degree']][:5])

print('______________________________________')
print('top connected ally character in BotW by out degrees')

print(df_gryffindors_degree.sort_values(by='out_degree',ascending=False)[['Name','out_degree']][:5])
# Out:
# top connected ally character in BotW by All degrees
#                    Name  all_degree
# 165        Harry Potter         371
# 52     Albus Dumbledore         222
# 220      Ronald Weasley         211
# 71     Hermione Granger         201
# 125  Minerva McGonagall         174
# ______________________________________
# top connected ally character in BotW by in degrees
#                    Name  in_degree
# 165        Harry Potter        277
# 52     Albus Dumbledore        129
# 220      Ronald Weasley        128
# 71     Hermione Granger        123
# 125  Minerva McGonagall        100
# ______________________________________
# top connected ally character in BotW by out degrees
#                    Name  out_degree
# 165        Harry Potter          94
# 52     Albus Dumbledore          93
# 220      Ronald Weasley          83
# 71     Hermione Granger          78
# 125  Minerva McGonagall          74

# %%
# Plot function for degree distributions
def plot_degree_dist(degs, title):
    k_min = np.min(degs)
    k_max = np.max(degs)
    print(f"k_min: {min(degs)}, k_max: {max(degs)}")
    bin_vector = np.arange(k_min,k_max+2)
    count, bins = np.histogram(degs, bins=bin_vector)
    f, (plt1, plt2) = plt.subplots(1,2, figsize=(16,5))  

    # Hist plot
    plt1.bar(bins[:len(bins)-1], count)
    plt1.set_title("Histogram of the degree distrubution " + title)   
    plt1.set(xlabel = 'Degree', ylabel = 'Number of nodes')

    # Log plot
    plt2.scatter(bins[:len(bins)-1], count)
    plt.xscale('log')
    plt.yscale('log')
    plt.xlim(1,1000)
    plt.ylim(1,1000)
    plt2.set_title("Degree distrubution in Log-Log scale " + title)  
    plt2.set(xlabel = 'Degree', ylabel = 'Number of nodes')

# %%
degs_in = [(v) for (e,v) in GCC.in_degree]
plot_degree_dist(degs_in, "(in-degree)")
# Out:
# k_min: 0, k_max: 277

# %%
degs_out = [(v) for (e,v) in GCC.out_degree]
plot_degree_dist(degs_out, "(out-degree)")
# Out:
# k_min: 0, k_max: 94

# %%
from collections import Counter
w_in = Counter(degrees_in)
w_out= Counter(degrees_out)
w= Counter(all_degree)
plt.figure(figsize=(7, 5)) 

plt.scatter(list(w_in.keys()), list(w_in.values()),color='g', label='in-degree')
plt.scatter(list(w_out.keys()), list(w_out.values()),color='b', label='out-degree')
plt.scatter(list(w.keys()), list(w.values()),color='r', label='all-degree')

# plt.loglog(list(w_in.keys()),  list(w_in.values()), 'go-', label='in-degree') 
# plt.loglog(list(w_out.keys()), list(w_out.values()), 'bo-', label='out-degree')
plt.xlabel('degree')
plt.ylabel('nb_nodes')
plt.xscale("log")
plt.yscale("log")
plt.legend()
plt.show()

# %%
import powerlaw
import warnings
warnings.filterwarnings("ignore")
in_exponent = powerlaw.Fit(degrees_in).power_law.alpha
out_exponent = powerlaw.Fit(degrees_out).power_law.alpha
total_exponent = powerlaw.Fit(all_degree).power_law.alpha

print("Degree exponent for in-degree: ", in_exponent)
print("Degree exponent for out-degree: ", out_exponent)
print("Degree exponent for total-degree: ", total_exponent)
# Out:
# Calculating best minimal value for power law fit
# Calculating best minimal value for power law fit
# Calculating best minimal value for power law fit
# Degree exponent for in-degree:  2.710108156799835
# Degree exponent for out-degree:  3.783308874309365
# Degree exponent for total-degree:  2.9916396758690453
# Values less than or equal to 0 in data. Throwing out 0 or negative values
# Values less than or equal to 0 in data. Throwing out 0 or negative values

# %% [markdown]
# ## Exercise 1b: Visualization (see lecture 5 for more hints)

# %%
def top_n_most_connected(house,n=3):
    df_house_degree=df_degree.loc[df_degree['House']==house]

    return list(df_house_degree.sort_values(by='all_degree',ascending=False)['Name'][:n])
sorted(set(df['House']))
# Out:
# ['Gryffindors', 'Hufflepuffs', 'Ravenclaws', 'Slytherins', 'Unknown']

# %% [markdown]
# <img src="house_color.png" alt="Hylian" width="350" style="float: center;" title="House color in Harry Potter"/>

# %%
GCC_ind= GCC.to_undirected()

House_list = list(nx.get_node_attributes(GCC_ind,'House').values())

color_list, uniques = pd.factorize(House_list)
d = nx.degree(GCC_ind)

house_list = ['Gryffindors', 'Hufflepuffs', 'Ravenclaws', 'Slytherins', 'Unknown']
color_list = ['firebrick','dimgrey','navy','forestgreen','yellow']
zip_iterator = zip(house_list, color_list)
dict_color = dict(zip_iterator)

dict_nodes={}
dict_size={}
dict_label={}
i=0
for house in set(df['House']):
    dict_nodes[house]=[x for x,y in GCC_ind.nodes(data=True) if y['House']==house]
    dict_size[house]=np.array([d[x]+1 for x in dict_nodes[house]])*4
    n=3
    if house == 'Gryffindors':
        n=6
    elif house == 'Slytherins':
        n=10
    else: n=3
    dict_label[house]={name:name if name in top_n_most_connected(house,n) else " " for name,y in GCC_ind.nodes(data=True) if y['House']==house}
    
    i+=1
#Color edges
edges = GCC_ind.edges()
color = []
width_egde=[]

for u,v in edges:
    if df.loc[df['Name']==u].House.values[0]=="Gryffindors" and df.loc[df['Name']==v].House.values[0]=="Gryffindors":
        color.append('firebrick')
        width_egde.append(0.5)
    elif df.loc[df['Name']==u].House.values[0]=="Hufflepuffs" and df.loc[df['Name']==v].House.values[0]=="Hufflepuffs":
        color.append('dimgrey')
        width_egde.append(0.5)

    elif df.loc[df['Name']==u].House.values[0]=="Ravenclaws" and df.loc[df['Name']==v].House.values[0]=="Ravenclaws":
        color.append('navy')
        width_egde.append(0.5)

    elif df.loc[df['Name']==u].House.values[0]=="Slytherins" and df.loc[df['Name']==v].House.values[0]=="Slytherins":
        color.append('forestgreen')     
        width_egde.append(0.5)
    elif df.loc[df['Name']==u].House.values[0]=="Unknown" and df.loc[df['Name']==v].House.values[0]=="Unknown":
        color.append('yellow')     
        width_egde.append(0.5)
    
#     elif df.loc[df['Name']==u].House.values[0]=="Gryffindors" and df.loc[df['Name']==v].House.values[0]=="Slytherins" \
#         and d[df.loc[df['Name']==u].Name.values[0]]>60 and d[df.loc[df['Name']==v].Name.values[0]]>60 :
#         color.append('black')     
#         width_egde.append(1)
    else:
        color.append('whitesmoke')
        width_egde.append(0.1)
        
# # pos = nx.kamada_kawai_layout(GCC_ind)
pos_1 = nx.shell_layout(GCC_ind) #GOOD ONE ! 
pos_2 =nx.spring_layout(GCC_ind,k=9,iterations=115,pos=pos_1)

# %%
plt.figure(figsize=(16,10))

for house in set(df['House']):
    nx.draw_networkx_nodes(GCC_ind, pos=pos_2, nodelist=dict_nodes[house],node_size=dict_size[house],
                       node_color=dict_color[house], label=house)
    nx.draw_networkx_labels(GCC_ind, nodelist=dict_nodes[house],pos=pos_2,labels=dict_label[house], font_size=10,font_weight='bold')
    
nx.draw_networkx_edges(GCC_ind, pos=pos_2,edge_color=color,width=width_egde)

plt.legend()
plt.show()

# %%
from fa2 import ForceAtlas2
plt.figure(figsize=(16,10))
forceatlas2 = ForceAtlas2(
                        # Behavior alternatives
                        outboundAttractionDistribution=True,  # Dissuade hubs
                        linLogMode=False,  # NOT IMPLEMENTED
                        adjustSizes=False,  # Prevent overlap (NOT IMPLEMENTED)
                        edgeWeightInfluence=1,

                        # Performance
                        jitterTolerance=10,  # Tolerance
                        barnesHutOptimize=True,
#                         barnesHutTheta=1.2,
                        multiThreaded=False,  # NOT IMPLEMENTED

                        # Tuning
                        scalingRatio=15,
                        strongGravityMode=True,
                        gravity = 500,

                        # Log
                        verbose=True)

positions = forceatlas2.forceatlas2_networkx_layout(GCC_ind, pos=pos_2, iterations=500)

# F = ForceAtlas2()
# positions = F.forceatlas2_networkx_layout(GCC_ind, iterations=10000)
# positions = forceatlas2.forceatlas2_networkx_layout(GCC_ind, iterations=2000)


for house in set(df['House']):
    nx.draw_networkx_nodes(GCC_ind, pos=positions, nodelist=dict_nodes[house],node_size=dict_size[house],
                       node_color=dict_color[house], label=house)
    nx.draw_networkx_labels(GCC_ind, nodelist=dict_nodes[house],pos=positions,labels=dict_label[house], font_size=10,font_weight='bold')

    
nx.draw_networkx_edges(GCC_ind, pos=positions,edge_color=color,width=width_egde)

plt.axis('off')
plt.legend()
plt.show()
# Out:
# 100%|██████████| 500/500 [00:05<00:00, 88.65it/s]
# BarnesHut Approximation  took  0.68  seconds
# Repulsion forces  took  4.73  seconds
# Gravitational forces  took  0.00  seconds
# Attraction forces  took  0.03  seconds
# AdjustSpeedAndApplyForces step  took  0.11  seconds

# %% [markdown]
# ## Part 3: Communities and TF-IDF

# %%
from community import community_louvain
import networkx.algorithms.community as nx_comm

partition = community_louvain.best_partition(GCC_ind,random_state =41)
print('nb of Louvain partitions:', max(partition.values()))
reverse_partition= dict((k, []) for k in range(max(partition.values())+1))
# max(partition.values())
for keys, values in partition.items():
    reverse_partition[values].append(keys)

print('Louvain modularity:',nx_comm.modularity(GCC_ind,list(reverse_partition.values())))
# # Modularity

# # type_="House
dict_cal = {}
for type_calc in ['House','Gender']:
    test_list = list(nx.get_node_attributes(GCC_ind,type_calc).values())
    color_list, uniques_test = pd.factorize(test_list)
    dict_test=dict()
    for test_name in uniques_test:
        dict_test[test_name]=[x for x,y in GCC_ind.nodes(data=True) if y[type_calc]==test_name]
        
    dict_cal[type_calc]=dict_test
    print('{} modularity:'.format(type_calc),nx_comm.modularity(GCC_ind,list(dict_test.values())))
# Out:
# nb of Louvain partitions: 11
# Louvain modularity: 0.3134397254041703
# House modularity: 0.11265560089385748
# Gender modularity: 0.022275556870641578

# %%
size_communities={}
plt.figure(figsize=(12, 10))
for keys,values in reverse_partition.items():
    size_communities[keys] = len(values)
plt.bar(list(size_communities.keys()),list(size_communities.values()))
plt.title('Distribution of community sizes, created by the Louvain algorithm')
plt.xlabel('Community number')
plt.ylabel('Number of characters per communities')
plt.show()

# %%
community_partition=pd.DataFrame.from_records([partition]).transpose()
list_of_col=df.columns
list_of_col=list_of_col.insert(0, "Partition")
partition_def= community_partition.merge(df,how='inner',left_index=True,right_on='Name')
partition_def
partition_def.reset_index(drop=True, inplace= True)
partition_def.columns=list_of_col
partition_def
# Out:
#      Partition                        Name        House  Gender       Blood  \
# 0            9            Euan Abercrombie  Gryffindors    Male     Unknown
# 1            1             Filemina Alchin  Gryffindors  Female     Unknown
# 2            1               Astrix Alixan  Gryffindors    Male     Unknown
# 3            1            Angelina Appleby  Gryffindors  Female     Unknown
# 4            1             Oona Ballington  Gryffindors  Female     Unknown
# ..         ...                         ...          ...     ...         ...
# 506          4               Panju Weasley      Unknown    Male  Half-blood
# 507          4            Victoire Weasley      Unknown  Female     Unknown
# 508          5  William (Hogwarts student)      Unknown    Male  Pure-blood
# 509          9             Winston's niece      Unknown  Female     Unknown
# 510         11               Eldred Worple      Unknown    Male     Unknown
#
#     Species Nationality    Heigh   Weight     Hair     Eyes     Skin  \
# 0     Human      GBorIE  Unknown  Unknown  Unknown  Unknown  Unknown
# 1     Human      GBorIE  Unknown  Unknown  Unknown  Unknown  Unknown
# 2     Human      GBorIE  Unknown  Unknown  Unknown  Unknown  Unknown
# 3     Human      GBorIE  Unknown  Unknown  Unknown  Unknown  Unknown
# 4     Human      GBorIE  Unknown  Unknown  Unknown  Unknown  Unknown
# ..      ...         ...      ...      ...      ...      ...      ...
# 506   Human      GBorIE  Unknown  Unknown  Unknown  Unknown  Unknown
# 507   Human     Unknown  Unknown  Unknown   Blonde  Unknown    White
# 508   Human      GBorIE  Unknown  Unknown  Unknown  Unknown  Unknown
# 509   Human      GBorIE  Unknown  Unknown    Brown    Brown    White
# 510   Human      GBorIE    Short  Unknown  Unknown  Unknown  Unknown
#
#                                      Caracters_in_page
# 0                                       [Harry Potter]
# 1                    [Angelina Appleby, Astrix Alixan]
# 2                      [Filemina Alchin, Harry Potter]
# 3    [Angelina Johnson, Filemina Alchin, Oona Balli...
# 4                [Angelina Appleby, Concepta Battista]
# ..                                                 ...
# 506  [Padma Patil, Ronald Weasley, Scorpius Malfoy,...
# 507  [Lily L. Potter, Fred Weasley, Arthur Weasley,...
# 508        [Jacob (Hogwarts student), Jacob's sibling]
# 509                                     [Harry Potter]
# 510  [Horace Slughorn, Harry Potter, Hermione Granger]
#
# [511 rows x 13 columns]

# %% [markdown]
# ADD the description extract

# %%
# WITH A FOR LOOP
from nltk.corpus import stopwords

tk = WordPunctTokenizer()
names_list = [n.lower() for n in partition_def.Name]
stop_words = set(stopwords.words('english'))

lemmatizer = WordNetLemmatizer()

#Creation of a first_name list and last name columns
#Cleaning names with brackets: 
to_remove = []
list_of_names_clean=list(partition_def.Name)
for full_name in partition_def.Name:
    # REMOVE ALL THE NAMES WITH BRACKETS
    if '(' in full_name:
        to_remove.append(full_name)
        
for weird_name in to_remove:
    list_of_names_clean.remove(weird_name)
list_of_names_clean



all_names=[]
for name in list_of_names_clean:
    all_names.append(name.split())
all_names=sorted(set([item for sublist in all_names for item in sublist]))


# REMOVE ALL THE REAL WORDS FROM THE LIST OF NAMES
import enchant

d = enchant.Dict("en_US")
all_real_names=[]
for element in all_names:
    if element.lower() in ['potter','granger','harry','james','dumbledore','voldemort','sirius']:
        all_real_names.append(element.lower())
    elif d.check(element)==False:
        all_real_names.append(element.lower())
all_real_names.append('ron')
all_real_names=sorted(set(all_real_names))


def get_description_extract_clean(name,page_path = "Description_extract/"):
    with open(page_path+name+'.txt','r') as f:        
        # Remove whitespace characters
        node_description = f.read()

    # Put lower case
    node_description= node_description.lower()

    # Remove names
    for name in all_real_names:
        node_description=re.sub(name+'(?:s*)','', node_description)

    # Tokenize and remove stopwords
    node_description= tk.tokenize(node_description)
#     node_description= [lemmatizer.lemmatize(w) for w in node_description if (not w in stop_words) and (w.isalnum())]
    node_description= [lemmatizer.lemmatize(w) for w in node_description if (not w in stop_words) and (w.isalpha()) and len(w)>1]


    return node_description
    
    
description_extract= []
for name in partition_def.Name:
    description_extract.append(get_description_extract_clean(name))
    
partition_def['Description_extract']=description_extract

# %%
vocabulary=set(partition_def['Description_extract'].explode())

small_dfs =[]
for part_n in partition_def["Partition"].unique():
    all_partition_word = partition_def.loc[partition_def["Partition"]==part_n]['Description_extract'].explode()
    freq_table = dict.fromkeys(vocabulary,0)
    for word in all_partition_word:
        if word in vocabulary:
            freq_table[word] += 1/len(all_partition_word)
    small_dfs.append(pd.DataFrame.from_dict(freq_table, orient='index',columns=[part_n]))
tf_idf = pd.concat(small_dfs,axis=1)

tf = tf_idf.copy()
#IDF
prep_idf= np.where(tf_idf.to_numpy()>0, 1, 0)
_,N=prep_idf.shape
idf_=[]
for element in prep_idf:
    idf_.append(np.log(N/(1+sum(element))))

#TF-IDF
tf_idf['idf']=idf_
for columns in tf_idf.columns[:-1]:
    tf_idf[columns]=tf_idf[columns]*tf_idf['idf']
tf_idf.drop(columns='idf',inplace=True)
tf_idf = tf_idf.sort_index(axis=1)

# %%
#Get the top 5 partition
top_partition= list({k: v for k, v in sorted(size_communities.items(), key=lambda item: item[1],reverse=True)}.keys())[:5]
empty={}
for partition_number in top_partition:
#     print('partition_number:', partition_number)
    top_5_tf = tf[partition_number].sort_values(ascending=False)[:5].index
    top_5_tf_idf = tf_idf[partition_number].sort_values(ascending=False)[:5].index
    d = {'partition_{}: top 5 TF'.format(partition_number): top_5_tf, 'top 5 TF-IDF': top_5_tf_idf}
    print( pd.DataFrame(d))
#     empty[partition_number]=  pd.DataFrame(d).transpose()
# Out:
#   partition_9: top 5 TF top 5 TF-IDF
# 0             voldemort    voldemort
# 1              hogwarts        curse
# 2                   sol        death
# 3                  year    constance
# 4                 first        ginny
#   partition_5: top 5 TF top 5 TF-IDF
# 0                 jacob        jacob
# 1               sibling      sibling
# 2              hogwarts        penny
# 3                  year      barnaby
# 4                   sol     beatrice
#   partition_3: top 5 TF top 5 TF-IDF
# 0                  year        ginny
# 1              hogwarts      neville
# 2                  also       battle
# 3                 ginny         fred
# 4               neville    voldemort
#   partition_4: top 5 TF top 5 TF-IDF
# 0             voldemort    voldemort
# 1                 death        death
# 2              hogwarts        eater
# 3                  also        remus
# 4                family        draco
#   partition_11: top 5 TF top 5 TF-IDF
# 0               hogwarts         newt
# 1                   newt      theseus
# 2              voldemort    voldemort
# 3                   also         leta
# 4                  would  grindelwald

# %% [markdown]
# # SCRIPT HARRY POTTER

# %% [markdown]
# ## Harry potter sorcerer's stone

# %%
tk = WordPunctTokenizer()

#SOURCE https://scripts-onscreen.com/harry-potter-movie-scripts/
with open('script_sorcerer_stone.txt', encoding="utf8") as f:        
    # Remove whitespace characters
    node_description_row = f.read()
node_description= tk.tokenize(node_description_row)


node_description_transfo=node_description_row.replace('w/','with')
# node_description_transfo=node_description_transfo.replace('\n\n','\n\n--')
node_description_transfo=node_description_transfo.replace('  ','')
node_description_transfo=node_description_transfo.replace('\n \n','\n\n')
# node_description_row

with open('script_sorcerer_stone_clean_V3.txt', 'w') as f:
    f.write(node_description_transfo)
    
    
filename = 'script_sorcerer_stone_clean_V3.txt'
with open(filename) as file:
    lines = file.readlines()
    lines = [line.rstrip() for line in lines]
modified = [w if w!='' else ":-:" for w in lines]
new_string = ' '.join(modified).replace('  ',' ').replace(' -',"")
modified_bis=new_string.split(':-:')



modified_bis=[w[1:-1] for w in modified_bis if w!=' '][1:-1]
from collections import defaultdict

class DictList(dict):
    def __setitem__(self, key, value):
        try:
            # Assumes there is a list on the key
            self[key].append(value)
        except KeyError: # If it fails, because there is no key
            super(DictList, self).__setitem__(key, value)
        except AttributeError: # If it fails because it is not a list
            super(DictList, self).__setitem__(key, [self[key], value])
dl = DictList()
character = list(map(lambda index: modified_bis[index],filter(lambda x: x%2 == 0,range(len(modified_bis)))))
dialogue= list(map(lambda index: modified_bis[index],filter(lambda x: x%2 == 1,range(len(modified_bis)))))
zip_iterator = zip(character, dialogue)
for key,values in zip_iterator:
    dl[key]=values

# %%
# to_export_dialogue=' '.join(dialogue)
# with open('dialogue.txt', 'w') as f:
#     f.write(to_export_dialogue)

# %%
nb_dialogues={}
sorted(list(dl.keys()))
for k,v in dl.items():
    if type(v)==list:
        nb_dialogues[k]=len(v)
    else:
        nb_dialogues[k]=1
        
nb_dialogues = dict(sorted(nb_dialogues.items(), key=lambda item: item[1],reverse=True))        

fig =plt.figure(figsize=(16,10))
ax = fig.add_axes([0,0,1,1])
langs = list(nb_dialogues.keys())
students = list(nb_dialogues.values())
ax.bar(langs,students)
plt.xticks(rotation=90)
plt.show()

# %%
all_sentence = DictList()

for name in list(nb_dialogues.keys()):
    if len(dl[name]) ==1:
        all_sentence[name]=dl[name]
    else:
        for dialogue in dl[name]:
            pattern =r'(?<!\w\.\w.)(?<![A-Z][a-z]\.)(?<=\.|\?)\s'
            all_set = []
            for sentence in re.split(pattern, dialogue):
                all_sentence[name]=sentence

            
fig =plt.figure(figsize=(16,10))
ax = fig.add_axes([0,0,1,1])
langs = list(all_sentence.keys())
students = [len(w) for w in all_sentence.values()]
ax.bar(langs,students)
plt.xticks(rotation=90)
plt.show()

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
list_of_vader_sentiment={}
# init the sentiment analyzer
sia = SentimentIntensityAnalyzer()

for name in list(nb_dialogues.keys()):
    score_list=[]
    for sentence in all_sentence[name]:
        if len(sentence)>4:
            score_list.append(sia.polarity_scores(sentence)["compound"])
    if score_list==[]:
        list_of_vader_sentiment[name]=""
    else:
        list_of_vader_sentiment[name]=round(np.array(score_list).mean(),3)

# %%
LabMT = pd.read_csv('Data_Set_S1.txt', header=2, delim_whitespace=True)
lemmatizer = WordNetLemmatizer()
def vlookup(word,sentiment_dict=LabMT):
    try: 
        return sentiment_dict.loc[sentiment_dict.word==word]['happiness_average'].values[0]
    except:
        return 0
    
    
    
def happiness_by_LabMT(Character_name,sentiment_dict=LabMT):
    list_of_text = all_sentence[Character_name]
    concatenate_list=' '.join(list_of_text)
    tokenize_list= re.sub(r"[^\w\d'\s]+",'',concatenate_list).split(' ')
    tokenize_list_lower= map(str.lower, tokenize_list)

    clean_list = nltk.Text([lemmatizer.lemmatize(w) for w in tokenize_list_lower if w!=''])
    fdist1 =  dict(FreqDist(clean_list))
    my_dictionary = {vlookup(k): v for k, v in fdist1.items()}
    my_dictionary = {k: v for k, v in my_dictionary.items() if k!=0}
    sentement_values = np.array(list(my_dictionary.keys()))
    word_counter = np.array(list(my_dictionary.values()))

    return sentement_values@word_counter/word_counter.sum()

# %%
#Creation of the Sentiment by LabMT pickle, it takes quite long to run (5 minutes).

# sentiment_by_LabMT={}
# for Character_name in list(nb_dialogues.keys()):
#     sentiment_by_LabMT[Character_name]=happiness_by_LabMT(Character_name)


#         For storing

# with open(r"sentiment_by_LabMT.txt", "wb") as fp:   #Pickling
#     pickle.dump(sentiment_by_LabMT, fp)

# Loading of the pickle just created
with open(r"sentiment_by_LabMT.txt", "rb") as fp:   # Unpickling
    sentiment_by_LabMT = pickle.load(fp)

# %%
dict_to_consider = {k: [v] for k, v in sentiment_by_LabMT.items() if k in  list(nb_dialogues.keys())}
df_sentiment = pd.DataFrame.from_dict(dict_to_consider).transpose()

df_sentiment.reset_index(inplace=True)
df_sentiment.columns=['Name','LabMT']
df_sentiment.sort_values(by='LabMT',inplace=True,ascending=False)



fig, ax = plt.subplots(figsize=(15,10))

ax.hist(df_sentiment['LabMT'].values,bins=30, color="firebrick");
ax.set(ylabel='Nb of characters', xlabel='Sentiment Score');
ax.set_title('Sentiment Score with LabMT for the BoTW characters', fontsize=14)
ax.set_xlim([4, 7]);

# %% [markdown]
# # GRAPH WITH WEIGHT

# %% [markdown]
# ## Creation of the network

# %%
import pickle

# # # For storing

# with open(r"pickle_network_final.txt", "wb") as fp:   #Pickling
#     pickle.dump(df, fp)

# For loading

with open(r"pickle_network_final.txt", "rb") as fp:   # Unpickling
    df = pickle.load(fp)

df.head()
# Out:
#                 Name        House  Gender    Blood Species Nationality  \
# 0   Euan Abercrombie  Gryffindors    Male  Unknown   Human      GBorIE
# 4    Filemina Alchin  Gryffindors  Female  Unknown   Human      GBorIE
# 6      Astrix Alixan  Gryffindors    Male  Unknown   Human      GBorIE
# 10  Angelina Appleby  Gryffindors  Female  Unknown   Human      GBorIE
# 11   Oona Ballington  Gryffindors  Female  Unknown   Human      GBorIE
#
#       Heigh   Weight     Hair     Eyes     Skin  \
# 0   Unknown  Unknown  Unknown  Unknown  Unknown
# 4   Unknown  Unknown  Unknown  Unknown  Unknown
# 6   Unknown  Unknown  Unknown  Unknown  Unknown
# 10  Unknown  Unknown  Unknown  Unknown  Unknown
# 11  Unknown  Unknown  Unknown  Unknown  Unknown
#
#                                     Caracters_in_page
# 0                                      [Harry Potter]
# 4                   [Angelina Appleby, Astrix Alixan]
# 6                     [Filemina Alchin, Harry Potter]
# 10  [Angelina Johnson, Filemina Alchin, Oona Balli...
# 11              [Angelina Appleby, Concepta Battista]

# %%
from collections import Counter


name = 'Harry Potter'
page_path = "Description/"


# def normalize(d, target=1.0):
#     raw = sum(d.values())
#     factor = target/raw
#     return {key:value*factor for key,value in d.items()}


def characters_connections(name,page_path= "Description/"):
    with open(page_path+name+'.txt','r') as f:
        node_description= f.read()

    new_reg_link = r'\[\[(.*?)(?:\|.*?)?\]\]'

    caracters_in_page=[]
    linked_names_quick= re.findall(new_reg_link,node_description)
    for element in linked_names_quick:
        if element in list(df.Name) and element !=name:
            caracters_in_page.append(element)
    try:
#         final=normalize(Counter(caracters_in_page),target=1) 
        final=Counter(caracters_in_page)
    except:
        final ={}
    return final

# sorted(characters_connections('Harry Potter').items(), key=lambda x: x[1], reverse=True) 
from tqdm import tqdm
characters_connections_list={}
for name in tqdm(list(df['Name'])):
    characters_connections_list[name]=characters_connections(name)
df_weight =df.copy() 
df_weight.reset_index(inplace=True,drop=True)
df_weight['poids_lien']=list(characters_connections_list.values())
df_weight
# Out:
# 100%|██████████| 511/511 [00:12<00:00, 39.56it/s]
#                            Name        House  Gender       Blood Species  \
# 0              Euan Abercrombie  Gryffindors    Male     Unknown   Human
# 1               Filemina Alchin  Gryffindors  Female     Unknown   Human
# 2                 Astrix Alixan  Gryffindors    Male     Unknown   Human
# 3              Angelina Appleby  Gryffindors  Female     Unknown   Human
# 4               Oona Ballington  Gryffindors  Female     Unknown   Human
# ..                          ...          ...     ...         ...     ...
# 506               Panju Weasley      Unknown    Male  Half-blood   Human
# 507            Victoire Weasley      Unknown  Female     Unknown   Human
# 508  William (Hogwarts student)      Unknown    Male  Pure-blood   Human
# 509             Winston's niece      Unknown  Female     Unknown   Human
# 510               Eldred Worple      Unknown    Male     Unknown   Human
#
#     Nationality    Heigh   Weight     Hair     Eyes     Skin  \
# 0        GBorIE  Unknown  Unknown  Unknown  Unknown  Unknown
# 1        GBorIE  Unknown  Unknown  Unknown  Unknown  Unknown
# 2        GBorIE  Unknown  Unknown  Unknown  Unknown  Unknown
# 3        GBorIE  Unknown  Unknown  Unknown  Unknown  Unknown
# 4        GBorIE  Unknown  Unknown  Unknown  Unknown  Unknown
# ..          ...      ...      ...      ...      ...      ...
# 506      GBorIE  Unknown  Unknown  Unknown  Unknown  Unknown
# 507     Unknown  Unknown  Unknown   Blonde  Unknown    White
# 508      GBorIE  Unknown  Unknown  Unknown  Unknown  Unknown
# 509      GBorIE  Unknown  Unknown    Brown    Brown    White
# 510      GBorIE    Short  Unknown  Unknown  Unknown  Unknown
#
#                                      Caracters_in_page  \
# 0                                       [Harry Potter]
# 1                    [Angelina Appleby, Astrix Alixan]
# 2                      [Filemina Alchin, Harry Potter]
# 3    [Angelina Johnson, Filemina Alchin, Oona Balli...
# 4                [Angelina Appleby, Concepta Battista]
# ..                                                 ...
# 506  [Padma Patil, Ronald Weasley, Scorpius Malfoy,...
# 507  [Lily L. Potter, Fred Weasley, Arthur Weasley,...
# 508        [Jacob (Hogwarts student), Jacob's sibling]
# 509                                     [Harry Potter]
# 510  [Horace Slughorn, Harry Potter, Hermione Granger]
#
#                                             poids_lien
# 0                                  {'Harry Potter': 2}
# 1          {'Astrix Alixan': 1, 'Angelina Appleby': 1}
# 2            {'Harry Potter': 1, 'Filemina Alchin': 1}
# 3    {'Angelina Johnson': 1, 'Filemina Alchin': 1, ...
# 4      {'Angelina Appleby': 1, 'Concepta Battista': 1}
# ..                                                 ...
# 506  {'Ronald Weasley': 3, 'Padma Patil': 3, 'Parva...
# 507  {'William Weasley': 3, 'Charles Weasley': 1, '...
# 508  {'Jacob (Hogwarts student)': 1, 'Jacob's sibli...
# 509                                {'Harry Potter': 1}
# 510  {'Horace Slughorn': 4, 'Harry Potter': 3, 'Her...
#
# [511 rows x 13 columns]

# %%
G_weight = nx.DiGraph()
for index, row in df_weight.iterrows():
    G_weight.add_node(row['Name'], House=row['House'], Gender=row['Gender'],Blood=row['Blood'],Species=row['Species'] \
                          , Nationality=row['Nationality'], Heigh=row['Heigh'],Weight=row['Weight'],Eyes=row['Eyes'] \
                          ,Skin=row['Skin'])
G_weight.nodes()
    
keys_=df_weight['Name'].values
values_=df_weight['poids_lien'].values
dictionary_poids_lien= dict(zip(keys_, values_))

weigh_list=[]
for name,mini_dict in dictionary_poids_lien.items():
    for keys,weight_values in mini_dict.items():
            G_weight.add_edge(name,keys,weight =weight_values)
            weigh_list.append(weight_values)

# %% [markdown]
# ## Louvain communities

# %%
from community import community_louvain
import networkx.algorithms.community as nx_comm


G_weight_ind= G_weight.to_undirected()

partition = community_louvain.best_partition(G_weight_ind,weight='lol',random_state=14)
print('Nb of communities:',max(partition.values()) + 1)
# Out:
# Nb of communities: 11

# %%
reverse_partition= dict((k, []) for k in range(max(partition.values())+1))
# max(partition.values())
for keys, values in partition.items():
    reverse_partition[values].append(keys)

#     df_weight
    
# # type_="House
dict_cal = {}
for type_calc in ['House','Gender']:
    test_list = list(nx.get_node_attributes(G_weight_ind,type_calc).values())
    color_list, uniques_test = pd.factorize(test_list)
    dict_test=dict()
    for test_name in uniques_test:
        dict_test[test_name]=[x for x,y in G_weight_ind.nodes(data=True) if y[type_calc]==test_name]
        
    dict_cal[type_calc]=dict_test
    print('{} modularity:'.format(type_calc),nx_comm.modularity(G_weight_ind,list(dict_test.values())))

print('Louvain modularity:',nx_comm.modularity(G_weight_ind,list(reverse_partition.values())))
# Out:
# House modularity: 0.10789981212208032
# Gender modularity: 0.018156954889623364
# Louvain modularity: 0.2703309826976175

# %%
size_communities={}
plt.figure(figsize=(12, 10))
for keys,values in reverse_partition.items():
    size_communities[keys] = len(values)
plt.bar(list(size_communities.keys()),list(size_communities.values()))
plt.title('Distribution of community sizes, created by the Louvain algorithm')
plt.xlabel('Community number')
plt.ylabel('Number of characters per communities')
plt.show()

# %%
community_partition=pd.DataFrame.from_records([partition]).transpose()
list_of_col=df_weight.columns
list_of_col=list_of_col.insert(0, "Partition")
partition_def= community_partition.merge(df_weight,how='inner',left_index=True,right_on='Name')
partition_def
partition_def.reset_index(drop=True, inplace= True)
partition_def.columns=list_of_col
partition_def.head()
# Out:
#    Partition              Name        House  Gender    Blood Species  \
# 0          0  Euan Abercrombie  Gryffindors    Male  Unknown   Human
# 1          1   Filemina Alchin  Gryffindors  Female  Unknown   Human
# 2          1     Astrix Alixan  Gryffindors    Male  Unknown   Human
# 3          1  Angelina Appleby  Gryffindors  Female  Unknown   Human
# 4          1   Oona Ballington  Gryffindors  Female  Unknown   Human
#
#   Nationality    Heigh   Weight     Hair     Eyes     Skin  \
# 0      GBorIE  Unknown  Unknown  Unknown  Unknown  Unknown
# 1      GBorIE  Unknown  Unknown  Unknown  Unknown  Unknown
# 2      GBorIE  Unknown  Unknown  Unknown  Unknown  Unknown
# 3      GBorIE  Unknown  Unknown  Unknown  Unknown  Unknown
# 4      GBorIE  Unknown  Unknown  Unknown  Unknown  Unknown
#
#                                    Caracters_in_page  \
# 0                                     [Harry Potter]
# 1                  [Angelina Appleby, Astrix Alixan]
# 2                    [Filemina Alchin, Harry Potter]
# 3  [Angelina Johnson, Filemina Alchin, Oona Balli...
# 4              [Angelina Appleby, Concepta Battista]
#
#                                           poids_lien  all_degree
# 0                                {'Harry Potter': 2}           1
# 1        {'Astrix Alixan': 1, 'Angelina Appleby': 1}           4
# 2          {'Harry Potter': 1, 'Filemina Alchin': 1}           3
# 3  {'Angelina Johnson': 1, 'Filemina Alchin': 1, ...           6
# 4    {'Angelina Appleby': 1, 'Concepta Battista': 1}           4

# %%
import pickle

# # For storing

with open(r"network_weighted_with_commu.txt", "wb") as fp:   #Pickling
    pickle.dump(partition_def, fp)

# # For loading

# with open(r"network_weighted_with_commu.txt", "rb") as fp:   # Unpickling
#     partition_def = pickle.load(fp)

# df.head()

# %%
pos = nx.spring_layout(G_weight)
 # color the nodes according to their partition
cmap = plt.cm.get_cmap('viridis', max(partition.values()) + 1)
nx.draw_networkx_nodes(G_weight, pos, partition.keys(), node_size=40, 
                       cmap=cmap, node_color=list(partition.values()))
nx.draw_networkx_edges(G_weight, pos, alpha=0.5)
plt.show()

# %%
#GENERATION OF A DENDRODRAM
# from community import generate_dendrogram,partition_at_level

# dendo = generate_dendrogram(G_weight_ind)
# for level in range(len(dendo) - 1) :
#     print("partition at level", level,"is", partition_at_level(dendo, level))

# %% [markdown]
# # Node to vector

# %%
import multiprocessing
from node2vec import Node2Vec
from stellargraph.data import BiasedRandomWalk
from stellargraph import StellarGraph
cores = multiprocessing.cpu_count() # Count the number of cores in a computer

# %% [markdown]
# ## Creation of the sampling

# %%
df_weight['all_degree']=np.array([G_weight.degree(n) for n in G_weight.nodes()])

def top_x_names_by_all_degree(top=20):
    return list(df_weight.sort_values(by='all_degree',ascending=False)['Name'][:top].values)

def generate_walk(graph #graph: Input graph
                  ,node="" # root nodes for the walk
                  ,walk_length=30 #walk_length: Number of nodes in each walk (default: 30)
                  , num_walks=10 #num_walks: Number of walks per node (default: 10)
#                    , worker=cores #workers: Number of workers for parallel execution (default: 1)
                  , p = 1 #p: Return hyper parameter (default: 1)
                  , q = 1 #q: Inout parameter (default: 1)):
                  , weighted=True # if edge has weight
                  ,  seed=42 # random seed fixed for reproducibility
                     ):
    if node =="":
        node= graph.nodes()
    
    rw = BiasedRandomWalk(StellarGraph.from_networkx(G_weight,edge_weight_attr='weight'))
    
    return rw.run(
        nodes=node,  # root nodes
        length=walk_length,  # maximum length of a random walk
        n=num_walks,  # number of random walks per root node
        p=2,  # Defines (unormalised) probability, 1/p, of returning to source node
        q=0.5,  # Defines (unormalised) probability, 1/q, for moving away from source node
        weighted=weighted,  # for  random walks
        seed=seed,  # random seed fixed for reproducibility
    )

# %%
mean_weith = np.array(weigh_list).mean()
# print(mean_weith)

walks=generate_walk(G_weight #graph: Input graph
                  ,node=top_x_names_by_all_degree(30)
                  ,walk_length=25
                  , num_walks=40
#                   , worker=cores #workers: Number of workers for parallel execution (default: 1)
                  , p = 1  # Defines (unormalised) probability, 1/p, of returning to source node
                  , q = 1 # Defines (unormalised) probability, 1/q, for moving away from source node
                  , weighted=True
                   ,  seed=42)
print('{} Walks Generated for a total of {} nodes'.format(len(walks),len(walks)*40))
# Out:
# 1200 Walks Generated for a total of 48000 nodes

# %%
# class DictList(dict):
#     def __setitem__(self, key, value):
#         try:
#             # Assumes there is a list on the key
#             self[key].append(value)
#         except KeyError: # If it fails, because there is no key
#             super(DictList, self).__setitem__(key, value)
#         except AttributeError: # If it fails because it is not a list
#             super(DictList, self).__setitem__(key, [self[key], value])
# dl_sampling = DictList()

# walks_bis=walks[:]
# character = [element[0] for element in walks_bis]
# zip_iterator = zip(character, walks_bis)
# for key,values in zip_iterator:
#     dl_sampling[key]=values
# dl_sampling['Harry Potter']
# Out:
# ['Harry Potter',
#  'Nandini Johar',
#  ['Harry Potter',
#   'Lily L. Potter',
#   'Hermione Granger',
#   'Helena Ravenclaw',
#   'Bloody Baron',
#   'Harry Potter',
#   'Nicholas de Mimsy-Porpington',
#   'Angelica Cole',
#   'Charles Weasley',
#   'Oliver Wood'],
#  ['Harry Potter',
#   'Ginevra Weasley',
#   'Amycus Carrow',
#   'Grim Fawley',
#   'Sage Bragnam',
#   'Mathilda Grimblehawk',
#   'Abraham Grimblehawk',
#   'Newton Scamander',
#   'Theseus Scamander',
#   'Leta Lestrange'],
#  ['Harry Potter',
#   'Sybill Trelawney',
#   'Ronald Weasley',
#   'Gwenog Jones',
#   'Horace Slughorn',
#   'Tom Riddle',
#   'Dean Thomas',
#   'Ronald Weasley',
#   'Molly Weasley',
#   'Andromeda Tonks'],
#  ['Harry Potter',
#   'Tom Riddle',
#   'Ginevra Weasley',
#   'James Potter II',
#   'Hermione Granger',
#   'Hannah Abbott',
#   'Neville Longbottom',
#   'Bellatrix Lestrange',
#   'Tom Riddle',
#   'Albus Dumbledore'],
#  ['Harry Potter',
#   'Rubeus Hagrid',
#   'Remus Lupin',
#   'Filius Flitwick',
#   'Wilfred Levi Kidd',
#   'William Weasley',
#   'Ronald Weasley',
#   'Ginevra Weasley',
#   'Tom Riddle',
#   'Ernest Prang'],
#  ['Harry Potter',
#   'Neville Longbottom',
#   'Draco Malfoy',
#   'Hermione Granger',
#   'Trio',
#   'Luna Lovegood',
#   'Lily L. Potter',
#   'Charles Weasley',
#   'Oliver Wood',
#   'Marcus Flint'],
#  ['Harry Potter',
#   'Rubeus Hagrid',
#   'Horace Slughorn',
#   'Dirk Cresswell',
#   'Lee Jordan',
#   'Lucius Malfoy',
#   'Cygnus Black III',
#   'Phineas Nigellus Black',
#   'Draco Malfoy',
#   'Minerva McGonagall'],
#  ['Harry Potter',
#   'Tom Riddle',
#   'Myrtle Warren',
#   'Olive Hornby',
#   'Armando Dippet',
#   'Albus Dumbledore',
#   'Zacharias Smith',
#   'Minerva McGonagall',
#   'Rubeus Hagrid',
#   'Ronald Weasley'],
#  ['Harry Potter', 'Xander Lofthouse', 'Lina Tande', 'Sujita Tande'],
#  ['Harry Potter',
#   'Albus Dumbledore',
#   "Jacob's sibling",
#   'Ben Copper',
#   'Uric the Oddball',
#   'Robert Hilliard',
#   'Marcus Turner',
#   'Darrel Turner'],
#  ['Harry Potter',
#   'Albus Dumbledore',
#   'Mundungus Fletcher',
#   'Tom Riddle',
#   'Hannah Abbott',
#   'Ernest Macmillan',
#   'Colin Creevey',
#   'Oliver Wood',
#   'Sirius Black',
#   'Bellatrix Lestrange'],
#  ['Harry Potter',
#   'Ronald Weasley',
#   'Remus Lupin',
#   'Harry Potter',
#   'Tom Riddle',
#   'Hannah Abbott',
#   'Katie Bell',
#   'Angelina Johnson',
#   'Tom Riddle',
#   'Kingsley Shacklebolt'],
#  ['Harry Potter',
#   'Marauders',
#   'James Potter I',
#   'Peter Pettigrew',
#   'Garrick Ollivander',
#   'Severus Snape',
#   'Cornelius Fudge',
#   'Bellatrix Lestrange',
#   'Andromeda Tonks',
#   'Cassiopeia Black'],
#  ['Harry Potter',
#   'Cornelius Fudge',
#   'Albus Dumbledore',
#   'Sirius Black',
#   'Wilkes',
#   'Evan Rosier',
#   'Alastor Moody',
#   'Albus Dumbledore',
#   'Albus Potter',
#   'James Potter I'],
#  ['Harry Potter',
#   'Jacob (Hogwarts student)',
#   "Jacob's sibling",
#   'Percy Weasley',
#   'William Weasley',
#   'Nymphadora Tonks',
#   'Bellatrix Lestrange',
#   'Nicholas de Mimsy-Porpington',
#   'Harry Potter',
#   'Albus Dumbledore'],
#  ['Harry Potter',
#   'Sue Li',
#   'Padma Patil',
#   'Anthony Goldstein',
#   'Dean Thomas',
#   'Padma Patil',
#   'Panju Weasley',
#   'James Potter II',
#   'George Weasley',
#   'Tom Riddle'],
#  ['Harry Potter', 'Hortense Cooper'],
#  ['Harry Potter',
#   'Cho Chang',
#   'Luna Lovegood',
#   'Rubeus Hagrid',
#   "Jacob's sibling",
#   'Severus Snape',
#   'Amycus Carrow',
#   'Neville Longbottom',
#   'Severus Snape',
#   'Gregory Goyle'],
#  ['Harry Potter', 'Anna Mirfield'],
#  ['Harry Potter',
#   'Fred Weasley',
#   'Charles Weasley',
#   'Rose Granger-Weasley',
#   'Hermione Granger',
#   'Eloise Midgen',
#   'Padma Patil',
#   'Katie Bell',
#   "Rionach O'Neal",
#   'Cho Chang'],
#  ['Harry Potter',
#   'Pomona Sprout',
#   'Neville Longbottom',
#   'Severus Snape',
#   'Bartemius Crouch Junior',
#   'Harry Potter',
#   'Charles Weasley',
#   'Albus Dumbledore',
#   'Armando Dippet',
#   'Tom Riddle'],
#  ['Harry Potter',
#   'Dean Thomas',
#   'Cedric Diggory',
#   'Diego Caplan',
#   "Jacob's sibling",
#   'William Weasley',
#   'Molly Weasley',
#   'Remus Lupin',
#   'Hermione Granger',
#   'Phineas Nigellus Black'],
#  ['Harry Potter',
#   'George Weasley',
#   'Remus Lupin',
#   'Lucius Malfoy',
#   'Draco Malfoy',
#   'Alecto Carrow',
#   'Hestia Carrow',
#   'Amycus Carrow',
#   'Ronald Weasley',
#   'Draco Malfoy'],
#  ['Harry Potter',
#   'Albus Potter',
#   'Panju Weasley',
#   'Padma Patil',
#   'Anthony Goldstein',
#   'Lee Jordan',
#   'Minerva McGonagall',
#   'Harry Potter',
#   'Alastor Moody',
#   'Ronald Weasley'],
#  ['Harry Potter',
#   'Severus Snape',
#   'Ronald Weasley',
#   'Head of Slytherin House',
#   'Horace Slughorn',
#   'Minerva McGonagall',
#   'Percy Weasley',
#   'Hermione Granger',
#   'Gilderoy Lockhart',
#   'Cecil Lee'],
#  ['Harry Potter',
#   'Tom Riddle',
#   'Amycus Carrow',
#   'Draco Malfoy',
#   'Tom Riddle',
#   'Sirius Black',
#   'Arthur Weasley',
#   'Tom Riddle',
#   'Helena Ravenclaw',
#   'Kingsley Shacklebolt'],
#  ['Harry Potter',
#   'Ronald Weasley',
#   'Sirius Black',
#   'Leta Lestrange',
#   'Rodolphus Lestrange',
#   'Albus Potter',
#   'Severus Snape',
#   'Lily J. Potter',
#   'Remus Lupin',
#   'Arthur Weasley'],
#  ['Harry Potter',
#   'Zacharias Smith',
#   'Ronald Weasley',
#   'Filius Flitwick',
#   'Severus Snape',
#   'Ernest Macmillan',
#   'Pippa Macmillan',
#   'Chiara Lobosca',
#   'Victor Ketsueki',
#   "Jacob's sibling"],
#  ['Harry Potter',
#   'Pomona Sprout',
#   'Sybill Trelawney',
#   'Luna Lovegood',
#   'Bellatrix Lestrange',
#   'Ginevra Weasley',
#   'Neville Longbottom',
#   'Godric Gryffindor',
#   'Rowena Ravenclaw',
#   'Helena Ravenclaw'],
#  ['Harry Potter',
#   'Sally-Anne Perks',
#   'Hannah Abbott',
#   'Justin Finch-Fletchley',
#   'Harry Potter',
#   'Dennis Creevey',
#   'Colin Creevey',
#   'Pomona Sprout',
#   "Jacob's sibling",
#   'Rubeus Hagrid'],
#  ['Harry Potter',
#   'Tom Riddle',
#   'Quirinus Quirrell',
#   'Oliver Rivers',
#   'Harry Potter',
#   'Minerva McGonagall',
#   'Severus Snape',
#   'Filius Flitwick',
#   'Amycus Carrow',
#   'Tom Riddle'],
#  ['Harry Potter',
#   'Albus Potter',
#   'Scorpius Malfoy',
#   'Myrtle Warren',
#   'Alastor Moody',
#   'Albus Dumbledore',
#   'Armando Dippet',
#   'Silvanus Kettleburn',
#   'Barnaby Lee',
#   'William Weasley'],
#  ['Harry Potter',
#   'Remus Lupin',
#   'Marauders',
#   'George Weasley',
#   'Fred Weasley',
#   "Jacob's sibling",
#   'Ismelda Murk',
#   'Merula Snyde',
#   'Tulip Karasu',
#   "Jacob's sibling"],
#  ['Harry Potter',
#   'Molly Weasley',
#   'Neville Longbottom',
#   'Alastor Moody',
#   'Bartemius Crouch Junior',
#   'Albus Dumbledore',
#   'Harry Potter',
#   'Scorpius Malfoy',
#   'Draco Malfoy',
#   'Yann Fredericks'],
#  ['Harry Potter',
#   'Lily J. Potter',
#   'Gang of Slytherins',
#   'Evan Rosier',
#   'Alastor Moody',
#   'Bartemius Crouch Junior',
#   'Peter Pettigrew',
#   'Garrick Ollivander',
#   'Neville Longbottom',
#   'Augusta Longbottom'],
#  ['Harry Potter',
#   'Lee Jordan',
#   'Dirk Cresswell',
#   'Remus Lupin',
#   'Peter Pettigrew',
#   'Hermione Granger',
#   'Fat Lady',
#   'Sirius Black',
#   'Peter Pettigrew',
#   'Mundungus Fletcher'],
#  ['Harry Potter',
#   'Phineas Nigellus Black',
#   'Albus Dumbledore',
#   'John Dawlish',
#   'Helen Dawlish',
#   'Shoma Ichikawa',
#   'Harry Potter',
#   'Albus Dumbledore',
#   'Aberforth Dumbledore',
#   'Tom Riddle'],
#  ['Harry Potter',
#   'Albus Dumbledore',
#   'Millicent Bagnold',
#   'Tom Riddle',
#   'Regulus Black',
#   'Dorea Black',
#   'Alphard Black',
#   'Andromeda Tonks',
#   'Sirius Black',
#   'Severus Snape'],
#  ['Harry Potter',
#   'Severus Snape',
#   'Draco Malfoy',
#   'Remus Lupin',
#   'Fred Weasley',
#   'Draco Malfoy',
#   'Lucius Malfoy',
#   'Remus Lupin',
#   'Alastor Moody',
#   "Jacob's sibling"],
#  ['Harry Potter',
#   'Hermione Granger',
#   'Sirius Black',
#   'Remus Lupin',
#   'James Potter I',
#   'Fleamont Potter',
#   'Abraxas Malfoy',
#   'Narcissa Malfoy',
#   'Albus Dumbledore',
#   'Seamus Finnigan'],
#  ['Harry Potter',
#   'Justin Finch-Fletchley',
#   'Ernest Macmillan',
#   'Alecto Carrow',
#   'Amycus Carrow',
#   'Severus Snape',
#   'Harry Potter',
#   'Bartemius Crouch Junior',
#   'Ronald Weasley',
#   'Harry Potter'],
#  ['Harry Potter',
#   'Zacharias Smith',
#   'Harper',
#   'Draco Malfoy',
#   'Filius Flitwick',
#   'Sirius Black',
#   'Head of Slytherin House',
#   'Head of Hufflepuff House',
#   'Pomona Sprout',
#   'Draco Malfoy'],
#  ['Harry Potter',
#   'Bartemius Crouch Junior',
#   'Alastor Moody',
#   'Albus Dumbledore',
#   'James Potter I',
#   'Ginevra Weasley',
#   'Zacharias Smith',
#   'Fred Weasley',
#   'William Weasley',
#   'Alastor Moody'],
#  ['Harry Potter',
#   'Tom Riddle',
#   'John Dawlish',
#   'Dirk Cresswell',
#   'Remus Lupin',
#   'Bellatrix Lestrange',
#   'Alastor Moody',
#   'Bartemius Crouch Junior',
#   'Tom Riddle',
#   'Remus Lupin'],
#  ['Harry Potter',
#   'William Weasley',
#   'Nymphadora Tonks',
#   'Rodolphus Lestrange',
#   'Tom Riddle',
#   'Quirinus Quirrell',
#   'Raymond',
#   'Harry Potter',
#   'Marauders',
#   'Remus Lupin'],
#  ['Harry Potter',
#   'Draco Malfoy',
#   'Abraxas Malfoy',
#   'Lucius Malfoy',
#   'Severus Snape',
#   'Helena Ravenclaw',
#   'Harry Potter',
#   'Rubeus Hagrid',
#   'Tom Riddle',
#   'Alicia Spinnet'],
#  ['Harry Potter',
#   'Rubeus Hagrid',
#   'Cornelius Fudge',
#   'Marietta Edgecombe',
#   'Cho Chang',
#   'Draco Malfoy',
#   'Bellatrix Lestrange',
#   'Tom Riddle',
#   'Horace Slughorn',
#   'Severus Snape'],
#  ['Harry Potter',
#   'Aberforth Dumbledore',
#   'Hermione Granger',
#   'Luna Lovegood',
#   'Sybill Trelawney',
#   'Ronald Weasley',
#   'Hermione Granger',
#   'Albus Dumbledore',
#   'Silvanus Kettleburn',
#   "Jacob's sibling"],
#  ['Harry Potter',
#   'James Potter I',
#   'Fleamont Potter',
#   'Lily J. Potter',
#   'Garrick Ollivander',
#   "Jacob's sibling",
#   'George Weasley',
#   'Cedrella Black',
#   'Andromeda Tonks',
#   'Regulus Black'],
#  ['Harry Potter',
#   'Tom Riddle',
#   'Narcissa Malfoy',
#   'Quirinus Quirrell',
#   'Harry Potter',
#   'Elphias Doge',
#   'Albus Dumbledore',
#   'Terry Boot',
#   'Michael Corner',
#   'Alicia Spinnet'],
#  ['Harry Potter',
#   'Sybill Trelawney',
#   'Severus Snape',
#   "Jacob's sibling",
#   'Cedric Diggory',
#   'Garrick Ollivander',
#   'Jacob (Hogwarts student)',
#   "Jacob's sibling",
#   'Jae Kim',
#   'Merula Snyde'],
#  ['Harry Potter',
#   'Roderick Seaton',
#   'Horace Slughorn',
#   'Pansy Parkinson',
#   'Hermione Granger',
#   'Molly Weasley',
#   'Severus Snape',
#   'Hannah Abbott',
#   'Neville Longbottom',
#   'Lavender Brown'],
#  ['Harry Potter',
#   'Rubeus Hagrid',
#   'Dolores Umbridge',
#   'Dennis Creevey',
#   'Harry Potter',
#   'Remus Lupin',
#   'Peter Pettigrew',
#   'Tom Riddle',
#   'Harry Potter',
#   'Demelza Robins'],
#  ['Harry Potter',
#   'Alicia Spinnet',
#   'Draco Malfoy',
#   'Lucius Malfoy',
#   'Scorpius Malfoy',
#   'Yann Fredericks',
#   'Hermione Granger',
#   'Albus Dumbledore',
#   'Cedric Diggory',
#   'Nigel Wolpert'],
#  ['Harry Potter',
#   'Bellatrix Lestrange',
#   'Sirius Black',
#   'Evan Rosier',
#   'Bellatrix Lestrange',
#   'Narcissa Malfoy',
#   'Severus Snape',
#   'Eileen Prince',
#   'Hermione Granger',
#   'Ernest Macmillan'],
#  ['Harry Potter',
#   'Sirius Black',
#   'Narcissa Malfoy',
#   'Tom Riddle',
#   'Ismelda Murk',
#   "Jacob's sibling",
#   'Alastor Moody',
#   'Cedric Diggory',
#   'Neville Longbottom',
#   'Bellatrix Lestrange'],
#  ['Harry Potter',
#   'Sybill Trelawney',
#   'Lavender Brown',
#   'Harry Potter',
#   'Xenophilius Lovegood',
#   'Barnaby Lee',
#   'Jae Kim',
#   'Merula Snyde',
#   'Ronald Weasley',
#   'Cho Chang'],
#  ['Harry Potter',
#   'Ginevra Weasley',
#   'Cornelius Fudge',
#   'Rubeus Hagrid',
#   'Silvanus Kettleburn',
#   'George Weasley',
#   'Kingsley Shacklebolt',
#   'Albus Dumbledore',
#   'Nicholas de Mimsy-Porpington',
#   'Amycus Carrow'],
#  ['Harry Potter',
#   'William Weasley',
#   "Jacob's sibling",
#   'Cecil Lee',
#   'Barnaby Lee',
#   'Tom Riddle',
#   'Lucius Malfoy',
#   'Narcissa Malfoy',
#   'Andromeda Tonks',
#   'Molly Weasley'],
#  ['Harry Potter',
#   'Ronald Weasley',
#   'Albus Dumbledore',
#   'Stebbins (1990s Hogwarts student)',
#   'Stebbins (1970s Hogwarts student)',
#   'Filius Flitwick',
#   'Barnaby Lee',
#   'Tulip Karasu',
#   "Jacob's sibling",
#   'Rubeus Hagrid'],
#  ['Harry Potter',
#   'Peter Pettigrew',
#   'Patricia Rakepick',
#   "Jacob's sibling",
#   'Cornelius Fudge',
#   'Harry Potter',
#   'Lee Jordan',
#   'Colin Creevey',
#   'Draco Malfoy',
#   'Lucius Malfoy'],
#  ['Harry Potter',
#   'Rubeus Hagrid',
#   'Neville Longbottom',
#   'Horace Slughorn',
#   'Tom Riddle',
#   'Narcissa Malfoy',
#   'Rodolphus Lestrange',
#   'Lucius Malfoy',
#   'Tom Riddle',
#   'William Weasley'],
#  ['Harry Potter',
#   'Cho Chang',
#   'Dean Thomas',
#   'Ginevra Weasley',
#   'Harper',
#   'Ronald Weasley',
#   'Jimmy Peakes',
#   'Hermione Granger',
#   'Narcissa Malfoy',
#   'Draco Malfoy'],
#  ['Harry Potter',
#   'Draco Malfoy',
#   'Ronald Weasley',
#   'William Weasley',
#   'Xenophilius Lovegood',
#   "Jacob's sibling",
#   'Diego Caplan',
#   'Ismelda Murk',
#   'Jae Kim',
#   "Jacob's sibling"],
#  ['Harry Potter',
#   'Edward Lupin',
#   'Phineas Nigellus Black',
#   'Callidora Black',
#   'Dorea Black',
#   'Harry Potter',
#   'Ronald Weasley',
#   'Luna Lovegood',
#   'Bellatrix Lestrange',
#   'Harry Potter'],
#  ['Harry Potter',
#   'Sirius Black',
#   'Cygnus Black III',
#   'Walburga Black',
#   'Peter Pettigrew',
#   'Fred Weasley',
#   'Lee Jordan',
#   'Parvati Patil',
#   'Ginevra Weasley',
#   'Ronald Weasley'],
#  ['Harry Potter',
#   'Minerva McGonagall',
#   'Albus Dumbledore',
#   'Cornelius Fudge',
#   'Peter Pettigrew',
#   'Lily J. Potter',
#   'Ginevra Weasley',
#   'Albus Potter',
#   'Theodore Nott',
#   'Nott'],
#  ['Harry Potter',
#   'Lily Moon',
#   'Luna Lovegood',
#   'Ginevra Weasley',
#   'Michael Corner',
#   'Dolores Umbridge',
#   'Severus Snape',
#   "Jacob's sibling",
#   'Liz Tuttle',
#   'Penny Haywood'],
#  ['Harry Potter',
#   'Ginevra Weasley',
#   'Andrew Kirke',
#   'Cedric Diggory',
#   'Pomona Sprout',
#   'Alastor Moody',
#   'Arthur Weasley',
#   'William Weasley',
#   'Percy Weasley',
#   'Albus Potter'],
#  ['Harry Potter',
#   'Hestia Carrow',
#   'Amycus Carrow',
#   'Harry Potter',
#   'Remus Lupin',
#   'Neville Longbottom',
#   'Augusta Longbottom',
#   'Albus Dumbledore',
#   'Leta Lestrange',
#   'Newton Scamander'],
#  ['Harry Potter',
#   'Helena Ravenclaw',
#   'Hermione Granger',
#   'Augusta Longbottom',
#   'Ginevra Weasley',
#   'Luna Lovegood',
#   'Albus Potter',
#   'Tom Riddle',
#   'Pomona Sprout',
#   'Ronald Weasley'],
#  ['Harry Potter',
#   'Minerva McGonagall',
#   'Hermione Granger',
#   'Harry Potter',
#   'Lily J. Potter',
#   'Severus Snape',
#   'Grim Fawley',
#   'Sage Bragnam',
#   "Mathilda Grimblehawk's partner",
#   'Mathilda Grimblehawk'],
#  ['Harry Potter',
#   'Cho Chang',
#   'Romilda Vane',
#   'Ronald Weasley',
#   'Victoire Weasley',
#   'James Potter II',
#   'Lily L. Potter',
#   'Victoire Weasley',
#   'George Weasley',
#   'Alicia Spinnet'],
#  ['Harry Potter',
#   'George Weasley',
#   'Peter Pettigrew',
#   'Patricia Rakepick',
#   'Minerva McGonagall',
#   'Lee Jordan',
#   'Rubeus Hagrid',
#   'Fred Weasley',
#   'Hermione Granger',
#   'Harry Potter'],
#  ['Harry Potter',
#   'William Weasley',
#   'Lucretia Black',
#   'Sirius Black',
#   'Peter Pettigrew',
#   'Ronald Weasley',
#   'Rose Granger-Weasley',
#   'Lily J. Potter',
#   'Harry Potter',
#   'Ronald Weasley'],
#  ['Harry Potter',
#   'Rubeus Hagrid',
#   'Charles Weasley',
#   'Arthur Weasley',
#   'Tom Riddle',
#   'Penelope Fawley',
#   'Grim Fawley',
#   'Sage Bragnam',
#   "Mathilda Grimblehawk's partner",
#   'Mathilda Grimblehawk'],
#  ['Harry Potter',
#   'Draco Malfoy',
#   'Theodore Nott',
#   'Dean Thomas',
#   'Narcissa Malfoy',
#   'Scorpius Malfoy',
#   'Sirius Black',
#   'Cornelius Fudge',
#   'Bartemius Crouch Junior',
#   'Bellatrix Lestrange'],
#  ['Harry Potter',
#   'Aberforth Dumbledore',
#   'Tom Riddle',
#   'Helena Ravenclaw',
#   "Jacob's sibling",
#   'Barnaby Lee',
#   'Ismelda Murk',
#   "Jacob's sibling",
#   'William Weasley',
#   'Ronald Weasley'],
#  ['Harry Potter',
#   'Charles Weasley',
#   'Percy Weasley',
#   'Arthur Weasley',
#   'Lucius Malfoy',
#   'Ronald Weasley',
#   'Panju Weasley',
#   'Scorpius Malfoy',
#   'Cedric Diggory',
#   'Nigel Wolpert'],
#  ['Harry Potter',
#   'Romilda Vane',
#   'Amycus Carrow',
#   'Minerva McGonagall',
#   'Ben Copper',
#   'Patricia Rakepick',
#   'Jacob (Hogwarts student)',
#   "Jacob's sibling",
#   'Liz Tuttle',
#   'Penny Haywood'],
#  ['Harry Potter',
#   'Severus Snape',
#   'Arthur Weasley',
#   'Hermione Granger',
#   'Xenophilius Lovegood',
#   'Sybill Trelawney',
#   'Padma Patil',
#   'Eloise Midgen',
#   'Ronald Weasley',
#   'Harper'],
#  ['Harry Potter',
#   'Minerva McGonagall',
#   'Talbott Winger',
#   "Jacob's sibling",
#   'Angelica Cole',
#   'Sophia Prickett',
#   'Jason Charmer',
#   'Mike Boon',
#   'Hugh Biggs',
#   'Betty Bickering'],
#  ['Harry Potter',
#   'Charles Weasley',
#   'Sirius Black',
#   'Bellatrix Lestrange',
#   'Ronald Weasley',
#   'Katie Bell',
#   'Alicia Spinnet',
#   'Oliver Wood',
#   'Colin Creevey',
#   'Harry Potter'],
#  ['Harry Potter',
#   'Rubeus Hagrid',
#   'Molly Weasley',
#   'Arthur Weasley',
#   'James Potter I',
#   'Marauders',
#   'Tom Riddle',
#   'Gwendoline Hedgeflower',
#   'Severus Snape',
#   'Sirius Black'],
#  ['Harry Potter',
#   'Bartemius Crouch Junior',
#   'Tom Riddle',
#   'Neville Longbottom',
#   'Amycus Carrow',
#   'Augusta Longbottom',
#   'Aberforth Dumbledore',
#   "Jacob's sibling",
#   'Diego Caplan',
#   'Cedric Diggory'],
#  ['Harry Potter',
#   'Theodore Nott',
#   'Hermione Granger',
#   'Ronald Weasley',
#   'Charles Weasley',
#   'Penny Haywood',
#   'Beatrice Haywood',
#   "Jacob's sibling",
#   'Severus Snape',
#   'Nymphadora Tonks'],
#  ['Harry Potter',
#   'Terry Boot',
#   'Ginevra Weasley',
#   'Percy Weasley',
#   'Mundungus Fletcher',
#   'Fred Weasley',
#   'Ginevra Weasley',
#   'Harry Potter',
#   'Justin Steele',
#   'Daisy Corran'],
#  ['Harry Potter',
#   'Michael Corner',
#   'Hermione Granger',
#   'Rose Granger-Weasley',
#   'Cedric Diggory',
#   'Draco Malfoy',
#   'Harry Potter',
#   'Michael',
#   'Angus Matlock',
#   'Ronald Weasley'],
#  ['Harry Potter', 'Eldon Pembroke'],
#  ['Harry Potter',
#   'Rubeus Hagrid',
#   "Jacob's sibling",
#   "Erika Rath's friend (I)",
#   "Erika Rath's friend (II)",
#   "Jacob's sibling",
#   'Jacob (Hogwarts student)',
#   'Angelica Cole',
#   "Jacob's sibling",
#   'Albus Dumbledore'],
#  ['Harry Potter',
#   'Millicent Bulstrode',
#   'Hermione Granger',
#   'Filius Flitwick',
#   'Wilfred Levi Kidd',
#   'Albus Dumbledore',
#   'Newton Scamander',
#   'Silvanus Kettleburn',
#   'Patricia Rakepick',
#   "Jacob's sibling"],
#  ['Harry Potter',
#   'Eldred Worple',
#   'Horace Slughorn',
#   'Marcus Belby',
#   'Albus Dumbledore',
#   'Patricia Rakepick',
#   'Severus Snape',
#   'Tom Riddle',
#   'Garrick Ollivander',
#   'Peter Pettigrew'],
#  ['Harry Potter',
#   'Severus Snape',
#   'Angelina Johnson',
#   'Harry Potter',
#   'Alastor Moody',
#   'Remus Lupin',
#   'Marauders',
#   'George Weasley',
#   'Ronald Weasley',
#   'Cormac McLaggen'],
#  ['Harry Potter',
#   'Luna Lovegood',
#   'Xenophilius Lovegood',
#   'Harry Potter',
#   'Dolores Umbridge',
#   'Zacharias Smith',
#   'Fred Weasley',
#   'Head of Ravenclaw House',
#   'Filius Flitwick',
#   "Jacob's sibling"],
#  ['Harry Potter',
#   'Romilda Vane',
#   'James Potter I',
#   'Marauders',
#   'Tom Riddle',
#   'William Weasley',
#   'Harry Potter',
#   'Horace Slughorn',
#   'Flora Carrow',
#   'Hestia Carrow'],
#  ['Harry Potter',
#   'Ernest Macmillan',
#   'Justin Finch-Fletchley',
#   'Hermione Granger',
#   'Michael Corner',
#   'Parvati Patil',
#   'Cormac McLaggen',
#   'Ronald Weasley',
#   'Tom Riddle',
#   'Draco Malfoy'],
#  ['Harry Potter',
#   'Justin Finch-Fletchley',
#   'Hannah Abbott',
#   'Sirius Black',
#   'Tom Riddle',
#   'Alecto Carrow',
#   'Albus Dumbledore',
#   "Jacob's sibling",
#   'Merula Snyde',
#   'Ismelda Murk'],
#  ['Harry Potter',
#   'Cedric Diggory',
#   'Chiara Lobosca',
#   'Cecil Lee',
#   'Barnaby Lee',
#   "Jacob's sibling",
#   'Severus Snape',
#   'Head of Slytherin House',
#   'Horace Slughorn',
#   'Abraxas Malfoy'],
#  ['Harry Potter',
#   'Ginevra Weasley',
#   'Tom Riddle',
#   'Merula Snyde',
#   'Jae Kim',
#   'Emily Tyler',
#   'Ismelda Murk',
#   "Ismelda Murk's sister"],
#  ['Harry Potter',
#   'Neville Longbottom',
#   'Ginevra Weasley',
#   'Charles Weasley',
#   'Lily L. Potter',
#   'Lily J. Potter',
#   'Severus Snape',
#   'Quirinus Quirrell',
#   'Minerva McGonagall',
#   'Severus Snape'],
#  ['Harry Potter',
#   'Horace Slughorn',
#   'Tom Riddle',
#   'Katie Bell',
#   'Albus Dumbledore',
#   'Tom Riddle',
#   'Lestrange',
#   "Tom Riddle's gang",
#   'Horace Slughorn',
#   'Tom Riddle'],
#  ['Harry Potter',
#   'Dean Thomas',
#   'Parvati Patil',
#   'Padma Patil',
#   'Neville Longbottom',
#   'Luna Lovegood',
#   'Tom Riddle',
#   'Kingsley Shacklebolt',
#   'John Dawlish',
#   'Albus Dumbledore'],
#  ['Harry Potter',
#   'Hermione Granger',
#   'Gregory Goyle',
#   'Draco Malfoy',
#   'Blaise Zabini',
#   'Pansy Parkinson',
#   'Lily L. Potter',
#   'Luna Lovegood',
#   'Tom Riddle',
#   'Albus Dumbledore'],
#  ['Harry Potter',
#   'Fred Weasley',
#   'Arthur Weasley',
#   'Molly Weasley',
#   'Fat Lady',
#   'Cadogan',
#   "Jacob's sibling",
#   'Corey Hayden',
#   'Victor Ketsueki',
#   "Jacob's sibling"],
#  ['Harry Potter',
#   'Fay Dunbar',
#   'Ronald Weasley',
#   'Neville Longbottom',
#   'Rubeus Hagrid',
#   'Rose Granger-Weasley',
#   'Minerva McGonagall',
#   'Peter Pettigrew',
#   'William Weasley',
#   'Arthur Weasley'],
#  ['Harry Potter',
#   'Merlin',
#   "Jacob's sibling",
#   'Liz Tuttle',
#   'Penny Haywood',
#   'Patricia Rakepick',
#   'Albus Dumbledore',
#   'Tom Riddle',
#   'Minerva McGonagall',
#   'Draco Malfoy'],
#  ['Harry Potter',
#   'Tom Riddle',
#   'Bellatrix Lestrange',
#   'Fred Weasley',
#   'Ronald Weasley',
#   'Tom Riddle',
#   'Aberforth Dumbledore',
#   'Seamus Finnigan',
#   'Ronald Weasley',
#   'Draco Malfoy'],
#  ['Harry Potter',
#   'Narcissa Malfoy',
#   'Andromeda Tonks',
#   'Bellatrix Lestrange',
#   'Neville Longbottom',
#   'Tom Riddle',
#   'Filius Flitwick',
#   'Albus Dumbledore',
#   'Severus Snape',
#   'Eileen Prince'],
#  ['Harry Potter',
#   'Molly Weasley',
#   'Sirius Black',
#   'Ginevra Weasley',
#   'Lily J. Potter',
#   'Tom Riddle',
#   'Cho Chang',
#   'Luna Lovegood',
#   'Garrick Ollivander',
#   'Talbott Winger'],
#  ['Harry Potter',
#   'Zacharias Smith',
#   'Albus Dumbledore',
#   'Lucius Malfoy',
#   'Evan Rosier',
#   'Alastor Moody',
#   'Aberforth Dumbledore',
#   'Harry Potter',
#   'George Weasley',
#   'Percy Weasley'],
#  ['Harry Potter',
#   'Alice Tolipan (witch)',
#   'Alice',
#   'Minerva McGonagall',
#   'Harry Potter',
#   'Albus Dumbledore',
#   'Rubeus Hagrid',
#   'Harry Potter',
#   'Myrtle Warren',
#   'Olive Hornby'],
#  ['Harry Potter',
#   'Lily L. Potter',
#   'Lucretia Black',
#   'William Weasley',
#   'Charles Weasley',
#   'Molly Weasley',
#   'Bellatrix Lestrange',
#   'Draco Malfoy',
#   'Harry Potter',
#   'Scorpius Malfoy'],
#  ['Harry Potter',
#   'Pansy Parkinson',
#   "Draco Malfoy's gang",
#   'Theodore Nott',
#   'Lucius Malfoy',
#   'Rodolphus Lestrange',
#   'Neville Longbottom',
#   'Sirius Black',
#   'Severus Snape',
#   'Penny Haywood'],
#  ['Harry Potter',
#   'William Weasley',
#   'James Potter II',
#   'Molly Weasley',
#   'Rubeus Hagrid',
#   'Head of Gryffindor House',
#   'Godric Gryffindor',
#   'Salazar Slytherin',
#   'Rowena Ravenclaw',
#   'Helena Ravenclaw'],
#  ['Harry Potter',
#   'Pansy Parkinson',
#   'Lavender Brown',
#   'Romilda Vane',
#   'Marietta Edgecombe',
#   'Cho Chang',
#   'Oliver Wood',
#   'Colin Creevey',
#   'Ernest Macmillan',
#   'Harry Potter'],
#  ['Harry Potter',
#   'Luna Lovegood',
#   'Newton Scamander',
#   'Theseus Scamander',
#   'Leta Lestrange',
#   'Albus Dumbledore',
#   'Harry Potter',
#   'Millicent Bulstrode',
#   'Draco Malfoy',
#   'Phineas Nigellus Black'],
#  ['Harry Potter',
#   'Angelina Johnson',
#   'Ginevra Weasley',
#   'Draco Malfoy',
#   'Tom Riddle',
#   'Albus Dumbledore',
#   'Harry Potter',
#   'Luna Lovegood',
#   'Helena Ravenclaw',
#   'Bloody Baron'],
#  ['Harry Potter',
#   'Fred Weasley',
#   'James Potter I',
#   'Severus Snape',
#   'Ben Copper',
#   "Jacob's sibling",
#   'Victor Ketsueki',
#   'Chiara Lobosca',
#   'Harry Potter',
#   'Molly Weasley'],
#  ['Harry Potter',
#   'Gregory Goyle',
#   'Draco Malfoy',
#   'Abraxas Malfoy',
#   'Dorea Black',
#   'Walburga Black',
#   'Sirius Black',
#   'Remus Lupin',
#   'Edward Lupin',
#   'Bellatrix Lestrange'],
#  ['Harry Potter',
#   'John Dawlish',
#   'Cornelius Fudge',
#   'Ronald Weasley',
#   'Dean Thomas',
#   'Narcissa Malfoy',
#   'Tom Riddle',
#   'Myrtle Warren',
#   'Harry Potter',
#   'Neville Longbottom'],
#  ['Harry Potter',
#   'Sirius Black',
#   'James Potter I',
#   'Marauders',
#   'Harry Potter',
#   'Myrtle Warren',
#   'Draco Malfoy',
#   'Gregory Goyle',
#   'Ernest Macmillan',
#   'Seamus Finnigan'],
#  ['Harry Potter',
#   'Draco Malfoy',
#   'Katie Bell',
#   'Leanne',
#   'Romilda Vane',
#   'Albus Dumbledore',
#   'George Weasley',
#   'Lee Jordan',
#   'Rubeus Hagrid',
#   'Albus Dumbledore'],
#  ['Harry Potter',
#   'Alastor Moody',
#   'Tom Riddle',
#   'Armando Dippet',
#   'Silvanus Kettleburn',
#   'Patricia Rakepick',
#   "Jacob's sibling",
#   'Charles Weasley',
#   'Andre Egwu',
#   "Jacob's sibling"],
#  ['Harry Potter',
#   'Remus Lupin',
#   'Ronald Weasley',
#   'Severus Snape',
#   "Jacob's sibling",
#   'Tulip Karasu',
#   'Merula Snyde',
#   "Jacob's sibling",
#   'George Weasley',
#   'Molly Weasley'],
#  ['Harry Potter',
#   'Quirinus Quirrell',
#   'Boy who kept a bezoar in his pocket',
#   'Michael Corner',
#   'Cho Chang',
#   'Padma Patil',
#   'Leanne',
#   'Katie Bell',
#   'Angelina Johnson',
#   'Rose Granger-Weasley'],
#  ['Harry Potter',
#   'Isobel MacDougal',
#   'Morag MacDougal',
#   'Harry Potter',
#   'Filius Flitwick',
#   'Hermione Granger',
#   'Justin Finch-Fletchley',
#   'Penelope Clearwater',
#   'Percy Weasley',
#   'Angelina Johnson'],
#  ['Harry Potter',
#   'Amycus Carrow',
#   'Neville Longbottom',
#   'Bartemius Crouch Junior',
#   'Alastor Moody',
#   "Jacob's sibling",
#   'Tulip Karasu',
#   'Patricia Rakepick',
#   'Albus Dumbledore',
#   'Alastor Moody'],
#  ['Harry Potter',
#   'Albus Dumbledore',
#   'Nymphadora Tonks',
#   'Emily Tyler',
#   'Emily Taylor'],
#  ['Harry Potter',
#   'Fleamont Potter',
#   'James Potter I',
#   'William Weasley',
#   'Tom Riddle',
#   'Lucius Malfoy',
#   'Rubeus Hagrid',
#   'Patricia Rakepick',
#   'Merula Snyde',
#   "Merula Snyde's gang"],
#  ['Harry Potter',
#   'Rubeus Hagrid',
#   'Draco Malfoy',
#   'Susan Bones',
#   'Hermione Granger',
#   'Rubeus Hagrid',
#   'Cornelius Fudge',
#   'Severus Snape',
#   'Gregory Goyle',
#   'Theodore Nott'],
#  ['Harry Potter',
#   'Blaise Zabini',
#   'Theodore Nott',
#   'Lily Moon',
#   'Lily J. Potter',
#   'Avery II',
#   'Tom Riddle',
#   'Padma Patil',
#   'Ronald Weasley',
#   'Lee Jordan'],
#  ['Harry Potter',
#   'Ginevra Weasley',
#   'Ernest Macmillan',
#   'Gregory Goyle',
#   'Graham Montague',
#   'Katie Bell',
#   'Aberforth Dumbledore',
#   'Dean Thomas',
#   'Romilda Vane',
#   'Luna Lovegood'],
#  ['Harry Potter',
#   'Rolanda Hooch',
#   'Patricia Rakepick',
#   'Rubeus Hagrid',
#   'Bartemius Crouch Junior',
#   'Tom Riddle',
#   'Harry Potter',
#   'Michael',
#   'Michael Corner',
#   'Ginevra Weasley'],
#  ['Harry Potter',
#   'Myrtle Warren',
#   'Albus Potter',
#   'Panju Weasley',
#   'Scorpius Malfoy',
#   'Tom Riddle',
#   'Quirinus Quirrell',
#   'Lily J. Potter',
#   'Peter Pettigrew',
#   'Remus Lupin'],
#  ['Harry Potter',
#   'Sybill Trelawney',
#   'Lucius Malfoy',
#   'Tom Riddle',
#   'Amycus Carrow',
#   'Harry Potter',
#   'Lucius Malfoy',
#   'Arthur Weasley',
#   'Remus Lupin',
#   'Filius Flitwick'],
#  ['Harry Potter',
#   'Tom Riddle',
#   'Michael Corner',
#   'Cho Chang',
#   'Padma Patil',
#   'Minerva McGonagall',
#   'Severus Snape',
#   'Lucius Malfoy',
#   'Albus Dumbledore',
#   'Sybill Trelawney'],
#  ['Harry Potter',
#   'Severus Snape',
#   'Draco Malfoy',
#   'Theodore Nott',
#   'Pike',
#   'Hermione Granger',
#   'Peter Pettigrew',
#   'Sirius Black',
#   'George Weasley',
#   'Dolores Umbridge'],
#  ['Harry Potter',
#   'Hermione Granger',
#   'Xenophilius Lovegood',
#   'Eldred Worple',
#   'Harry Potter',
#   'Peter Pettigrew',
#   'Sirius Black',
#   'Hogwarts Express conductor',
#   'Remus Lupin',
#   'Peter Pettigrew'],
#  ['Harry Potter',
#   'Tom Riddle',
#   'Jacob (Hogwarts student)',
#   'Ben Copper',
#   "Jacob's sibling",
#   'Ismelda Murk',
#   'Albus Dumbledore',
#   'James Potter I',
#   'Peter Pettigrew',
#   'Sirius Black'],
#  ['Harry Potter',
#   'Andromeda Tonks',
#   'Narcissa Malfoy',
#   'Patricia Rakepick',
#   'Silvanus Kettleburn',
#   'Barnaby Lee',
#   'Merula Snyde',
#   "Merula Snyde's mother",
#   "Merula Snyde's father",
#   'Merula Snyde'],
#  ['Harry Potter', 'Sophie Roper'],
#  ['Harry Potter',
#   'Bartemius Crouch Junior',
#   'Severus Snape',
#   'Mundungus Fletcher',
#   'Albus Dumbledore',
#   'Leta Lestrange',
#   'Newton Scamander',
#   'Silvanus Kettleburn',
#   "Jacob's sibling",
#   'Bloody Baron'],
#  ['Harry Potter',
#   'Gilderoy Lockhart',
#   'Lucius Malfoy',
#   'Bartemius Crouch Junior',
#   'Tom Riddle',
#   'Narcissa Malfoy',
#   'Astoria Malfoy',
#   'Daphne Greengrass',
#   'Draco Malfoy',
#   'Lucius Malfoy'],
#  ['Harry Potter',
#   'Sirius Black',
#   'Myrtle Warren',
#   'Draco Malfoy',
#   'Lucius Malfoy',
#   'Nott',
#   'Luna Lovegood',
#   'Romilda Vane',
#   'Hermione Granger',
#   'Garrick Ollivander'],
#  ['Harry Potter',
#   'Sirius Black',
#   'Hermione Granger',
#   'Ernest Macmillan',
#   'Tom Riddle',
#   'George Weasley',
#   'William Weasley',
#   'Percy Weasley',
#   'Ronald Weasley',
#   'Rubeus Hagrid'],
#  ['Harry Potter',
#   'Draco Malfoy',
#   'Terry Boot',
#   'Michael Corner',
#   'Ginevra Weasley',
#   'Fred Weasley',
#   'Charles Weasley',
#   "Jacob's sibling",
#   'Badeea Ali',
#   'Ismelda Murk'],
#  ['Harry Potter',
#   'Alicia Spinnet',
#   'Katie Bell',
#   'Luna Lovegood',
#   'William Weasley',
#   'Fred Weasley',
#   'Charles Weasley',
#   'Penny Haywood',
#   'Cedric Diggory',
#   'Cedric'],
#  ['Harry Potter',
#   'Neville Longbottom',
#   'Augusta Longbottom',
#   'Albus Dumbledore',
#   'Molly Weasley',
#   'Andromeda Tonks',
#   'Nymphadora Tonks',
#   "Jacob's sibling",
#   'Tulip Karasu',
#   'Nymphadora Tonks'],
#  ['Harry Potter',
#   'Albus Dumbledore',
#   'Bartemius Crouch Junior',
#   'Peter Pettigrew',
#   'Remus Lupin',
#   'Lyall Lupin',
#   'Edward Lupin',
#   'Albus Potter',
#   'Rubeus Hagrid',
#   'Cedric Diggory'],
#  ['Harry Potter',
#   'Sally-Anne Perks',
#   'Susan Bones',
#   'Anthony Goldstein',
#   'Vincent Crabbe',
#   'Rolanda Hooch',
#   'Seamus Finnigan',
#   'Nicholas de Mimsy-Porpington',
#   'Badeea Ali',
#   "Jacob's sibling"],
#  ['Harry Potter',
#   'Hermione Granger',
#   'Terry Boot',
#   'Albus Dumbledore',
#   'Cedric Diggory',
#   'Cedric'],
#  ['Harry Potter',
#   'Severus Snape',
#   'Filius Flitwick',
#   'Minerva McGonagall',
#   'Rose Granger-Weasley',
#   'Narcissa Malfoy',
#   'Evan Rosier',
#   'Bellatrix Lestrange',
#   'Bartemius Crouch Junior',
#   'Draco Malfoy'],
#  ['Harry Potter',
#   'Neville Longbottom',
#   'Morag MacDougal',
#   'Morag',
#   'Minerva McGonagall',
#   'Merula Snyde',
#   "Jacob's sibling",
#   'Jacob (Hogwarts student)',
#   'Peter Pettigrew',
#   'Bartemius Crouch Junior'],
#  ['Harry Potter',
#   'Cornelius Fudge',
#   'Gilderoy Lockhart',
#   'Susan Bones',
#   'Dolores Umbridge',
#   'Head of Slytherin House',
#   'Salazar Slytherin',
#   'Ginevra Weasley',
#   'Ronald Weasley',
#   'Vincent Crabbe'],
#  ['Harry Potter',
#   'Michael',
#   'Michael Corner',
#   'Ginevra Weasley',
#   'Pansy Parkinson',
#   'Daphne Greengrass',
#   'Scorpius Malfoy',
#   'Dolores Umbridge',
#   'Romilda Vane',
#   'James Potter I'],
#  ['Harry Potter',
#   'Slytherin student that blames Harry Potter (I)',
#   'Slytherin student that blames Harry Potter (II)',
#   'Harry Potter',
#   'Grim Fawley',
#   'Penelope Fawley',
#   'Sage Bragnam',
#   'Mathilda Grimblehawk',
#   'Abraham Grimblehawk',
#   'Newton Scamander'],
#  ['Harry Potter',
#   'Hermione Granger',
#   'Draco Malfoy',
#   'Harry Potter',
#   'Cedric Diggory',
#   'Hannah Abbott',
#   'Barnaby Lee',
#   'Andre Egwu',
#   'Talbott Winger',
#   'Helena Ravenclaw'],
#  ['Harry Potter',
#   'Graham Montague',
#   'Fred Weasley',
#   'Dolores Umbridge',
#   'Nigel Wolpert',
#   'Neville Longbottom',
#   'Dean Thomas',
#   'Parvati Patil',
#   'Hermione Granger',
#   'Dean Thomas'],
#  ['Harry Potter',
#   'Andromeda Tonks',
#   'Sirius Black',
#   'Fred Weasley',
#   'Marietta Edgecombe',
#   'Parvati Patil',
#   'Nicholas de Mimsy-Porpington',
#   'Bloody Baron',
#   'Seamus Finnigan',
#   'Katie Bell'],
#  ['Harry Potter',
#   'Tom Riddle',
#   'Horace Slughorn',
#   'Armando Dippet',
#   'Tom Riddle',
#   'Harry Potter',
#   'Hermione Granger',
#   'Luna Lovegood',
#   'Ronald Weasley',
#   'Percy Weasley'],
#  ['Harry Potter',
#   'Lavender Brown',
#   'Alicia Spinnet',
#   'Marietta Edgecombe',
#   'Kingsley Shacklebolt',
#   'Ronald Weasley',
#   'Hermione Granger',
#   'Fred Weasley',
#   'Victoire Weasley',
#   'Harry Potter'],
#  ['Harry Potter',
#   'Scorpius Malfoy',
#   'Albus Potter',
#   'Fred Weasley',
#   'George Weasley',
#   'Hermione Granger',
#   'Nicholas de Mimsy-Porpington',
#   'Angelica Cole',
#   "Jacob's sibling",
#   'Silvanus Kettleburn'],
#  ['Harry Potter',
#   'James Potter I',
#   'Albus Dumbledore',
#   'Theseus Scamander',
#   'Newton Scamander',
#   'Albus Dumbledore',
#   'Leta Lestrange',
#   'Theseus Scamander',
#   'Newton Scamander',
#   'Uric the Oddball'],
#  ['Harry Potter',
#   'Peter Pettigrew',
#   'Bertha Jorkins',
#   "Florence's boyfriend",
#   'Florence',
#   'Bertha Jorkins',
#   'Remus Lupin',
#   'Seamus Finnigan',
#   'Katie Bell',
#   'Severus Snape'],
#  ['Harry Potter',
#   'Lee Jordan',
#   'Angelina Johnson',
#   'Arthur Weasley',
#   'Nymphadora Tonks',
#   'Oliver Wood',
#   'Lee Jordan',
#   'Harry Potter',
#   'Pomona Sprout',
#   'Trio'],
#  ['Harry Potter',
#   'Filius Flitwick',
#   'George Weasley',
#   'Angelina Johnson',
#   'Albus Potter',
#   'Ginevra Weasley',
#   'Remus Lupin',
#   'Lee Jordan',
#   'Nigel Wolpert',
#   'Bem'],
#  ['Harry Potter',
#   'Lee Jordan',
#   'George Weasley',
#   'Tom Riddle',
#   'Luna Lovegood',
#   'Bellatrix Lestrange',
#   'Aberforth Dumbledore',
#   'Nymphadora Tonks',
#   'Edward Lupin',
#   'William Weasley'],
#  ['Harry Potter',
#   'Severus Snape',
#   'Rubeus Hagrid',
#   'Arthur Weasley',
#   'Hermione Granger',
#   'Aberforth Dumbledore',
#   'Harry Potter',
#   'Roger Malone',
#   'Stephen Cornfoot',
#   'Oliver Rivers'],
#  ['Harry Potter',
#   'Luna Lovegood',
#   'Newton Scamander',
#   'Albus Dumbledore',
#   'Kingsley Shacklebolt',
#   'Nymphadora Tonks',
#   "Jacob's sibling",
#   'Merula Snyde',
#   'Penny Haywood',
#   'Minerva McGonagall'],
#  ['Harry Potter',
#   'Angus Matlock',
#   'Nigel Wolpert',
#   'Tom Riddle',
#   'Molly Weasley',
#   'Percy Weasley',
#   'Kingsley Shacklebolt',
#   'Cornelius Fudge',
#   'Sirius Black',
#   'Remus Lupin'],
#  ['Harry Potter',
#   'Phineas Nigellus Black',
#   'Severus Snape',
#   'Bartemius Crouch Junior',
#   'Tom Riddle',
#   'Harry Potter',
#   'Neville Longbottom',
#   'Scabior',
#   'Hermione Granger',
#   'Fred Weasley'],
#  ['Harry Potter',
#   'Vincent Crabbe',
#   'Gregory Goyle',
#   'Severus Snape',
#   'Albus Potter',
#   'Panju Weasley',
#   'Lily L. Potter',
#   'Pansy Parkinson',
#   "Draco Malfoy's gang",
#   'Hannah Abbott'],
#  ['Harry Potter',
#   'Severus Snape',
#   'Albus Dumbledore',
#   'Newton Scamander',
#   'Bunty',
#   'Leta Lestrange',
#   'Theseus Scamander',
#   'Newton Scamander',
#   'Harry Potter',
#   'Gang of Slytherins'],
#  ['Harry Potter',
#   'George Weasley',
#   'Fred Weasley',
#   'Ronald Weasley',
#   'Zacharias Smith',
#   'Sally Smith',
#   'Helga Hufflepuff',
#   'Head of Hufflepuff House',
#   'Sirius Black',
#   'Molly Weasley'],
#  ['Harry Potter',
#   'Albus Dumbledore',
#   'Rolanda Hooch',
#   'Minerva McGonagall',
#   'Pansy Parkinson',
#   'Vincent Crabbe',
#   'Bellatrix Lestrange',
#   'Dorea Black',
#   'Cygnus Black III',
#   'Alphard Black'],
#  ['Harry Potter',
#   'Albus Dumbledore',
#   'Rubeus Hagrid',
#   'Hermione Granger',
#   'Cormac McLaggen',
#   'Jimmy Peakes',
#   'Ritchie Coote',
#   'Minerva McGonagall',
#   'Sirius Black',
#   'Tom Riddle'],
#  ['Harry Potter',
#   'Tom Riddle',
#   'Severus Snape',
#   'Remus Lupin',
#   'Rubeus Hagrid',
#   'Albus Dumbledore',
#   'Tom Riddle',
#   'Oliver Wood',
#   'Alicia Spinnet',
#   'Justin Finch-Fletchley'],
#  ['Harry Potter',
#   'Regulus Black',
#   'Tom Riddle',
#   'George Weasley',
#   'Dolores Umbridge',
#   'Filius Flitwick',
#   'Fred Weasley',
#   'William Weasley',
#   'Percy Weasley',
#   'George Weasley'],
#  ['Harry Potter',
#   'Amycus Carrow',
#   'Severus Snape',
#   'Sirius Black',
#   'Harry Potter',
#   'J. E. Prewitt',
#   'D. L. Boot',
#   'Terry Boot',
#   'Alecto Carrow',
#   'Minerva McGonagall'],
#  ['Harry Potter',
#   'Rubeus Hagrid',
#   'Albus Dumbledore',
#   'Draco Malfoy',
#   'Phineas Nigellus Black',
#   'Armando Dippet',
#   'Minerva McGonagall',
#   'Dolores Umbridge',
#   'Hermione Granger',
#   'Albus Dumbledore'],
#  ['Harry Potter',
#   'Padma Patil',
#   'Cedric Diggory',
#   'Albus Dumbledore',
#   'Pomona Sprout',
#   'Harry Potter',
#   'Luna Lovegood',
#   'Hermione Granger',
#   'Bellatrix Lestrange',
#   'Garrick Ollivander'],
#  ['Harry Potter',
#   'Zacharias Smith',
#   'Ronald Weasley',
#   'Draco Malfoy',
#   'Lucius Malfoy',
#   'Peter Pettigrew',
#   'Percy Weasley',
#   'Fred Weasley',
#   'Cho Chang',
#   'Leanne'],
#  ['Harry Potter',
#   'Dolores Umbridge',
#   'Dean Thomas',
#   'Anthony Goldstein',
#   'Albus Dumbledore',
#   'Rubeus Hagrid',
#   'Tom Riddle',
#   'Molly Weasley',
#   'Hermione Granger',
#   'William Weasley'],
#  ['Harry Potter',
#   'Marietta Edgecombe',
#   'Cho Chang',
#   'Susan Bones',
#   'Hermione Granger',
#   'Vincent Crabbe',
#   'Cedric Diggory',
#   'Scorpius Malfoy',
#   'Karl Jenkins',
#   'Albus Potter'],
#  ['Harry Potter',
#   'Albus Dumbledore',
#   'Arthur Weasley',
#   'Peter Pettigrew',
#   'Tom Riddle',
#   'Bellatrix Lestrange',
#   'Walburga Black',
#   'Araminta Meliflua Black',
#   'Sirius Black',
#   'Hermione Granger'],
#  ['Harry Potter', 'Nandini Johar'],
#  ['Harry Potter',
#   'Katie Bell',
#   'Ronald Weasley',
#   'Ginevra Weasley',
#   'Rolanda Hooch',
#   'Ethan Parkin',
#   'Penny Haywood',
#   "Jacob's sibling",
#   'Ben Copper',
#   'William Weasley'],
#  ['Harry Potter',
#   'Phineas Nigellus Black',
#   'Severus Snape',
#   'Ben Copper',
#   "Jacob's sibling",
#   'Nymphadora Tonks',
#   'Kingsley Shacklebolt',
#   'Horace Slughorn',
#   'B. C.',
#   'Bartemius Crouch Junior'],
#  ['Harry Potter', 'Gillian Ossett'],
#  ['Harry Potter',
#   'Gregory Goyle',
#   'Justin Finch-Fletchley',
#   'Harry Potter',
#   'Scorpius Malfoy',
#   'Albus Potter',
#   'Albus Dumbledore',
#   'Newton Scamander',
#   'Leta Lestrange',
#   'Theseus Scamander'],
#  ['Harry Potter',
#   'Tom Riddle',
#   'Neville Longbottom',
#   'Luna Lovegood',
#   'Cadwallader',
#   'Ginevra Weasley',
#   'Parvati Patil',
#   'Sybill Trelawney',
#   'Lavender Brown',
#   'Harry Potter'],
#  ['Harry Potter',
#   'Katie Bell',
#   'Terry Boot',
#   'Luna Lovegood',
#   'Newton Scamander',
#   'Albus Dumbledore',
#   'Cornelius Fudge',
#   'Sirius Black',
#   'Albus Dumbledore',
#   'Hermione Granger'],
#  ['Harry Potter',
#   'Severus Snape',
#   'Bartemius Crouch Junior',
#   'Cedric Diggory',
#   'Hannah Abbott',
#   'Sally-Anne Perks',
#   'Harry Potter',
#   'Wayne Hopkins',
#   'Carl Hopkins',
#   'Scott Ancrum'],
#  ['Harry Potter',
#   'Oliver Wood',
#   'Marcus Flint',
#   'Graham Montague',
#   'George Weasley',
#   'Harry Potter',
#   'Euan Abercrombie'],
#  ['Harry Potter',
#   'George Weasley',
#   'Ronald Weasley',
#   'Lucius Malfoy',
#   'Andromeda Tonks',
#   'Narcissa Malfoy',
#   'Cornelius Fudge',
#   'Bartemius Crouch Junior',
#   'Alastor Moody',
#   'Neville Longbottom'],
#  ['Harry Potter', 'Gillian Ossett'],
#  ['Harry Potter',
#   'Tom Riddle',
#   'Nott',
#   'Theodore Nott',
#   'Draco Malfoy',
#   'Cedric Diggory',
#   'Angelina Johnson',
#   'Harry Potter',
#   'Colin Creevey',
#   'Susan Bones'],
#  ['Harry Potter',
#   'Molly Weasley',
#   'Alastor Moody',
#   'Minerva McGonagall',
#   'Cadogan',
#   'Merlin',
#   'Ben Copper',
#   'Rubeus Hagrid',
#   'Tom Riddle',
#   'Amycus Carrow'],
#  ['Harry Potter',
#   'Seamus Finnigan',
#   'Ginevra Weasley',
#   'Luna Lovegood',
#   'Xenophilius Lovegood',
#   'Garrick Ollivander',
#   'Harry Potter',
#   'Remus Lupin',
#   'Ginevra Weasley',
#   'Molly Weasley'],
#  ['Harry Potter',
#   'Horace Slughorn',
#   'Trevor Birch',
#   'Gilderoy Lockhart',
#   'Colin Creevey',
#   'Cho Chang',
#   'Luna Lovegood',
#   'Harry Potter',
#   'James Potter I',
#   'Hermione Granger'],
#  ['Harry Potter',
#   'Zacharias Smith',
#   'Hannah Abbott',
#   'Justin Finch-Fletchley',
#   'Harry Potter',
#   'Remus Lupin',
#   'Ronald Weasley',
#   'Leanne',
#   'Romilda Vane',
#   'Dean Thomas'],
#  ['Harry Potter',
#   'Tom Riddle',
#   'Molly Weasley',
#   'Draco Malfoy',
#   'Seamus Finnigan',
#   'Katie Bell',
#   'Severus Snape',
#   'Harry Potter',
#   'Narcissa Malfoy',
#   'Edward Lupin'],
#  ['Harry Potter',
#   'Hermione Granger',
#   'Alicia Spinnet',
#   'Angelina Johnson',
#   'Hermione Granger',
#   'Sirius Black',
#   'Peter Pettigrew',
#   'Tom Riddle',
#   'Hestia Carrow',
#   'Flora Carrow'],
#  ['Harry Potter',
#   'Head of Slytherin House',
#   'Dolores Umbridge',
#   'Neville Longbottom',
#   'Molly Weasley',
#   'Rose Granger-Weasley',
#   'Ronald Weasley',
#   'Peter Pettigrew',
#   'Bartemius Crouch Junior',
#   'Severus Snape'],
#  ['Harry Potter',
#   'Marauders',
#   'James Potter I',
#   'Trio',
#   'Rose Granger-Weasley',
#   'Albus Potter',
#   'Lucretia Black',
#   'James Potter II',
#   'Ginevra Weasley',
#   'Lily L. Potter'],
#  ['Harry Potter',
#   'Lucius Malfoy',
#   'Vincent Crabbe',
#   'Draco Malfoy',
#   'Quirinus Quirrell',
#   'Ronald Weasley',
#   'Gang of Slytherins',
#   'Wilkes',
#   'Lucius Malfoy',
#   'Nymphadora Tonks'],
#  ['Harry Potter',
#   'Amycus Carrow',
#   'Dolores Umbridge',
#   'Alicia Spinnet',
#   'Oliver Wood',
#   'Colin Creevey',
#   'Hermione Granger',
#   'Scabior',
#   'Bellatrix Lestrange',
#   'Regulus Black'],
#  ['Harry Potter',
#   'Susan Bones',
#   'Marietta Edgecombe',
#   'Cho Chang',
#   'Harry Potter',
#   'Regulus Black',
#   'Ronald Weasley',
#   'Penelope Clearwater',
#   'Nicholas de Mimsy-Porpington',
#   'Hermione Granger'],
#  ['Harry Potter',
#   'Molly Weasley',
#   'George Weasley',
#   'Angelina Johnson',
#   'Dean Thomas',
#   'Harry Potter',
#   'Colin Creevey',
#   'Dennis Creevey',
#   'Oliver Wood',
#   'Angelina Johnson'],
#  ['Harry Potter',
#   'Marauders',
#   'Peter Pettigrew',
#   'Harry Potter',
#   'Sybill Trelawney',
#   'Tom Riddle',
#   'Bartemius Crouch Junior',
#   'Bellatrix Lestrange',
#   'Albus Potter',
#   'Hermione Granger'],
#  ['Harry Potter',
#   'Draco Malfoy',
#   'Tom Riddle',
#   'Rubeus Hagrid',
#   'John Dawlish',
#   'Kingsley Shacklebolt',
#   'Marietta Edgecombe',
#   'Cho Chang',
#   'Justin Finch-Fletchley',
#   'Harry Potter'],
#  ['Harry Potter', 'David Nolton'],
#  ['Harry Potter',
#   'Severus Snape',
#   'Leta Lestrange',
#   'Newton Scamander',
#   'Silvanus Kettleburn',
#   'Fred Weasley',
#   'Sirius Black',
#   'James Potter II',
#   'Lily L. Potter',
#   'Luna Lovegood'],
#  ['Harry Potter',
#   'Severus Snape',
#   'Draco Malfoy',
#   'Harry Potter',
#   'Boy who kept a bezoar in his pocket',
#   'Michael Corner',
#   'Alecto Carrow',
#   'Filius Flitwick',
#   'Sirius Black',
#   'Rodolphus Lestrange'],
#  ['Harry Potter',
#   'Hengist of Woodcroft',
#   'Gabriel Truman',
#   'Bridget Wenlock',
#   'Bridget'],
#  ['Harry Potter',
#   'Tom Riddle',
#   'Sirius Black',
#   'Orion Amari',
#   "Jacob's sibling",
#   'Merlin',
#   'Eglantine Puffett',
#   'Gemma Farley',
#   'Millicent Bulstrode',
#   'Hermione Granger'],
#  ['Harry Potter',
#   'Ronald Weasley',
#   'Zacharias Smith',
#   'Helga Hufflepuff',
#   'Rowena Ravenclaw',
#   'Harry Potter',
#   'Nicholas de Mimsy-Porpington',
#   'Badeea Ali',
#   "Jacob's sibling",
#   'Rowan Khanna'],
#  ['Harry Potter',
#   'William Weasley',
#   'Fred Weasley',
#   'Hermione Granger',
#   'Ronald Weasley',
#   'Fred Weasley',
#   'Alastor Moody',
#   'Hermione Granger',
#   'Albus Potter',
#   'Karl Jenkins'],
#  ['Harry Potter',
#   'Lucius Malfoy',
#   'Miles Bletchley',
#   'Kevin Bletchley',
#   'Bletchley (musician)',
#   'Miles Bletchley',
#   'Kevin Bletchley',
#   'Bletchley (musician)',
#   'Miles Bletchley',
#   'Draco Malfoy'],
#  ['Harry Potter',
#   'Sirius Black',
#   'Rubeus Hagrid',
#   'Tom Riddle',
#   'Harry Potter',
#   "Boy who failed Avifors Spell's cousin",
#   'Boy who failed Avifors Spell'],
#  ['Harry Potter',
#   'Narcissa Malfoy',
#   'Scorpius Malfoy',
#   'Lucius Malfoy',
#   'Peter Pettigrew',
#   'Percy Weasley',
#   'William Weasley',
#   "Jacob's sibling",
#   'Albus Dumbledore',
#   'John Dawlish'],
#  ['Harry Potter',
#   'Draco Malfoy',
#   'Albus Potter',
#   'Cedrella Black',
#   'Andromeda Tonks',
#   'Evan Rosier',
#   'Gang of Slytherins',
#   'Regulus Black',
#   'Sirius Black',
#   'Cornelius Fudge'],
#  ['Harry Potter',
#   'Remus Lupin',
#   'Marauders',
#   'Patricia Rakepick',
#   'Armando Dippet',
#   'Phineas Nigellus Black',
#   'Draco Malfoy',
#   'Narcissa Malfoy',
#   'Cygnus Black III',
#   'Andromeda Tonks'],
#  ['Harry Potter',
#   'Remus Lupin',
#   'Alastor Moody',
#   'Ginevra Weasley',
#   'Victoire Weasley',
#   'Rose Granger-Weasley',
#   'Ronald Weasley',
#   'Mundungus Fletcher',
#   'Alastor Moody',
#   'Minerva McGonagall'],
#  ['Harry Potter',
#   'Justin Finch-Fletchley',
#   'Hermione Granger',
#   'Dean Thomas',
#   'Ginevra Weasley',
#   'Ronald Weasley',
#   'Gregory Goyle',
#   'Susan Bones',
#   'Harry Potter',
#   'Bem'],
#  ['Harry Potter',
#   'Arthur Weasley',
#   'Draco Malfoy',
#   'Narcissa Malfoy',
#   'Rose Granger-Weasley',
#   'Ronald Weasley',
#   'Lucius Malfoy',
#   'Avery II',
#   'Severus Snape',
#   'Bartemius Crouch Junior'],
#  ['Harry Potter',
#   'Cho Chang',
#   'Marietta Edgecombe',
#   'Cornelius Fudge',
#   'Narcissa Malfoy',
#   'Scorpius Malfoy',
#   'Panju Weasley',
#   'Ronald Weasley',
#   'Harry Potter',
#   'Albus Dumbledore'],
#  ['Harry Potter',
#   'Percy Weasley',
#   'George Weasley',
#   'Fred Weasley',
#   'Hermione Granger',
#   'Cormac McLaggen',
#   'Ritchie Coote',
#   'Albus Dumbledore',
#   'Phineas Nigellus Black',
#   'Severus Snape'],
#  ['Harry Potter',
#   'Anthony Goldstein',
#   'Dolores Umbridge',
#   'Horace Slughorn',
#   'Lucius Malfoy',
#   'Garrick Ollivander',
#   'Albus Dumbledore',
#   'Head of Ravenclaw House',
#   'Harry Potter',
#   'Quirinus Quirrell'],
#  ['Harry Potter',
#   'Alicia Spinnet',
#   'Lavender Brown',
#   'Hermione Granger',
#   'Albus Dumbledore',
#   'Lucius Malfoy',
#   'Harry Potter',
#   'Helena Ravenclaw',
#   'Bloody Baron',
#   'Ismelda Murk'],
#  ['Harry Potter',
#   'Nicholas de Mimsy-Porpington',
#   "Jacob's sibling",
#   'George Weasley',
#   'Remus Lupin',
#   'Sirius Black',
#   'Trio',
#   'Hermione Granger',
#   'Katie Bell',
#   'Cho Chang'],
#  ['Harry Potter',
#   'Albus Potter',
#   'Charles Weasley',
#   'Molly Weasley',
#   'Lucretia Black',
#   'Regulus Black',
#   'Tom Riddle',
#   'Dolores Umbridge',
#   'Hermione Granger',
#   'William Weasley'],
#  ['Harry Potter',
#   'Bellatrix Lestrange',
#   'Gang of Slytherins',
#   'Harry Potter',
#   'Draco Malfoy',
#   'Sirius Black',
#   'Evan Rosier',
#   'Avery II',
#   'Tom Riddle',
#   'Dolores Umbridge'],
#  ['Harry Potter',
#   'Phineas Nigellus Black',
#   'Sirius Black',
#   'Peter Pettigrew',
#   'Marauders',
#   'Remus Lupin',
#   'William Weasley',
#   'Alastor Moody',
#   "Jacob's sibling",
#   'Felix Rosier'],
#  ['Harry Potter', 'Karl Limpley', 'Neil Randall'],
#  ['Harry Potter',
#   'Bellatrix Lestrange',
#   'Neville Longbottom',
#   'Harry Potter',
#   'Severus Snape',
#   "Jacob's sibling",
#   'Orion Amari',
#   'Skye Parkin',
#   'Ethan Parkin',
#   "Jacob's sibling"],
#  ['Harry Potter',
#   'Hermione Granger',
#   'Ginevra Weasley',
#   'Craig Bowker Junior',
#   'Harry Potter',
#   'Albus Dumbledore',
#   'Minerva McGonagall',
#   'Alastor Moody',
#   'Hermione Granger',
#   'Kingsley Shacklebolt'],
#  ['Harry Potter',
#   'Severus Snape',
#   'Marauders',
#   'Edward Lupin',
#   'Remus Lupin',
#   'Gilderoy Lockhart',
#   'Pomona Sprout',
#   'Gabriel Truman',
#   'Dugald McPhail'],
#  ['Harry Potter',
#   'Gilderoy Lockhart',
#   'Ronald Weasley',
#   '1996 Gryffindor Quidditch Keeper trials spectators',
#   'Harry Potter',
#   'Cormac McLaggen',
#   'Ronald Weasley',
#   'Harry Potter',
#   'Theodore Nott',
#   'Nott'],
#  ['Harry Potter',
#   'Lily J. Potter',
#   'Rose Granger-Weasley',
#   'Angelina Johnson',
#   'Anthony Goldstein',
#   'Marcus Turner',
#   'Darrel Turner'],
#  ['Harry Potter',
#   'Dean Thomas',
#   'Sirius Black',
#   'Cornelius Fudge',
#   'Minerva McGonagall',
#   'Craig Bowker Junior',
#   'Tom Riddle',
#   'Demelza Robins',
#   'Harry Potter',
#   'James Potter I'],
#  ['Harry Potter',
#   'Lily J. Potter',
#   'Draco Malfoy',
#   'Gregory Goyle',
#   'Peter Pettigrew',
#   'Jacob (Hogwarts student)',
#   'Patricia Rakepick',
#   'Barnaby Lee',
#   "Merula Snyde's gang",
#   'Merula Snyde'],
#  ['Harry Potter',
#   'Sirius Black',
#   'Rubeus Hagrid',
#   "Jacob's sibling",
#   'Patricia Rakepick',
#   'Narcissa Malfoy',
#   'James Potter I',
#   'Harry Potter',
#   'Sirius Black',
#   'Evan Rosier'],
#  ['Harry Potter',
#   'Theodore Nott',
#   'Albus Potter',
#   'Harry Potter',
#   'Leanne',
#   'Padma Patil',
#   'Albus Potter',
#   'Panju Weasley',
#   'Padma Patil',
#   'Ronald Weasley'],
#  ['Harry Potter',
#   'Angelina Johnson',
#   'James Potter II',
#   'William Weasley',
#   'Tom Riddle',
#   'Gang of Slytherins',
#   'Harry Potter',
#   'Colin Creevey',
#   'Dolores Umbridge',
#   'Minerva McGonagall'],
#  ['Harry Potter',
#   'Angelina Johnson',
#   'Rose Granger-Weasley',
#   'James Potter I',
#   'Severus Snape',
#   'Rodolphus Lestrange',
#   'Lucius Malfoy',
#   'Tom Riddle',
#   'Ernest Macmillan',
#   'Anthony Goldstein'],
#  ['Harry Potter',
#   'Romilda Vane',
#   'Amycus Carrow',
#   'Nicholas de Mimsy-Porpington',
#   'James Potter I',
#   'Quirinus Quirrell',
#   'Harry Potter',
#   'Angelina Johnson',
#   'Hermione Granger',
#   'Luna Lovegood'],
#  ['Harry Potter',
#   'Colin Creevey',
#   'Justin Finch-Fletchley',
#   'Harry Potter',
#   'Sybill Trelawney',
#   'Severus Snape',
#   'Alastor Moody',
#   'Elphias Doge',
#   'James Potter I',
#   'Marauders'],
#  ['Harry Potter',
#   'Hermione Granger',
#   'Rubeus Hagrid',
#   'Charles Weasley',
#   'Nymphadora Tonks',
#   'Alastor Moody',
#   'Bartemius Crouch Junior',
#   'Rodolphus Lestrange',
#   'Bellatrix Lestrange',
#   'Tom Riddle'],
#  ['Harry Potter',
#   'Lily J. Potter',
#   'Peter Pettigrew',
#   'Bartemius Crouch Junior',
#   'Bellatrix Lestrange',
# ...
#   'Eglantine Puffett',
#   'Gemma Farley',
#   'Millicent Bulstrode',
#   'Hermione Granger'],
#  ['Harry Potter',
#   'Ronald Weasley',
#   'Zacharias Smith',
#   'Helga Hufflepuff',
#   'Rowena Ravenclaw',
#   'Harry Potter',
#   'Nicholas de Mimsy-Porpington',
#   'Badeea Ali',
#   "Jacob's sibling",
#   'Rowan Khanna'],
#  ['Harry Potter',
#   'William Weasley',
#   'Fred Weasley',
#   'Hermione Granger',
#   'Ronald Weasley',
#   'Fred Weasley',
#   'Alastor Moody',
#   'Hermione Granger',
#   'Albus Potter',
#   'Karl Jenkins'],
#  ['Harry Potter',
#   'Lucius Malfoy',
#   'Miles Bletchley',
#   'Kevin Bletchley',
#   'Bletchley (musician)',
#   'Miles Bletchley',
#   'Kevin Bletchley',
#   'Bletchley (musician)',
#   'Miles Bletchley',
#   'Draco Malfoy'],
#  ['Harry Potter',
#   'Sirius Black',
#   'Rubeus Hagrid',
#   'Tom Riddle',
#   'Harry Potter',
#   "Boy who failed Avifors Spell's cousin",
#   'Boy who failed Avifors Spell'],
#  ['Harry Potter',
#   'Narcissa Malfoy',
#   'Scorpius Malfoy',
#   'Lucius Malfoy',
#   'Peter Pettigrew',
#   'Percy Weasley',
#   'William Weasley',
#   "Jacob's sibling",
#   'Albus Dumbledore',
#   'John Dawlish'],
#  ['Harry Potter',
#   'Draco Malfoy',
#   'Albus Potter',
#   'Cedrella Black',
#   'Andromeda Tonks',
#   'Evan Rosier',
#   'Gang of Slytherins',
#   'Regulus Black',
#   'Sirius Black',
#   'Cornelius Fudge'],
#  ['Harry Potter',
#   'Remus Lupin',
#   'Marauders',
#   'Patricia Rakepick',
#   'Armando Dippet',
#   'Phineas Nigellus Black',
#   'Draco Malfoy',
#   'Narcissa Malfoy',
#   'Cygnus Black III',
#   'Andromeda Tonks'],
#  ['Harry Potter',
#   'Remus Lupin',
#   'Alastor Moody',
#   'Ginevra Weasley',
#   'Victoire Weasley',
#   'Rose Granger-Weasley',
#   'Ronald Weasley',
#   'Mundungus Fletcher',
#   'Alastor Moody',
#   'Minerva McGonagall'],
#  ['Harry Potter',
#   'Justin Finch-Fletchley',
#   'Hermione Granger',
#   'Dean Thomas',
#   'Ginevra Weasley',
#   'Ronald Weasley',
#   'Gregory Goyle',
#   'Susan Bones',
#   'Harry Potter',
#   'Bem'],
#  ['Harry Potter',
#   'Arthur Weasley',
#   'Draco Malfoy',
#   'Narcissa Malfoy',
#   'Rose Granger-Weasley',
#   'Ronald Weasley',
#   'Lucius Malfoy',
#   'Avery II',
#   'Severus Snape',
#   'Bartemius Crouch Junior'],
#  ['Harry Potter',
#   'Cho Chang',
#   'Marietta Edgecombe',
#   'Cornelius Fudge',
#   'Narcissa Malfoy',
#   'Scorpius Malfoy',
#   'Panju Weasley',
#   'Ronald Weasley',
#   'Harry Potter',
#   'Albus Dumbledore'],
#  ['Harry Potter',
#   'Percy Weasley',
#   'George Weasley',
#   'Fred Weasley',
#   'Hermione Granger',
#   'Cormac McLaggen',
#   'Ritchie Coote',
#   'Albus Dumbledore',
#   'Phineas Nigellus Black',
#   'Severus Snape'],
#  ['Harry Potter',
#   'Anthony Goldstein',
#   'Dolores Umbridge',
#   'Horace Slughorn',
#   'Lucius Malfoy',
#   'Garrick Ollivander',
#   'Albus Dumbledore',
#   'Head of Ravenclaw House',
#   'Harry Potter',
#   'Quirinus Quirrell'],
#  ['Harry Potter',
#   'Alicia Spinnet',
#   'Lavender Brown',
#   'Hermione Granger',
#   'Albus Dumbledore',
#   'Lucius Malfoy',
#   'Harry Potter',
#   'Helena Ravenclaw',
#   'Bloody Baron',
#   'Ismelda Murk'],
#  ['Harry Potter',
#   'Nicholas de Mimsy-Porpington',
#   "Jacob's sibling",
#   'George Weasley',
#   'Remus Lupin',
#   'Sirius Black',
#   'Trio',
#   'Hermione Granger',
#   'Katie Bell',
#   'Cho Chang'],
#  ['Harry Potter',
#   'Albus Potter',
#   'Charles Weasley',
#   'Molly Weasley',
#   'Lucretia Black',
#   'Regulus Black',
#   'Tom Riddle',
#   'Dolores Umbridge',
#   'Hermione Granger',
#   'William Weasley'],
#  ['Harry Potter',
#   'Bellatrix Lestrange',
#   'Gang of Slytherins',
#   'Harry Potter',
#   'Draco Malfoy',
#   'Sirius Black',
#   'Evan Rosier',
#   'Avery II',
#   'Tom Riddle',
#   'Dolores Umbridge'],
#  ['Harry Potter',
#   'Phineas Nigellus Black',
#   'Sirius Black',
#   'Peter Pettigrew',
#   'Marauders',
#   'Remus Lupin',
#   'William Weasley',
#   'Alastor Moody',
#   "Jacob's sibling",
#   'Felix Rosier'],
#  ['Harry Potter', 'Karl Limpley', 'Neil Randall'],
#  ['Harry Potter',
#   'Bellatrix Lestrange',
#   'Neville Longbottom',
#   'Harry Potter',
#   'Severus Snape',
#   "Jacob's sibling",
#   'Orion Amari',
#   'Skye Parkin',
#   'Ethan Parkin',
#   "Jacob's sibling"],
#  ['Harry Potter',
#   'Hermione Granger',
#   'Ginevra Weasley',
#   'Craig Bowker Junior',
#   'Harry Potter',
#   'Albus Dumbledore',
#   'Minerva McGonagall',
#   'Alastor Moody',
#   'Hermione Granger',
#   'Kingsley Shacklebolt'],
#  ['Harry Potter',
#   'Severus Snape',
#   'Marauders',
#   'Edward Lupin',
#   'Remus Lupin',
#   'Gilderoy Lockhart',
#   'Pomona Sprout',
#   'Gabriel Truman',
#   'Dugald McPhail'],
#  ['Harry Potter',
#   'Gilderoy Lockhart',
#   'Ronald Weasley',
#   '1996 Gryffindor Quidditch Keeper trials spectators',
#   'Harry Potter',
#   'Cormac McLaggen',
#   'Ronald Weasley',
#   'Harry Potter',
#   'Theodore Nott',
#   'Nott'],
#  ['Harry Potter',
#   'Lily J. Potter',
#   'Rose Granger-Weasley',
#   'Angelina Johnson',
#   'Anthony Goldstein',
#   'Marcus Turner',
#   'Darrel Turner'],
#  ['Harry Potter',
#   'Dean Thomas',
#   'Sirius Black',
#   'Cornelius Fudge',
#   'Minerva McGonagall',
#   'Craig Bowker Junior',
#   'Tom Riddle',
#   'Demelza Robins',
#   'Harry Potter',
#   'James Potter I'],
#  ['Harry Potter',
#   'Lily J. Potter',
#   'Draco Malfoy',
#   'Gregory Goyle',
#   'Peter Pettigrew',
#   'Jacob (Hogwarts student)',
#   'Patricia Rakepick',
#   'Barnaby Lee',
#   "Merula Snyde's gang",
#   'Merula Snyde'],
#  ['Harry Potter',
#   'Sirius Black',
#   'Rubeus Hagrid',
#   "Jacob's sibling",
#   'Patricia Rakepick',
#   'Narcissa Malfoy',
#   'James Potter I',
#   'Harry Potter',
#   'Sirius Black',
#   'Evan Rosier'],
#  ['Harry Potter',
#   'Theodore Nott',
#   'Albus Potter',
#   'Harry Potter',
#   'Leanne',
#   'Padma Patil',
#   'Albus Potter',
#   'Panju Weasley',
#   'Padma Patil',
#   'Ronald Weasley'],
#  ['Harry Potter',
#   'Angelina Johnson',
#   'James Potter II',
#   'William Weasley',
#   'Tom Riddle',
#   'Gang of Slytherins',
#   'Harry Potter',
#   'Colin Creevey',
#   'Dolores Umbridge',
#   'Minerva McGonagall'],
#  ['Harry Potter',
#   'Angelina Johnson',
#   'Rose Granger-Weasley',
#   'James Potter I',
#   'Severus Snape',
#   'Rodolphus Lestrange',
#   'Lucius Malfoy',
#   'Tom Riddle',
#   'Ernest Macmillan',
#   'Anthony Goldstein'],
#  ['Harry Potter',
#   'Romilda Vane',
#   'Amycus Carrow',
#   'Nicholas de Mimsy-Porpington',
#   'James Potter I',
#   'Quirinus Quirrell',
#   'Harry Potter',
#   'Angelina Johnson',
#   'Hermione Granger',
#   'Luna Lovegood'],
#  ['Harry Potter',
#   'Colin Creevey',
#   'Justin Finch-Fletchley',
#   'Harry Potter',
#   'Sybill Trelawney',
#   'Severus Snape',
#   'Alastor Moody',
#   'Elphias Doge',
#   'James Potter I',
#   'Marauders'],
#  ['Harry Potter',
#   'Hermione Granger',
#   'Rubeus Hagrid',
#   'Charles Weasley',
#   'Nymphadora Tonks',
#   'Alastor Moody',
#   'Bartemius Crouch Junior',
#   'Rodolphus Lestrange',
#   'Bellatrix Lestrange',
#   'Tom Riddle'],
#  ['Harry Potter',
#   'Lily J. Potter',
#   'Peter Pettigrew',
#   'Bartemius Crouch Junior',
#   'Bellatrix Lestrange',
#   'Tom Riddle',
#   'Hannah Abbott',
#   'Angelina Johnson',
#   'Alicia Spinnet',
#   'Ronald Weasley'],
#  ['Harry Potter', 'Martine Copplestone'],
#  ['Harry Potter',
#   'Tom Riddle',
#   'Gilderoy Lockhart',
#   'Trevor Birch',
#   'Horace Slughorn',
#   'Severus Snape',
#   'Quirinus Quirrell',
#   'Gilderoy Lockhart',
#   'Severus Snape',
#   'Phineas Nigellus Black'],
#  ['Harry Potter',
#   'Minerva McGonagall',
#   'Dolores Umbridge',
#   'Millicent Bulstrode',
#   'Millicent Bagnold',
#   'Cornelius Fudge',
#   'Marietta Edgecombe',
#   'Cho Chang',
#   'Cedric Diggory',
#   'Hannah Abbott'],
#  ['Harry Potter',
#   'Dean Thomas',
#   'Hermione Granger',
#   'Rose Granger-Weasley',
#   'Draco Malfoy',
#   'Harry Potter',
#   'Albus Dumbledore',
#   'Ronald Weasley',
#   'Harry Potter',
#   'Severus Snape'],
#  ['Harry Potter', 'Xander Lofthouse', 'Lina Tande', 'Sujita Tande'],
#  ['Harry Potter', 'Nanette Desford'],
#  ['Harry Potter',
#   'Susan Bones',
#   'Katie Bell',
#   'Alicia Spinnet',
#   'William Weasley',
#   'Charles Weasley',
#   'Arthur Weasley',
#   'Tom Riddle',
#   'Ronald Weasley',
#   'Severus Snape'],
#  ['Harry Potter',
#   'Daisy Corran',
#   'Justin Steele',
#   'Horace Slughorn',
#   'Lily J. Potter',
#   'Harry Potter',
#   'Ernest Macmillan',
#   'Seamus Finnigan',
#   'Bem',
#   'Angus Matlock'],
#  ['Harry Potter',
#   'Blaise Zabini',
#   'Gregory Goyle',
#   'Ernest Macmillan',
#   'Seamus Finnigan',
#   'Fred Weasley',
#   'James Potter II',
#   'Ginevra Weasley',
#   'Hermione Granger',
#   'Luna Lovegood'],
#  ['Harry Potter',
#   'Severus Snape',
#   'Remus Lupin',
#   'William Weasley',
#   'Callidora Black',
#   'Charis Black',
#   'Cedrella Black',
#   'Percy Weasley',
#   'Penelope Clearwater',
#   'Ginevra Weasley'],
#  ['Harry Potter',
#   'Peter Pettigrew',
#   'Cedric Diggory',
#   'Harry Potter',
#   'Rubeus Hagrid',
#   'Dolores Umbridge',
#   'Bem',
#   'Seamus Finnigan',
#   'Harry Potter',
#   'Shawn Morris'],
#  ['Harry Potter',
#   'Severus Snape',
#   'Albus Potter',
#   'Percy Weasley',
#   'Ginevra Weasley',
#   'Harry Potter',
#   'Kingsley Shacklebolt',
#   'Horace Slughorn',
#   'Lucius Malfoy',
#   'Narcissa Malfoy'],
#  ['Harry Potter',
#   'Fred Weasley',
#   'Ginevra Weasley',
#   'Luna Lovegood',
#   'Phineas Nigellus Black',
#   'Severus Snape',
#   'Terry Boot',
#   'Lee Jordan',
#   'George Weasley',
#   'Charles Weasley'],
#  ['Harry Potter',
#   'Ernest Macmillan',
#   'Draco Malfoy',
#   'Rodolphus Lestrange',
#   'Bartemius Crouch Junior',
#   'Draco Malfoy',
#   'Alicia Spinnet',
#   'Andrew Kirke',
#   'Ritchie Coote',
#   'Tom Riddle'],
#  ['Harry Potter',
#   'Edward Lupin',
#   'Victoire Weasley',
#   'Hermione Granger',
#   'Augusta Longbottom',
#   'Albus Dumbledore',
#   'Newton Scamander',
#   'Leta Lestrange',
#   'Albus Dumbledore',
#   'Ernest Prang'],
#  ['Harry Potter',
#   'Draco Malfoy',
#   'Pansy Parkinson',
#   'Gregory Goyle',
#   'Harry Potter',
#   'Hermione Granger',
#   'Ronald Weasley',
#   'Phineas Nigellus Black',
#   'Arthur Weasley',
#   'William Weasley'],
#  ['Harry Potter',
#   'Sean Peakes',
#   'Jimmy Peakes',
#   'Colin Creevey',
#   'Dolores Umbridge',
#   'Kingsley Shacklebolt',
#   'Nicholas de Mimsy-Porpington',
#   'Lavender Brown',
#   'Seamus Finnigan',
#   'Dean Thomas'],
#  ['Harry Potter',
#   'Remus Lupin',
#   'Neville Longbottom',
#   'Ronald Weasley',
#   'Salazar Slytherin',
#   'Corvinus Gaunt',
#   'Tom Riddle',
#   'Sirius Black',
#   'Alphard Black',
#   'Orion Black'],
#  ['Harry Potter',
#   'Lucius Malfoy',
#   'Scorpius Malfoy',
#   'Dorea Black',
#   'Callidora Black',
#   'Arthur Weasley',
#   'Molly Weasley',
#   'Ronald Weasley',
#   'Scorpius Malfoy',
#   'Theodore Nott'],
#  ['Harry Potter',
#   'Amycus Carrow',
#   'Ronald Weasley',
#   'George Weasley',
#   'Harry Potter',
#   'Colin Creevey',
#   'Dennis Creevey',
#   'Dolores Umbridge',
#   'George Weasley',
#   'James Potter I'],
#  ['Harry Potter',
#   'Ronald Weasley',
#   'Draco Malfoy',
#   'Theodore Nott',
#   "Draco Malfoy's gang",
#   'Horace Slughorn',
#   'Severus Snape',
#   'Narcissa Malfoy',
#   'Rodolphus Lestrange',
#   'Lucius Malfoy'],
#  ['Harry Potter',
#   'Ronald Weasley',
#   'Peter Pettigrew',
#   'Sirius Black',
#   'Kingsley Shacklebolt',
#   'Dolores Umbridge',
#   'Mundungus Fletcher',
#   'Jane Court',
#   'Hannah Abbott',
#   'Luna Lovegood'],
#  ['Harry Potter',
#   'Cedric Diggory',
#   'Myrtle Warren',
#   'Nymphadora Tonks',
#   'Alastor Moody',
#   'Harry Potter',
#   'Minerva McGonagall',
#   'Hermione Granger',
#   'Parvati Patil',
#   'Michael Corner'],
#  ['Harry Potter',
#   'Molly Weasley',
#   'Bellatrix Lestrange',
#   'Draco Malfoy',
#   'Craig Bowker Junior',
#   'Scorpius Malfoy',
#   'Ronald Weasley',
#   'Ethan Bexley',
#   'Harry Potter',
#   'Cormac McLaggen'],
#  ['Harry Potter',
#   'Sirius Black',
#   'Lucretia Black',
#   'Arthur Weasley',
#   'Bellatrix Lestrange',
#   'Severus Snape',
#   'Remus Lupin',
#   'Marauders',
#   'Harry Potter',
#   'Molly Weasley'],
#  ['Harry Potter',
#   'Draco Malfoy',
#   'Cedric Diggory',
#   'Diego Caplan',
#   'Gwenog Jones',
#   'Peter Jones',
#   'Megan Jones',
#   'Hannah Abbott',
#   'Albus Dumbledore',
#   'Nigel Wolpert'],
#  ['Harry Potter',
#   'Hermione Granger',
#   'Narcissa Malfoy',
#   'Patricia Rakepick',
#   "Jacob's sibling",
#   'Diego Caplan',
#   'Penny Haywood',
#   'Merula Snyde',
#   'William Weasley',
#   'Fred Weasley'],
#  ['Harry Potter',
#   'Cornelius Fudge',
#   'Kingsley Shacklebolt',
#   'Arthur Weasley',
#   'Charis Black',
#   'Dorea Black',
#   'Bellatrix Lestrange',
#   'Severus Snape',
#   'Seamus Finnigan',
#   'Kellah'],
#  ['Harry Potter',
#   'Rubeus Hagrid',
#   'Neville Longbottom',
#   'Ronald Weasley',
#   'Albus Dumbledore',
#   'Minerva McGonagall',
#   'Horace Slughorn',
#   'Callidora Black',
#   'Cedrella Black',
#   'Ginevra Weasley'],
#  ['Harry Potter',
#   'Neville Longbottom',
#   'Cormac McLaggen',
#   'Albus Dumbledore',
#   'Remus Lupin',
#   'George Weasley',
#   'James Potter II',
#   'Lily J. Potter',
#   'Harry Potter',
#   'Angelina Johnson'],
#  ['Harry Potter',
#   'Neville Longbottom',
#   'Ronald Weasley',
#   'Marietta Edgecombe',
#   'Angelina Johnson',
#   'Lee Jordan',
#   'Michael Corner',
#   'Molly Weasley',
#   'Angelina Johnson',
#   'Cho Chang'],
#  ['Harry Potter',
#   'Rubeus Hagrid',
#   'Albus Dumbledore',
#   'Harry Potter',
#   'Fleamont Potter',
#   'James Potter I',
#   'Cedric Diggory',
#   'Harry Potter',
#   'Sirius Black',
#   'Gang of Slytherins'],
#  ['Harry Potter',
#   'Molly Weasley',
#   'Arthur Weasley',
#   'Lucius Malfoy',
#   'Narcissa Malfoy',
#   'Andromeda Tonks',
#   'Alastor Moody',
#   'Alecto Carrow',
#   'Luna Lovegood',
#   'Garrick Ollivander'],
#  ['Harry Potter',
#   'James Potter II',
#   'Neville Longbottom',
#   'Pansy Parkinson',
#   "Draco Malfoy's gang",
#   'Horace Slughorn',
#   'Arthur Weasley',
#   'Bellatrix Lestrange',
#   'Draco Malfoy',
#   'Minerva McGonagall'],
#  ['Harry Potter',
#   'Sirius Black',
#   'Ronald Weasley',
#   'Percy Weasley',
#   'Albus Dumbledore',
#   'Cassius Warrington',
#   'Dolores Umbridge',
#   'Mundungus Fletcher',
#   "Jacob's sibling",
#   'Skye Parkin'],
#  ['Harry Potter',
#   'Narcissa Malfoy',
#   'Peter Pettigrew',
#   'Ronald Weasley',
#   'Vicky Frobisher'],
#  ['Harry Potter',
#   'Justin Finch-Fletchley',
#   'Neville Longbottom',
#   'Albus Dumbledore',
#   'John Dawlish',
#   'Helen Dawlish',
#   'Shoma Ichikawa',
#   'Harry Potter',
#   'Victoire Weasley',
#   'Ginevra Weasley'],
#  ['Harry Potter',
#   'Victoire Weasley',
#   'Hermione Granger',
#   'Dolores Umbridge',
#   'Neville Longbottom',
#   'Ronald Weasley',
#   'Rose Granger-Weasley',
#   'Albus Potter',
#   'Victoire Weasley',
#   'Charles Weasley'],
#  ['Harry Potter',
#   'Dennis Aldermaston',
#   'Gilderoy Lockhart',
#   "Jacob's sibling",
#   'Bean',
#   'Erika Rath',
#   'Andre Egwu',
#   'Brennan Doyle',
#   'Mary Doyle'],
#  ['Harry Potter',
#   'Hermione Granger',
#   'Ronald Weasley',
#   'Albus Dumbledore',
#   'Minerva McGonagall',
#   'Patricia Rakepick',
#   'Tulip Karasu',
#   'Merula Snyde',
#   'Liz Tuttle',
#   "Jacob's sibling"],
#  ['Harry Potter',
#   'Thomas Paley',
#   'Terrence Fogarty',
#   'Harry Potter',
#   'Luna Lovegood',
#   'Newton Scamander',
#   'Leta Lestrange',
#   'Theseus Scamander',
#   'Newton Scamander',
#   'Harry Potter'],
#  ['Harry Potter',
#   'Bellatrix Lestrange',
#   'Narcissa Malfoy',
#   'Pansy Parkinson',
#   'Astoria Malfoy',
#   'Draco Malfoy',
#   'Harry Potter',
#   'Trio',
#   'Hermione Granger',
#   'Draco Malfoy'],
#  ['Harry Potter',
#   'Luna Lovegood',
#   'Lily L. Potter',
#   'Ginevra Weasley',
#   'Trio',
#   'Hermione Granger',
#   'Cho Chang',
#   'Marietta Edgecombe',
#   'Dolores Umbridge',
#   'Ginevra Weasley'],
#  ['Harry Potter',
#   'Sirius Black',
#   'Patricia Rakepick',
#   "Jacob's sibling",
#   'Merula Snyde',
#   'Harry Potter',
#   'Sirius Black',
#   'Lucius Malfoy',
#   'Felix Rosier',
#   'Evan Rosier'],
#  ['Harry Potter',
#   'Rubeus Hagrid',
#   'Hermione Granger',
#   'Colin Creevey',
#   'Dennis Creevey',
#   'Susan Bones',
#   'Vincent Crabbe',
#   'Draco Malfoy',
#   'Ronald Weasley',
#   'Amycus Carrow'],
#  ['Harry Potter',
#   'Phineas Nigellus Black',
#   'Cornelius Fudge',
#   'Cedric Diggory',
#   'Cho Chang',
#   'Harry Potter',
#   'Molly Weasley',
#   'Sirius Black',
#   'Phineas Nigellus Black',
#   'Draco Malfoy'],
#  ['Harry Potter',
#   'Albus Dumbledore',
#   'Terry Boot',
#   'Anthony Goldstein',
#   'Justin Finch-Fletchley',
#   'Minerva McGonagall',
#   "Jacob's sibling",
#   'Garrick Ollivander',
#   'Peter Pettigrew',
#   'Sirius Black'],
#  ['Harry Potter',
#   'Tom Riddle',
#   'Severus Snape',
#   'Gilderoy Lockhart',
#   'Cecil Lee',
#   "Jacob's sibling",
#   'Alastor Moody',
#   'Bartemius Crouch Junior',
#   'Harry Potter',
#   'Augusta Longbottom'],
#  ['Harry Potter',
#   'Severus Snape',
#   'Albus Potter',
#   'James Potter II',
#   'Ginevra Weasley',
#   'Penelope Clearwater',
#   'Ronald Weasley',
#   'Hermione Granger',
#   'Harry Potter',
#   'Narcissa Malfoy']]

# %%
import gensim

epochs=20
alpha=0.03
min_alpha=alpha/epochs
vector_size=30

##

n2v_model=gensim.models.Word2Vec(
        alpha=alpha, 
        vector_size=vector_size,
        min_alpha=min_alpha, 
        sg = 1, # Sgrim gramm
        window=5,
        min_count=10, # pruning the internal dictionary. Words that appear only once or twice in a billion-word corpus are probably 
                     #uninteresting typos and garbageso it’s best to ignore them:,
        workers=cores,
        epochs=epochs
            )


n2v_model.build_vocab(walks)
print('nb of walks epochs: ',n2v_model.epochs)
print('nb of walks/sentences generated: ', n2v_model.corpus_count)
print('Size of embedding :',vector_size)
print('nb_characters with more than 5 occurences:',len(n2v_model.wv.key_to_index))

n2v_model.train(walks, total_examples=n2v_model.corpus_count, epochs=epochs, report_delay=1)
# Out:
# nb of walks epochs:  20
# nb of walks/sentences generated:  1200
# Size of embedding : 30
# nb_characters with more than 5 occurences: 254
# (289094, 564520)

# %%
n2v_model.wv.key_to_index
# Out:
# {'Harry Potter': 0,
#  'Tom Riddle': 1,
#  'Albus Dumbledore': 2,
#  "Jacob's sibling": 3,
#  'Ronald Weasley': 4,
#  'Hermione Granger': 5,
#  'Severus Snape': 6,
#  'Ginevra Weasley': 7,
#  'Minerva McGonagall': 8,
#  'Draco Malfoy': 9,
#  'Sirius Black': 10,
#  'Remus Lupin': 11,
#  'Neville Longbottom': 12,
#  'Rubeus Hagrid': 13,
#  'Dolores Umbridge': 14,
#  'Bellatrix Lestrange': 15,
#  'George Weasley': 16,
#  'Horace Slughorn': 17,
#  'Lucius Malfoy': 18,
#  'William Weasley': 19,
#  'Fred Weasley': 20,
#  'Luna Lovegood': 21,
#  'Arthur Weasley': 22,
#  'Molly Weasley': 23,
#  'Nymphadora Tonks': 24,
#  'Filius Flitwick': 25,
#  'Peter Pettigrew': 26,
#  'Percy Weasley': 27,
#  'Alastor Moody': 28,
#  'Lily J. Potter': 29,
#  'Albus Potter': 30,
#  'James Potter I': 31,
#  'Cedric Diggory': 32,
#  'Bartemius Crouch Junior': 33,
#  'Charles Weasley': 34,
#  'Angelina Johnson': 35,
#  'Kingsley Shacklebolt': 36,
#  'Merula Snyde': 37,
#  'Narcissa Malfoy': 38,
#  'Dean Thomas': 39,
#  'Penny Haywood': 40,
#  'Pomona Sprout': 41,
#  'Cornelius Fudge': 42,
#  'Patricia Rakepick': 43,
#  'Cho Chang': 44,
#  'Sybill Trelawney': 45,
#  'Seamus Finnigan': 46,
#  'Parvati Patil': 47,
#  'James Potter II': 48,
#  'Lee Jordan': 49,
#  'Lavender Brown': 50,
#  'Scorpius Malfoy': 51,
#  'Marauders': 52,
#  'Gilderoy Lockhart': 53,
#  'Gregory Goyle': 54,
#  'Andromeda Tonks': 55,
#  'Katie Bell': 56,
#  'Edward Lupin': 57,
#  'Ernest Macmillan': 58,
#  'Pansy Parkinson': 59,
#  'Amycus Carrow': 60,
#  'Hannah Abbott': 61,
#  'Barnaby Lee': 62,
#  'Ben Copper': 63,
#  'Mundungus Fletcher': 64,
#  'Rowan Khanna': 65,
#  'Aberforth Dumbledore': 66,
#  'Rose Granger-Weasley': 67,
#  'Alicia Spinnet': 68,
#  'Quirinus Quirrell': 69,
#  'Oliver Wood': 70,
#  'Vincent Crabbe': 71,
#  'Lily L. Potter': 72,
#  'Salazar Slytherin': 73,
#  'Alecto Carrow': 74,
#  'Regulus Black': 75,
#  'Myrtle Warren': 76,
#  "Draco Malfoy's gang": 77,
#  'Nicholas de Mimsy-Porpington': 78,
#  'Colin Creevey': 79,
#  'Ismelda Murk': 80,
#  'Rodolphus Lestrange': 81,
#  'Walburga Black': 82,
#  'Jacob (Hogwarts student)': 83,
#  'Zacharias Smith': 84,
#  'Rolanda Hooch': 85,
#  'Susan Bones': 86,
#  'Justin Finch-Fletchley': 87,
#  'John Dawlish': 88,
#  'Victoire Weasley': 89,
#  'Armando Dippet': 90,
#  'Phineas Nigellus Black': 91,
#  'Helena Ravenclaw': 92,
#  'Garrick Ollivander': 93,
#  'Newton Scamander': 94,
#  'Chiara Lobosca': 95,
#  'Michael Corner': 96,
#  'Padma Patil': 97,
#  'Cormac McLaggen': 98,
#  'Bloody Baron': 99,
#  'Xenophilius Lovegood': 100,
#  'Cedrella Black': 101,
#  'Orion Black': 102,
#  'Terry Boot': 103,
#  'Leta Lestrange': 104,
#  'Cygnus Black III': 105,
#  'Rowena Ravenclaw': 106,
#  'Augusta Longbottom': 107,
#  'Talbott Winger': 108,
#  'Silvanus Kettleburn': 109,
#  'Anthony Goldstein': 110,
#  'Theodore Nott': 111,
#  'Elphias Doge': 112,
#  'Andre Egwu': 113,
#  'Marietta Edgecombe': 114,
#  'Beatrice Haywood': 115,
#  'Romilda Vane': 116,
#  'Leanne': 117,
#  'Astoria Malfoy': 118,
#  'Fat Lady': 119,
#  'Head of Gryffindor House': 120,
#  'Marcus Flint': 121,
#  'Tulip Karasu': 122,
#  'Trio': 123,
#  'Dorea Black': 124,
#  'Gwenog Jones': 125,
#  'Dirk Cresswell': 126,
#  'Gang of Slytherins': 127,
#  'Godric Gryffindor': 128,
#  'Helga Hufflepuff': 129,
#  'Alphard Black': 130,
#  'Head of Slytherin House': 131,
#  'Evan Rosier': 132,
#  'Charis Black': 133,
#  'Skye Parkin': 134,
#  'Theseus Scamander': 135,
#  'Avery II': 136,
#  'Callidora Black': 137,
#  'Cassius Warrington': 138,
#  'Cassiopeia Black': 139,
#  'Cadogan': 140,
#  'Millicent Bulstrode': 141,
#  'Head of Hufflepuff House': 142,
#  'Cecil Lee': 143,
#  'Liz Tuttle': 144,
#  'Penelope Clearwater': 145,
#  'Nigel Wolpert': 146,
#  'Bertha Jorkins': 147,
#  'Abraxas Malfoy': 148,
#  'Fleamont Potter': 149,
#  'Panju Weasley': 150,
#  'Dennis Creevey': 151,
#  'Nott': 152,
#  'Kellah': 153,
#  'Lucretia Black': 154,
#  'Badeea Ali': 155,
#  'Fat Friar': 156,
#  'Erika Rath': 157,
#  'Jae Kim': 158,
#  'Ritchie Coote': 159,
#  'Lyall Lupin': 160,
#  'Bem': 161,
#  'Wilkes': 162,
#  'Roger Davies': 163,
#  'Marcus Belby': 164,
#  'Head of Ravenclaw House': 165,
#  'Blaise Zabini': 166,
#  'Merlin': 167,
#  'Ethan Parkin': 168,
#  'Jimmy Peakes': 169,
#  'Ivy Warrington': 170,
#  'Emily Tyler': 171,
#  "Merula Snyde's mother": 172,
#  'Orion Amari': 173,
#  'Gemma Farley': 174,
#  'Daphne Greengrass': 175,
#  'Angelica Cole': 176,
#  'Wilfred Levi Kidd': 177,
#  'Roger Malone': 178,
#  'Grim Fawley': 179,
#  'Eileen Prince': 180,
#  'Damocles Belby': 181,
#  "Tom Riddle's gang": 182,
#  'Graham Montague': 183,
#  'M. G. McGonagall': 184,
#  'Millicent Bagnold': 185,
#  'Duncan Ashe': 186,
#  "Merula Snyde's father": 187,
#  'Mulciber II': 188,
#  'Diego Caplan': 189,
#  'Olive Hornby': 190,
#  'Megan Jones': 191,
#  'Donaghan Tremlett': 192,
#  'Pippa Macmillan': 193,
#  'Oliver Rivers': 194,
#  'Corey Hayden': 195,
#  'Chester Davies': 196,
#  'Karl Jenkins': 197,
#  'Daniel Page': 198,
#  'Araminta Meliflua Black': 199,
#  'Pike': 200,
#  'Cassandra Vole': 201,
#  'Scabior': 202,
#  'Stephen Cornfoot': 203,
#  'Mary Macdonald': 204,
#  'Lucian Bole': 205,
#  'Kevin Entwhistle': 206,
#  'Boy who kept a bezoar in his pocket': 207,
#  "Merula Snyde's gang": 208,
#  'Miles Bletchley': 209,
#  'Andrew Kirke': 210,
#  'Terence Higgs': 211,
#  'Yann Fredericks': 212,
#  'Colby Frey': 213,
#  'Angus Matlock': 214,
#  'Murphy McNully': 215,
#  'Fawcett': 216,
#  'Bunty': 217,
#  'Felix Rosier': 218,
#  "Rionach O'Neal": 219,
#  'Jack Sloper': 220,
#  'Adrian Pucey': 221,
#  'Harper': 222,
#  'Myron Wagtail': 223,
#  'Craig Bowker Junior': 224,
#  'Fischer Frey': 225,
#  'Flora Carrow': 226,
#  'Robert Hilliard': 227,
#  'Valeria Myriadd': 228,
#  'Girl who played Asha': 229,
#  'Penelope Fawley': 230,
#  'Jane Court': 231,
#  'Hestia Carrow': 232,
#  'Constance Pickering': 233,
#  'Eloise Midgen': 234,
#  'Isobel Ross': 235,
#  'Billingsley': 236,
#  "Erika Rath's friend (II)": 237,
#  'Mandy Brocklehurst': 238,
#  'Amanda': 239,
#  'Gormlaith Gaunt': 240,
#  'Robyn Thistlethwaite': 241,
#  'Avery I': 242,
#  'Tobias Stump': 243,
#  'Kevin Farrell': 244,
#  'Demelza Robins': 245,
#  'Lestrange': 246,
#  'Sally-Anne Perks': 247,
#  'Summerby': 248,
#  "James Potter II's friends": 249,
#  'Carl Hopkins': 250,
#  'D. L. Boot': 251,
#  'Bilton Bilmes': 252,
#  'Eldred Worple': 253}

# %%
vector = n2v_model.wv['Harry Potter'] 
print(len(vector))
vector
# Out:
# 30
# array([ 0.04138071, -0.02139988,  0.3747029 ,  0.07868609, -0.00921261,
#        -0.05916784, -0.03920813, -0.02009424, -0.3782749 , -0.24958086,
#         0.5202384 ,  0.00828949,  0.06715899, -0.2016349 , -0.11477514,
#        -0.07410303,  0.30907792, -0.27851468, -0.12647837, -0.06339805,
#        -0.02342661, -0.11938197, -0.0639893 ,  0.4236275 ,  0.15120196,
#         0.28688836, -0.03136272,  0.3262713 , -0.24332225, -0.2332754 ],
#       dtype=float32)

# %%
print('Most similar to Harry the Fuck Potter !')
print('\n')
for w in n2v_model.wv.most_similar(positive=['Harry Potter'], topn=10):
    print(w)
# Out:
# Most similar to Harry the Fuck Potter !
#
#
# ('Hermione Granger', 0.8525440096855164)
# ('Ronald Weasley', 0.8301417231559753)
# ('Tom Riddle', 0.8125330805778503)
# ('Dolores Umbridge', 0.7858249545097351)
# ('Severus Snape', 0.7594401836395264)
# ('George Weasley', 0.7538095712661743)
# ('Albus Dumbledore', 0.7367588877677917)
# ('Luna Lovegood', 0.7323964834213257)
# ('Ginevra Weasley', 0.7002020478248596)
# ('Remus Lupin', 0.6994820833206177)

# %%
print('Most similar to Harry the Fuck Potter !')
print('\n')
for w in n2v_model.wv.most_similar(positive=['Ginevra Weasley'], topn=10):
    print(w)
# Out:
# Most similar to Harry the Fuck Potter !
#
#
# ('Dolores Umbridge', 0.760675311088562)
# ('Hermione Granger', 0.7558061480522156)
# ('Molly Weasley', 0.7555997371673584)
# ('Ronald Weasley', 0.7516549229621887)
# ('Demelza Robins', 0.7320825457572937)
# ('Fred Weasley', 0.7120221853256226)
# ('George Weasley', 0.7116307616233826)
# ('Harry Potter', 0.7002020478248596)
# ('Constance Pickering', 0.6785751581192017)
# ('Lily L. Potter', 0.6688311100006104)

# %% [markdown]
# # FINAL PROJECT

# %% [markdown]
# Talk about how you've worked with text, including regular expressions, unicode, etc.
# Describe which network science tools and data analysis strategies you've used, how those network science measures work, and why the tools you've chosen are right for the problem you're solving.
# How did you use the tools to understand your dataset?

# %% [markdown]
# ### 3.5 Project 5: Node to vector: Similarity between characters <a class="anchor" id="s3_5"></a>

# %% [markdown]
# #### 3.5.1 Motivation

# %% [markdown]
# This graph made with the Fandom Wiki has some underlying knowledge that can be extracted by it structure.
# The Louvain community algorithm helped us to understand some of the structure by clustering individuals in group also know as community. However, this does not help us to get information on a node level.
#
# For instance, what is the most similar/close character to Harry Potter?
# With the Louvain community algorithm, I can only say that Harry potter belong to a certain community but nothing more. May I do better with?

# %% [markdown]
# #### 3.5.2 Tool: Node to vector:

# %% [markdown]
# **Prerequisite: Skim gram model**
# If you are familiar with the word2vec skip-gram model, great, if not I recommend this great post (http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/)  which explains it in great detail as from this point forward I assume you are familiar with it.
#
# The skip-gram neural network model is actually surprisingly simple in its most basic form. Train a simple neural network with a single hidden layer to perform a certain task, but then we’re not actually going to use that neural network for the task we trained it on! Instead, the goal is actually just to learn the weights of the hidden layer–we’ll see that these weights are actually the “word vectors” that we’re trying to learn.
#
# <img src="Generation_skip.png" alt="Generation_skip" width="400" style="float: center;" title="Generation_skip"/>
#
# <img src="training.png" alt="training" width="700" style="float: center;" title="Training"/>

# %% [markdown]
# **Node2vec is an algorithm to generate vector representations of nodes on a graph. node2vec follows the intuition that random walks through a graph can be treated like sentences in a corpus. Each node in a graph is treated like an individual word, and a random walk is treated as a sentence.**
#
# By feeding these "sentences" into a skip-gram, or by using the continuous bag of words model paths found by random walks can be treated as sentences, and traditional data-mining techniques for documents can be used.
#
# The algorithm generalizes prior work which is based on rigid notions of network neighborhoods, and argues that the added flexibility in exploring neighborhoods is the key to learning richer representations of nodes in graphs. The algorithm is an extension of Gensim's word2vec algorithm, and is considered one of the best classifiers for nodes in a graph.
#
# The algorithm follow 2 steps: Generation of a chain of nodes with a sampling strategy and training of a Word2vector algorithm such as the skim-gram model.
#
# <img src="node_to_vect.png" alt="Node to vector" width="1500" style="float: center;" title="Node to vector"/>
#
# High level process:
# > 1. From a graph, start from a node and generate a defined number of walks through the network with a certain length, that I will call "Sentence". For instance (Node 1 -> Node 5 -> Node 8 -> Node 6)
# > 2. Each of the sentences will be used to train a Word2vector and the output will attached for each unique node, a unique vector.
# > 3. This vector can be compared with other vector by using the cosine similarity
# > 4. The most similar vectors can be traceback to their nodes.
#
# For more information, I recommend you to have a look at this create post: https://towardsdatascience.com/node2vec-embeddings-for-graph-data-32a866340fef

# %% [markdown]
# **Example: What is the node that is the most similar to the node 1**
# > Step 1: Sentences generation
# > * (Node 1 -> Node 5 -> Node 8 -> Node 6)
# > * (Node 4 -> Node 2 -> Node 10 -> Node 14)
# > * ...
# > * (Node 3 -> Node 54 -> Node 8 -> Node 25)
#
# > Step 2: Training of a Word2vector and generation of a unique vector for each node
# > * Node 1: vec_node_1=[0.1,0.53,0.958]
# > * Node 2: vec_node_2=[-0.7,0.1,-0.4]
# > * ...
# > * Node 76: vec_node_76=[-0.1,-0.5,0.6]
#
# > Step 3: Compute the cosinus similarity to between each node:
# > * (Node 1, Node 2)= cosinus_similarity (vec_node_1,vec_node_2)= 0.6
# > * ...
# > * (Node 1, Node 76)= cosinus_similarity (vec_node_1,vec_node_76)= 0.3
#
# > Step 4: Sorting the cosinus similarity of the node 1 with all the nodes and return the most similar one
# > * Most_similar(Node 1) = Node 5

# %% [markdown]
# #### 3.5.3 Apply the tool: Node to vector:

# %%
# Import 
import multiprocessing
from stellargraph.data import BiasedRandomWalk
from stellargraph import StellarGraph
cores = multiprocessing.cpu_count() # Count the number of cores in a computer

import gensim
from collections import Counter
import pickle

# %%
# Creation of the graph with weight
with open(r"pickle_network_final.txt", "rb") as fp:   # Unpickling
    df = pickle.load(fp)

def characters_connections(name,page_path= "Description/"):
    with open(page_path+name+'.txt','r') as f:
        node_description= f.read()

    new_reg_link = r'\[\[(.*?)(?:\|.*?)?\]\]'

    caracters_in_page=[]
    linked_names_quick= re.findall(new_reg_link,node_description)
    for element in linked_names_quick:
        if element in list(df.Name) and element !=name:
            caracters_in_page.append(element)
    try:
#         final=normalize(Counter(caracters_in_page),target=1) 
        final=Counter(caracters_in_page)
    except:
        final ={}
    return final

# sorted(characters_connections('Harry Potter').items(), key=lambda x: x[1], reverse=True) 
from tqdm import tqdm
characters_connections_list={}
for name in tqdm(list(df['Name'])):
    characters_connections_list[name]=characters_connections(name)
df_weight =df.copy() 
df_weight.reset_index(inplace=True,drop=True)
df_weight['poids_lien']=list(characters_connections_list.values())

G_weight = nx.DiGraph()
for index, row in df_weight.iterrows():
    G_weight.add_node(row['Name'], House=row['House'], Gender=row['Gender'],Blood=row['Blood'],Species=row['Species'] \
                          , Nationality=row['Nationality'], Heigh=row['Heigh'],Weight=row['Weight'],Eyes=row['Eyes'] \
                          ,Skin=row['Skin'])
G_weight.nodes()
    
keys_=df_weight['Name'].values
values_=df_weight['poids_lien'].values
dictionary_poids_lien= dict(zip(keys_, values_))

weigh_list=[]
for name,mini_dict in dictionary_poids_lien.items():
    for keys,weight_values in mini_dict.items():
            G_weight.add_edge(name,keys,weight =weight_values)
            weigh_list.append(weight_values)
# Out:
# 100%|██████████| 511/511 [00:11<00:00, 43.56it/s]

# %%
df_weight['all_degree']=np.array([G_weight.degree(n) for n in G_weight.nodes()])

def top_x_names_by_all_degree(top=20):
    return list(df_weight.sort_values(by='all_degree',ascending=False)['Name'][:top].values)

def generate_walk(graph #graph: Input graph
                  ,node="" # root nodes for the walk
                  ,walk_length=30 #walk_length: Number of nodes in each walk (default: 30)
                  , num_walks=10 #num_walks: Number of walks per node (default: 10)
#                    , worker=cores #workers: Number of workers for parallel execution (default: 1)
                  , p = 1 #p: Return hyper parameter (default: 1)
                  , q = 1 #q: Inout parameter (default: 1)):
                  , weighted=True # if edge has weight
                  ,  seed=42 # random seed fixed for reproducibility
                     ):
    if node =="":
        node= graph.nodes()
    
    rw = BiasedRandomWalk(StellarGraph.from_networkx(G_weight,edge_weight_attr='weight'))
    
    return rw.run(
        nodes=node,  # root nodes
        length=walk_length,  # maximum length of a random walk
        n=num_walks,  # number of random walks per root node
        p=p,  # Defines (unormalised) probability, 1/p, of returning to source node
        q=q,  # Defines (unormalised) probability, 1/q, for moving away from source node
        weighted=weighted,  # for  biaised random walks
        seed=seed,  # random seed fixed for reproducibility
    )

# %%
walks=generate_walk(G_weight #graph: Input graph
                  ,node=top_x_names_by_all_degree(30) #Initial node for starting the walk
                  ,walk_length=25 # Size of the walk
                  , num_walks=40 #Nb of walks generated from each initial node
                  , p = 2  # Defines (unormalised) probability, 1/p, of returning to source node
                  , q = 0.5 # Defines (unormalised) probability, 1/q, for moving away from source node
                  , weighted=True
                   ,  seed=42)
print('{} Walks Generated for a total of {} nodes'.format(len(walks),len(walks)*40))
# Out:
# 1200 Walks Generated for a total of 48000 nodes

# %%
class DictList(dict):
    def __setitem__(self, key, value):
        try:
            # Assumes there is a list on the key
            self[key].append(value)
        except KeyError: # If it fails, because there is no key
            super(DictList, self).__setitem__(key, value)
        except AttributeError: # If it fails because it is not a list
            super(DictList, self).__setitem__(key, [self[key], value])
dl_sampling = DictList()

walks_bis=walks[:]
character = [element[0] for element in walks_bis]
zip_iterator = zip(character, walks_bis)
for key,values in zip_iterator:
    dl_sampling[key]=values
dl_sampling['Harry Potter']
# Out:
# ['Harry Potter',
#  'Nandini Johar',
#  ['Harry Potter',
#   'Lily L. Potter',
#   'Hermione Granger',
#   'Helena Ravenclaw',
#   'Bloody Baron',
#   'Harry Potter',
#   'Nicholas de Mimsy-Porpington',
#   'Angelica Cole',
#   'Charles Weasley',
#   'Oliver Wood',
#   'Minerva McGonagall',
#   'Arthur Weasley',
#   'Lily L. Potter',
#   'Ronald Weasley',
#   'Severus Snape',
#   'Neville Longbottom',
#   'Minerva McGonagall',
#   'Craig Bowker Junior',
#   'Harry Potter',
#   'Sybill Trelawney',
#   'Ronald Weasley',
#   'Gwenog Jones',
#   'Horace Slughorn',
#   'Tom Riddle',
#   'Dean Thomas'],
#  ['Harry Potter',
#   'James Potter I',
#   "James Potter II's friends",
#   'James Potter II',
#   'Edward Lupin',
#   'Dorea Black',
#   'Cedrella Black',
#   'Charis Black',
#   'Bartemius Crouch Junior',
#   'Alastor Moody',
#   'Harry Potter',
#   'Euan Abercrombie'],
#  ['Harry Potter',
#   'Garrick Ollivander',
#   'Nymphadora Tonks',
#   'Molly Weasley',
#   'William Weasley',
#   'Percy Weasley',
#   'Rubeus Hagrid',
#   'Mauricius',
#   'Vincent Crabbe',
#   'Millicent Bulstrode',
#   'Luna Lovegood',
#   'Sirius Black',
#   'Cassiopeia Black',
#   'Dorea Black',
#   'James Potter II',
#   'Ginevra Weasley',
#   'Remus Lupin',
#   'Gregory Goyle',
#   'Dolores Umbridge',
#   'George Weasley',
#   'Ginevra Weasley',
#   'Rubeus Hagrid',
#   'Dolores Umbridge',
#   'Angelina Johnson',
#   'George Weasley'],
#  ['Harry Potter',
#   'Hengist of Woodcroft',
#   'Gabriel Truman',
#   'Bridget Wenlock',
#   'Bridget'],
#  ['Harry Potter',
#   'Tom Riddle',
#   'Myrtle Warren',
#   'Olive Hornby',
#   'Armando Dippet',
#   'Albus Dumbledore',
#   'Zacharias Smith',
#   'Minerva McGonagall',
#   'Rubeus Hagrid',
#   'Ronald Weasley',
#   'Eloise Midgen',
#   'Minerva McGonagall',
#   'Harry Potter',
#   'Albus Dumbledore',
#   "Jacob's sibling",
#   'Ben Copper',
#   'Uric the Oddball',
#   'Robert Hilliard',
#   'Marcus Turner',
#   'Darrel Turner'],
#  ['Harry Potter',
#   'Albus Dumbledore',
#   'Mundungus Fletcher',
#   'Tom Riddle',
#   'Hannah Abbott',
#   'Ernest Macmillan',
#   'Colin Creevey',
#   'Oliver Wood',
#   'Sirius Black',
#   'Bellatrix Lestrange',
#   'Draco Malfoy',
#   'Hannah Abbott',
#   'Hermione Granger',
#   'Trio',
#   'Mafalda',
#   'Hermione Granger',
#   'Gilderoy Lockhart',
#   'Lucius Malfoy',
#   'Arthur Weasley',
#   'Cornelius Fudge',
#   'Phineas Nigellus Black',
#   'Severus Snape',
#   'Bellatrix Lestrange',
#   'Ginevra Weasley',
#   'Luna Lovegood'],
#  ['Harry Potter',
#   'Minerva McGonagall',
#   'Grim Fawley',
#   'Alecto Carrow',
#   'Neville Longbottom',
#   'Luna Lovegood',
#   'Albus Dumbledore',
#   'Percy Weasley',
#   'Remus Lupin',
#   'Ronald Weasley',
#   'Ginevra Weasley',
#   'Hermione Granger',
#   'Ronald Weasley',
#   'Demelza Robins',
#   'Harry Potter',
#   'Dolores Umbridge',
#   'Albus Dumbledore',
#   'Kingsley Shacklebolt',
#   'Hermione Granger',
#   'Ginevra Weasley',
#   'Draco Malfoy',
#   'Harry Potter',
#   'Oliver Wood',
#   'Fred Weasley',
#   'Dolores Umbridge'],
#  ['Harry Potter',
#   'Ronald Weasley',
#   'Luna Lovegood',
#   'Xenophilius Lovegood',
#   'Dirk Cresswell',
#   'Horace Slughorn',
#   'Minerva McGonagall',
#   'Valeria Myriadd',
#   'Head of Gryffindor House',
#   'M. G. McGonagall',
#   'Minerva McGonagall',
#   'Myrtle Warren',
#   'Cedric Diggory',
#   'Oliver Wood',
#   'Charles Weasley',
#   'William Weasley',
#   'Lee Jordan',
#   'Harry Potter',
#   'Mundungus Fletcher',
#   'Aberforth Dumbledore',
#   'Sybill Trelawney',
#   'Minerva McGonagall',
#   'Duncan Ashe',
#   'Mundungus Fletcher',
#   'Harry Potter'],
#  ['Harry Potter',
#   'Ginevra Weasley',
#   'Luna Lovegood',
#   'Narcissa Malfoy',
#   'Cygnus Black III',
#   'Araminta Meliflua Black',
#   'Alphard Black',
#   'Fleamont Potter',
#   'Harry Potter',
#   'Albus Dumbledore',
#   'Remus Lupin',
#   'Harry Potter',
#   'Dean Thomas',
#   'Cedric Diggory',
#   'Diego Caplan',
#   "Jacob's sibling",
#   'William Weasley',
#   'Molly Weasley',
#   'Remus Lupin',
#   'Hermione Granger',
#   'Phineas Nigellus Black',
#   'Callidora Black',
#   'Dorea Black',
#   'Trio',
#   'Sirius Black'],
#  ['Harry Potter',
#   'Draco Malfoy',
#   'Quirinus Quirrell',
#   'Tom Riddle',
#   "Jacob's sibling",
#   'Jane Court',
#   'Chester Davies',
#   'Penny Haywood',
#   'Severus Snape',
#   'Bellatrix Lestrange',
#   'Lucius Malfoy',
#   'Draco Malfoy',
#   'Colin Creevey',
#   'Marietta Edgecombe',
#   'Parvati Patil',
#   'Dolores Umbridge',
#   'Albus Dumbledore',
#   'Patricia Rakepick',
#   "Jacob's sibling",
#   'Chiara Lobosca',
#   'Cecil Lee',
#   'Barnaby Lee',
#   'Ismelda Murk',
#   "Ismelda Murk's sister"],
#  ['Harry Potter',
#   'Tom Riddle',
#   'Amycus Carrow',
#   'Draco Malfoy',
#   'Tom Riddle',
#   'Sirius Black',
#   'Arthur Weasley',
#   'Tom Riddle',
#   'Helena Ravenclaw',
#   'Kingsley Shacklebolt',
#   'Harry Potter',
#   'Lavender Brown',
#   'Sybill Trelawney',
#   'Xenophilius Lovegood',
#   'Ismelda Murk',
#   "Jacob's sibling",
#   'Tulip Karasu',
#   'Nymphadora Tonks',
#   'Harry Potter',
#   'Gillian Ossett'],
#  ['Harry Potter',
#   'Albus Dumbledore',
#   'Hermione Granger',
#   'William Weasley',
#   'Patricia Rakepick',
#   "Jacob's sibling",
#   'Orion Amari',
#   'Skye Parkin',
#   'Murphy McNully',
#   'Lee Jordan',
#   'Fred Weasley',
#   'Percy Weasley',
#   'Ronald Weasley',
#   'Michael Corner',
#   'Kevin Entwhistle',
#   'Oliver Rivers',
#   'Anthony Goldstein',
#   'Dolores Umbridge',
#   'Minerva McGonagall',
#   'Horace Slughorn',
#   'Theodore Nott',
#   'Lucius Malfoy',
#   'Bellatrix Lestrange',
#   'Lestrange',
#   'Rodolphus Lestrange'],
#  ['Harry Potter',
#   'Chiara Lobosca',
#   'Liz Tuttle',
#   "Jacob's sibling",
#   'Talbott Winger',
#   'Penny Haywood',
#   'Albus Dumbledore',
#   'Draco Malfoy',
#   'Severus Snape',
#   'Arthur Weasley',
#   'Lucretia Black',
#   'Molly Weasley',
#   'Bellatrix Lestrange',
#   'Nymphadora Tonks',
#   "Jacob's sibling",
#   'Elora Dunn',
#   'Craig Dunn'],
#  ['Harry Potter',
#   'Boy who kept a bezoar in his pocket',
#   'Severus Snape',
#   'Merula Snyde',
#   "Merula Snyde's gang",
#   'Jacob (Hogwarts student)',
#   'Albus Dumbledore',
#   'Severus Snape',
#   'Minerva McGonagall',
#   'George Weasley',
#   'Molly Weasley',
#   'Albus Dumbledore',
#   'Leta Lestrange',
#   'Bellatrix Lestrange',
#   'Albus Dumbledore',
#   'Lily J. Potter',
#   'Alastor Moody',
#   'Filius Flitwick',
#   'Draco Malfoy',
#   'Garrick Ollivander',
#   'Lily J. Potter',
#   'Harry Potter',
#   'Lee Jordan',
#   'Roger Davies',
#   'Davies'],
#  ['Harry Potter',
#   'Albus Dumbledore',
#   'Patricia Rakepick',
#   'Rowan Khanna',
#   'Barnaby Lee',
#   "Jacob's sibling",
#   'Billingsley',
#   'Minerva McGonagall',
#   'Draco Malfoy',
#   'Harry Potter',
#   'Nanette Desford'],
#  ['Harry Potter',
#   'Eldred Worple',
#   'Horace Slughorn',
#   'Arthur Weasley',
#   'Nymphadora Tonks',
#   'Talbott Winger',
#   'Penny Haywood',
#   'Beatrice Haywood',
#   'Merlin',
#   "Jacob's sibling",
#   'Patricia Rakepick',
#   'Horace Slughorn',
#   'Andromeda Tonks',
#   'Orion Black',
#   'Sirius Black',
#   'Head of Gryffindor House',
#   'Neville Longbottom',
#   'Amycus Carrow',
#   'Harry Potter',
#   'Neville Longbottom',
#   'Colin Creevey',
#   'Cedric Diggory',
#   'Bartemius Crouch Junior',
#   'Tom Riddle',
#   'Scorpius Malfoy'],
#  ['Harry Potter',
#   'Severus Snape',
#   'Draco Malfoy',
#   'Remus Lupin',
#   'Fred Weasley',
#   'Draco Malfoy',
#   'Lucius Malfoy',
#   'Remus Lupin',
#   'Alastor Moody',
#   "Jacob's sibling",
#   'Patricia Rakepick',
#   'Jacob (Hogwarts student)',
#   "Jacob's sibling",
#   'Rubeus Hagrid',
#   "Draco Malfoy's gang",
#   'Pike',
#   'Gregory Goyle',
#   'Susan Bones',
#   'Cedric Diggory',
#   'Oliver Wood',
#   'Charles Weasley',
#   'George Weasley',
#   'Hermione Granger',
#   'Kingsley Shacklebolt',
#   'Minerva McGonagall'],
#  ['Harry Potter',
#   'George Weasley',
#   'Remus Lupin',
#   'Bellatrix Lestrange',
#   'Luna Lovegood',
#   'Tom Riddle',
#   'Helga Hufflepuff',
#   'Salazar Slytherin',
#   'Tom Riddle',
#   'Lucius Malfoy',
#   'Cornelius Fudge',
#   'Harry Potter',
#   'Lynette Sawley',
#   'Molly Weasley',
#   'Ginevra Weasley',
#   'Zacharias Smith',
#   'Horace Slughorn',
#   'Theodore Nott',
#   'Hermione Granger',
#   'Molly Weasley',
#   'George Weasley',
#   'Ronald Weasley',
#   'Albus Dumbledore',
#   'Harry Potter',
#   'Dean Thomas'],
#  ['Harry Potter',
#   'Filius Flitwick',
#   'Cornelius Fudge',
#   'Minerva McGonagall',
#   'Talbott Winger',
#   "Jacob's sibling",
#   'Tulip Karasu',
#   'Nymphadora Tonks',
#   'Albus Dumbledore',
#   'Peter Pettigrew',
#   'Severus Snape',
#   'Lily J. Potter',
#   'Mulciber II',
#   'Tom Riddle',
#   'Arthur Weasley',
#   'Harry Potter',
#   'Draco Malfoy',
#   'Abraxas Malfoy',
#   'Lucius Malfoy',
#   'Severus Snape',
#   'Helena Ravenclaw',
#   'Harry Potter',
#   'Rubeus Hagrid',
#   'Tom Riddle',
#   'Alicia Spinnet'],
#  ['Harry Potter',
#   'Rubeus Hagrid',
#   'Cornelius Fudge',
#   'Marietta Edgecombe',
#   'Cho Chang',
#   'Draco Malfoy',
#   'Bellatrix Lestrange',
#   'Tom Riddle',
#   'Horace Slughorn',
#   'Severus Snape',
#   'Arthur Weasley',
#   'Harry Potter',
#   'Mundungus Fletcher',
#   'Sirius Black',
#   'Harry Potter',
#   'Elphias Doge',
#   'Lily J. Potter',
#   'Harry Potter',
#   'Lee Jordan',
#   'Dolores Umbridge',
#   'Hermione Granger',
#   'Charles Weasley',
#   "Jacob's sibling",
#   'Chiara Lobosca',
#   'Rowan Khanna'],
#  ['Harry Potter',
#   'J. E. Prewitt',
#   'D. L. Boot',
#   'Terry Boot',
#   'Alicia Spinnet',
#   'Marietta Edgecombe',
#   'Cho Chang',
#   'Anthony Goldstein',
#   'Dolores Umbridge',
#   'Parvati Patil',
#   'Alicia Spinnet',
#   'Colin Creevey',
#   'Draco Malfoy',
#   'Rose Granger-Weasley',
#   'Albus Potter',
#   'Luna Lovegood',
#   'Sirius Black',
#   'Cornelius Fudge',
#   'Bellatrix Lestrange',
#   'Molly Weasley',
#   'Michael Corner',
#   'Cho Chang',
#   'Roger Davies',
#   'William Weasley',
#   'Emily Tyler'],
#  ['Harry Potter',
#   'Hermione Granger',
#   'Molly Weasley',
#   'Severus Snape',
#   'Hannah Abbott',
#   'Neville Longbottom',
#   'Lavender Brown',
#   'Ronald Weasley',
#   'Pomona Sprout',
#   'Head of Hufflepuff House',
#   'Head of Ravenclaw House',
#   'Filius Flitwick',
#   'Jacob (Hogwarts student)',
#   "Jacob's sibling",
#   'Orion Amari',
#   "Erika Rath's friend (I)",
#   'Rolanda Hooch',
#   'Andre Egwu',
#   'Erika Rath',
#   'Gwenog Jones',
#   'Hermione Granger',
#   'Horace Slughorn',
#   'Kingsley Shacklebolt',
#   'Albus Dumbledore',
#   'Rubeus Hagrid'],
#  ['Harry Potter',
#   'Bellatrix Lestrange',
#   'Sirius Black',
#   'Evan Rosier',
#   'Bellatrix Lestrange',
#   'Narcissa Malfoy',
#   'Severus Snape',
#   'Eileen Prince',
#   'Hermione Granger',
#   'Ernest Macmillan',
#   'Justin Finch-Fletchley',
#   'Vincent Crabbe',
#   'Sirius Black',
#   'Kingsley Shacklebolt',
#   'Tom Riddle',
#   'Angus Matlock',
#   'Michael',
#   'Dolores Umbridge',
#   'Alicia Spinnet',
#   'Katie Bell',
#   'Angelina Johnson',
#   'Oliver Wood',
#   'Colin Creevey',
#   'Hermione Granger',
#   'Harry Potter'],
#  ['Harry Potter',
#   'Minerva McGonagall',
#   'Lee Jordan',
#   'Dean Thomas',
#   'Neville Longbottom',
#   'Minerva McGonagall',
#   'Harry Potter',
#   'Ginevra Weasley',
#   'Luna Lovegood',
#   'Harry Potter',
#   'Horace Slughorn',
#   'Albus Dumbledore',
#   "Jacob's sibling",
#   'Penny Haywood',
#   'Chiara Lobosca',
#   "Jacob's sibling",
#   'Rowan Khanna',
#   'Merula Snyde',
#   'Draco Malfoy',
#   'Rubeus Hagrid',
#   'Quirinus Quirrell',
#   'Tom Riddle',
#   'Orion Black',
#   'Regulus Black',
#   'Albus Dumbledore'],
#  ['Harry Potter', 'Niles Hanley'],
#  ['Harry Potter',
#   'Penelope Clearwater',
#   'Percy Weasley',
#   'Kingsley Shacklebolt',
#   'Nymphadora Tonks',
#   'Narcissa Malfoy',
#   'Lucius Malfoy',
#   'Arthur Weasley',
#   'Sirius Black',
#   'James Potter II',
#   'Ginevra Weasley',
#   'Hermione Granger',
#   'George Weasley',
#   'Angelina Johnson',
#   'Katie Bell',
#   'Tom Riddle',
#   'Eileen Prince',
#   'Severus Snape',
#   'Penny Haywood',
#   "Jacob's sibling",
#   'Erika Rath',
#   'Gwenog Jones',
#   'Harry Potter',
#   'Amycus Carrow',
#   'Luna Lovegood'],
#  ['Harry Potter',
#   'Kevin Entwhistle',
#   'Roger Malone',
#   'Anthony Goldstein',
#   'Daphne Greengrass',
#   'Scorpius Malfoy',
#   'Ronald Weasley',
#   'Rose Granger-Weasley',
#   'Tom Riddle',
#   'Dolores Umbridge',
#   'Parvati Patil',
#   'Rubeus Hagrid',
#   'Narcissa Malfoy',
#   'Severus Snape',
#   'Bartemius Crouch Junior',
#   'Tom Riddle',
#   'Ginevra Weasley',
#   'Luna Lovegood',
#   'Hermione Granger',
#   'Sirius Black',
#   'Walburga Black',
#   'Cygnus Black III',
#   'Cassiopeia Black',
#   'Callidora Black',
#   'Cedrella Black'],
#  ['Harry Potter',
#   'Minerva McGonagall',
#   'Albus Dumbledore',
#   'Lavender Brown',
#   'Susan Bones',
#   'Seamus Finnigan',
#   'Percy Weasley',
#   'Rubeus Hagrid',
#   'Harry Potter',
#   'Karl Jenkins',
#   'Albus Potter',
#   'James Potter II',
#   'Marauders',
#   'Remus Lupin',
#   'Albus Dumbledore',
#   'Newton Scamander',
#   'Xenophilius Lovegood',
#   'Hermione Granger',
#   'Luna Lovegood',
#   'Seamus Finnigan',
#   'Ronald Weasley',
#   'Fred Weasley',
#   'Percy Weasley',
#   'Marauders',
#   'Peter Pettigrew'],
#  ['Harry Potter',
#   'Oliver Wood',
#   'Minerva McGonagall',
#   'Ben Copper',
#   'Garrick Ollivander',
#   'Tom Riddle',
#   'Lucius Malfoy',
#   'Alastor Moody',
#   'Sirius Black',
#   'Cornelius Fudge',
#   'Percy Weasley',
#   'Hermione Granger',
#   'Sirius Black',
#   'James Potter I',
#   'Ronald Weasley',
#   'Seamus Finnigan',
#   'Katie Bell',
#   'Alicia Spinnet',
#   'Harry Potter',
#   'Cadogan',
#   "Jacob's sibling",
#   'Talbott Winger',
#   'Andre Egwu',
#   'Rowan Khanna',
#   "Jacob's sibling"],
#  ['Harry Potter',
#   'Fred Weasley',
#   'James Potter I',
#   'Tom Riddle',
#   'Harry Potter',
#   'Albus Dumbledore',
#   'Sirius Black',
#   'Rubeus Hagrid',
#   'Justin Finch-Fletchley',
#   'Hannah Abbott',
#   'Alecto Carrow',
#   'Hestia Carrow',
#   'Flora Carrow',
#   'Amycus Carrow',
#   'Minerva McGonagall',
#   'Kingsley Shacklebolt',
#   'Arthur Weasley',
#   'Charles Weasley',
#   "Jacob's sibling",
#   'Ismelda Murk',
#   'Barnaby Lee',
#   'Penny Haywood',
#   "Jacob's sibling",
#   'Andre Egwu',
#   'Barnaby Lee'],
#  ['Harry Potter',
#   'Mulciber II',
#   'Tom Riddle',
#   'Millicent Bagnold',
#   'Robert Hilliard',
#   'Helena Ravenclaw',
#   'Minerva McGonagall',
#   'Ginevra Weasley',
#   'Bellatrix Lestrange',
#   'Molly Weasley',
#   'William Weasley',
#   'Percy Weasley',
#   'Arthur Weasley',
#   'Ronald Weasley',
#   'Filius Flitwick',
#   'Harry Potter',
#   'Bem',
#   'Sybill Trelawney',
#   'Albus Dumbledore',
#   'Percy Weasley',
#   'Molly Weasley',
#   'Lucretia Black',
#   'Orion Black',
#   'Regulus Black',
#   'Percy Weasley'],
#  ['Harry Potter',
#   'Percy Weasley',
#   'Ronald Weasley',
#   'Alicia Spinnet',
#   'Jack Sloper',
#   'Jimmy Peakes',
#   'Ritchie Coote',
#   'Minerva McGonagall',
#   'Armando Dippet',
#   'Lucius Malfoy',
#   'Arthur Weasley',
#   'Sirius Black',
#   'Rolanda Hooch',
#   'Graham Montague',
#   'George Weasley',
#   'Lee Jordan',
#   'Tom Riddle',
#   'Helena Ravenclaw',
#   "Jacob's sibling",
#   'Barnaby Lee',
#   'Ismelda Murk',
#   "Jacob's sibling",
#   'William Weasley',
#   'Ronald Weasley',
#   'Percy Weasley'],
#  ['Harry Potter',
#   'Fat Lady',
#   'Arthur Weasley',
#   'Lucius Malfoy',
#   'Ronald Weasley',
#   'Panju Weasley',
#   'Scorpius Malfoy',
#   'Cedric Diggory',
#   'Nigel Wolpert',
#   'Hermione Granger',
#   'Luna Lovegood',
#   'Molly Weasley',
#   'Cedric Diggory',
#   'Harry Potter',
#   'Albus Dumbledore',
#   'Tom Riddle',
#   'Helga Hufflepuff',
#   'Hermione Granger',
#   'Albus Dumbledore',
#   'Luna Lovegood',
#   'Zacharias Smith',
#   'Cedric Diggory',
#   'Draco Malfoy',
#   'Arthur Weasley',
#   'Nymphadora Tonks'],
#  ['Harry Potter',
#   'Mundungus Fletcher',
#   'Aberforth Dumbledore',
#   'Alastor Moody',
#   'Filius Flitwick',
#   'Head of Ravenclaw House',
#   'Rowena Ravenclaw',
#   'Bloody Baron',
#   'Harry Potter',
#   'Rubeus Hagrid',
#   'Ben Copper',
#   'Rowan Khanna',
#   'Albus Dumbledore',
#   'Quirinus Quirrell',
#   'Tom Riddle',
#   'Lavender Brown',
#   'Zacharias Smith',
#   'Colin Creevey',
#   'Hermione Granger',
#   'Rubeus Hagrid',
#   'Ronald Weasley',
#   'Neville Longbottom',
#   'Hermione Granger',
#   'Harry Potter',
#   'Lily J. Potter'],
#  ['Harry Potter',
#   'Vincent Crabbe',
#   'Mauricius',
#   'Rubeus Hagrid',
#   'Tom Riddle',
#   'Ronald Weasley',
#   'Hermione Granger',
#   'Mundungus Fletcher',
#   'Merula Snyde',
#   'Albus Dumbledore',
#   'Arthur Weasley',
#   'Dirk Cresswell',
#   'John Dawlish',
#   'Marietta Edgecombe',
#   'Cedric Diggory',
#   'Ernest Macmillan',
#   'Harry Potter',
#   'Lily J. Potter',
#   'Lily L. Potter',
#   'Arthur Weasley',
#   'Sirius Black',
#   'Neville Longbottom',
#   'Dolores Umbridge',
#   'Padma Patil',
#   'Panju Weasley'],
#  ['Harry Potter',
#   'Albus Potter',
#   'Charles Weasley',
#   'Jacob (Hogwarts student)',
#   "Jacob's sibling",
#   'Percy Weasley',
#   'Charles Weasley',
#   'Angelica Cole',
#   'Nicholas de Mimsy-Porpington',
#   'Merula Snyde',
#   'Severus Snape',
#   "Jacob's sibling",
#   'George Weasley',
#   'Ginevra Weasley',
#   'Angelina Johnson',
#   'Harry Potter',
#   'Remus Lupin',
#   'Alastor Moody',
#   'Elphias Doge',
#   'Aberforth Dumbledore',
#   'Mundungus Fletcher',
#   'Tom Riddle',
#   'Armando Dippet',
#   'Rubeus Hagrid',
#   'Filius Flitwick'],
#  ['Harry Potter',
#   'Roland Abberley',
#   'Vincent Crabbe',
#   'Lucian Bole',
#   'Rolanda Hooch',
#   'Oliver Wood',
#   'Alicia Spinnet',
#   'Dolores Umbridge',
#   'Fred Weasley',
#   'Justin Finch-Fletchley',
#   'Dean Thomas',
#   'William Weasley',
#   'Charles Weasley',
#   'Andre Egwu',
#   "Jacob's sibling",
#   'Arthur Weasley',
#   'William Weasley',
#   'Merula Snyde',
#   "Merula Snyde's mother",
#   "Merula Snyde's father",
#   'Merula Snyde',
#   "Jacob's sibling",
#   'Penny Haywood',
#   'Beatrice Haywood',
#   'Merlin'],
#  ['Harry Potter',
#   'Mulciber II',
#   'Mary Macdonald',
#   'Lily J. Potter',
#   'Narcissa Malfoy',
#   'Bellatrix Lestrange',
#   'Neville Longbottom',
#   'Tom Riddle',
#   'Dolores Umbridge',
#   'Minerva McGonagall',
#   'Lee Jordan',
#   'Anthony Goldstein',
#   'Fred Weasley',
#   'Head of Ravenclaw House',
#   'Filius Flitwick',
#   "Jacob's sibling",
#   'Rubeus Hagrid',
#   'Sirius Black',
#   'Arthur Weasley',
#   'Alastor Moody',
#   'Remus Lupin',
#   'Parvati Patil',
#   'Harry Potter',
#   'Angelina Johnson',
#   'Lee Jordan'],
#  ['Harry Potter',
#   'Ernest Macmillan',
#   'Justin Finch-Fletchley',
#   'Hermione Granger',
#   'Michael Corner',
#   'Parvati Patil',
#   'Cormac McLaggen',
#   'Ronald Weasley',
#   'Tom Riddle',
#   'Draco Malfoy',
#   'Cedric Diggory',
#   'Gregory Goyle',
#   'Hermione Granger',
#   'Molly Weasley',
#   'George Weasley',
#   'Charles Weasley',
#   'Barnaby Lee',
#   "Jacob's sibling",
#   'Alastor Moody',
#   'Bartemius Crouch Junior',
#   'Severus Snape',
#   'James Potter I',
#   'James Potter II',
#   'Ginevra Weasley',
#   'Bellatrix Lestrange']]

# %%
epochs=20
alpha=0.03
min_alpha=alpha/epochs
vector_size=30

##

n2v_model=gensim.models.Word2Vec(
        alpha=alpha, 
        vector_size=vector_size,
        min_alpha=min_alpha, 
        sg = 1, # Sgrim gramm
        window=5,
        min_count=10, # pruning the internal dictionary. Words that appear only once or twice in a billion-word corpus are probably 
                     #uninteresting typos and garbageso it’s best to ignore them:,
        workers=cores,
        epochs=epochs
            )


n2v_model.build_vocab(walks)
print('nb of walks epochs: ',n2v_model.epochs)
print('nb of walks/sentences generated: ', n2v_model.corpus_count)
print('Size of embedding :',vector_size)
print('nb_characters with more than 5 occurences:',len(n2v_model.wv.key_to_index))

n2v_model.train(walks, total_examples=n2v_model.corpus_count, epochs=epochs, report_delay=1)
# Out:
# nb of walks epochs:  20
# nb of walks/sentences generated:  1200
# Size of embedding : 30
# nb_characters with more than 5 occurences: 254
# (289587, 564520)

# %%
vector = n2v_model.wv['Harry Potter'] 
print(len(vector))
vector
# Out:
# 30
# array([-0.1280801 , -0.07079901,  0.35140583,  0.10379893, -0.06559882,
#         0.20543346,  0.09243023,  0.17643829, -0.2913282 , -0.07919326,
#         0.46755642,  0.00162795,  0.2337747 , -0.26158413, -0.2599963 ,
#        -0.07105176,  0.24187285, -0.33638743, -0.22849321, -0.10485478,
#         0.01169917, -0.28912905, -0.03568604,  0.32563698, -0.01750135,
#         0.2175622 ,  0.1627385 ,  0.2729195 , -0.09406561, -0.24043891],
#       dtype=float32)

# %%
name='Harry Potter'
print('\t Most similar to {}!'.format(name))
for w in n2v_model.wv.most_similar(positive=[name], topn=10):
    print(w)
# Out:
# 	 Most similar to Harry Potter!
# ('Hermione Granger', 0.8702518939971924)
# ('Ronald Weasley', 0.8351869583129883)
# ('Severus Snape', 0.7843526601791382)
# ('Dolores Umbridge', 0.7751405835151672)
# ('Ginevra Weasley', 0.7678818702697754)
# ('Neville Longbottom', 0.7394402623176575)
# ('Carl Hopkins', 0.7064335346221924)
# ('Albus Dumbledore', 0.7000611424446106)
# ('Tom Riddle', 0.7000322341918945)
# ('Quirinus Quirrell', 0.6843520402908325)

# %% [markdown]
# * explain what you're interested in
# * explain the tool
# * apply the tool
# * discuss the outcome
